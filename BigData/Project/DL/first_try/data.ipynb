# %%
import pandas as pd
import numpy as np

# %%
DATA = r"C:\Users\kjy19\Downloads\Crimes_-_2001_to_Present.csv"

CrimeDF = pd.read_csv(DATA)
CrimeDF
# Out:
#                ID Case Number                    Date  \
# 0        11037294    JA371270  03/18/2015 12:00:00 PM
# 1        11646293    JC213749  12/20/2018 03:00:00 PM
# 2        11645836    JC212333  05/01/2016 12:25:00 AM
# 3        11645959    JC211511  12/20/2018 04:00:00 PM
# 4        11645601    JC212935  06/01/2014 12:01:00 AM
# ...           ...         ...                     ...
# 8157280  12131776    JD327752  08/10/2020 08:30:00 PM
# 8157281  12082414    JD269218  06/18/2020 09:00:00 PM
# 8157282  12118237    JD311791  07/27/2020 03:02:00 PM
# 8157283  12142591    JD340297  08/14/2020 03:00:00 PM
# 8157284  12002171    JD177406  03/06/2020 02:00:00 PM
#
#                                        Block  IUCR         Primary Type  \
# 0                          0000X W WACKER DR  1153   DECEPTIVE PRACTICE
# 1                       023XX N LOCKWOOD AVE  1154   DECEPTIVE PRACTICE
# 2                        055XX S ROCKWELL ST  1153   DECEPTIVE PRACTICE
# ...

# %%
CrimeDF['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                1726059
# BATTERY                              1487422
# CRIMINAL DAMAGE                       928940
# NARCOTICS                             755776
# ASSAULT                               540261
# OTHER OFFENSE                         506736
# BURGLARY                              435183
# MOTOR VEHICLE THEFT                   411400
# DECEPTIVE PRACTICE                    369889
# ROBBERY                               307119
# CRIMINAL TRESPASS                     220959
# WEAPONS VIOLATION                     118474
# PROSTITUTION                           70154
# OFFENSE INVOLVING CHILDREN             58449
# PUBLIC PEACE VIOLATION                 53651
# SEX OFFENSE                            32707
# CRIM SEXUAL ASSAULT                    27449
# INTERFERENCE WITH PUBLIC OFFICER       19262
# LIQUOR LAW VIOLATION                   15171
# GAMBLING                               14644
# ...

# %%
VEHICLE = CrimeDF[CrimeDF['Primary Type'] == 'MOTOR VEHICLE THEFT']

# %%
VEHICLE.to_csv('Motor_Vehicle_Theft.csv')
