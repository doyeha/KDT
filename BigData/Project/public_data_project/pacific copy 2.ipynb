# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import pandas as pd
import csv


file_name = 'Climate_year_DF.xlsx'
storm = 'pacific.csv'
Climate = pd.read_excel(file_name)
Cyclone = pd.read_csv(storm)

# Cyclone['Date'] = pd.to_datetime(Cyclone['Date'])
# 1980 ~ 2010 
Cyclone['Date']	=	pd.to_datetime(Cyclone['Date'],	format='%Y%m%d')
Cyclone = Cyclone[(Cyclone['Date'].dt.year>=1980) & (Cyclone['Date'].dt.year<=2010)]
Cyclone.drop(['Low Wind NE','Low Wind SE','Low Wind SW','Low Wind NW','Moderate Wind NE','Moderate Wind SE','Moderate Wind SW','Moderate Wind NW','High Wind NE','High Wind SE','High Wind SW','High Wind NW'], axis=1, inplace=True)
Cyclone['Name']= Cyclone['Name'].str.rstrip().str.lstrip()



Created_Cyclone = []
for y in range(1980,2011):
    Created_Cyclone.append(len(Cyclone[Cyclone['Date'].dt.year == y]['ID'].unique()))
# Created_Cyclone

# %%
StatusDF = pd.DataFrame(columns=['year','Hurricane'])
S_Cy = Cyclone[Cyclone['Status']==' TS']
S_Cy['ID']
# len(S_Cy['ID'].unique())          # 276
# Out:
# 7628     EP011980
# 7629     EP011980
# 7630     EP011980
# 7631     EP011980
# 7644     EP011980
#            ...
# 23090    CP012010
# 23091    CP012010
# 23092    CP012010
# 23093    CP012010
# 23094    CP012010
# Name: ID, Length: 5421, dtype: object

# %%
Cy_list = list(S_Cy['ID'].unique())
# Cy_list

# %%
plz = []
year_list = [i for i in range(1980,2011)]
for i in year_list:
    plz.append(len(S_Cy[S_Cy['Date'].dt.year==i]['ID'].unique()))
for i in plz:
    print(i,end=',')
# Out:
# 14,15,23,21,21,23,17,20,15,17,21,14,27,15,20,10,9,19,13,9,19,16,15,16,12,15,19,11,17,20,8,

# %%
len(S_Cy[S_Cy['Date'].dt.year==1980]['ID'].unique())
# Out:
# 7

# %%
year_list = [i for i in range(1980,2011)]
Cyc_list = []   # 넣은 아이디 append
idx = 0
for i in year_list:
    # StatusDF.loc[idx] = [S_Cye[S_Cy['Date'].dt.year==i]['Date'].dt.year]
    for c in Cy_list:   # 태풍 아이디 리스트
        Cyc_list.append(S_Cy[(S_Cy['Date'].dt.year==i) & (S_Cy['ID']==c)]['ID'])
        if S_Cy[S_Cy['Date'].dt.year==i]['ID'] in Cyc_list: # 확인용 리스트
            break
    idx += 1
    # if S_Cy[S_Cy['Date'].dt.year==i]['ID']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 8
#       6 for c in Cy_list:   # 태풍 아이디 리스트
#       7     Cyc_list.append(S_Cy[(S_Cy['Date'].dt.year==i) & (S_Cy['ID']==c)]['ID'])
# ----> 8     if S_Cy[S_Cy['Date'].dt.year==i]['ID'] in Cyc_list: # 확인용 리스트
#       9         break
#      10 idx += 1
#
# File c:\Users\kjy19\anaconda3\envs\EV_PY39\lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\kjy19\anaconda3\envs\EV_PY39\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
Cyc_list
# Out:
# [7632    EP011980
#  7633    EP011980
#  7634    EP011980
#  7635    EP011980
#  7636    EP011980
#  7637    EP011980
#  7638    EP011980
#  7639    EP011980
#  7640    EP011980
#  7641    EP011980
#  7642    EP011980
#  7643    EP011980
#  Name: ID, dtype: object,
#  7672    EP031980
#  7673    EP031980
#  7674    EP031980
#  7675    EP031980
#  7676    EP031980
#  7677    EP031980
#  7678    EP031980
#  7679    EP031980
#  Name: ID, dtype: object,
#  7726    EP071980
#  Name: ID, dtype: object,
#  7743    EP081980
#  7744    EP081980
#  7745    EP081980
#  7746    EP081980
#  7747    EP081980
#  7748    EP081980
#  7749    EP081980
#  7750    EP081980
#  7751    EP081980
#  7752    EP081980
#  7753    EP081980
#  7754    EP081980
#  7755    EP081980
#  7756    EP081980
#  7757    EP081980
#  7758    EP081980
#  Name: ID, dtype: object,
#  7772    EP091980
#  7773    EP091980
#  7774    EP091980
#  7775    EP091980
#  7776    EP091980
#  7777    EP091980
#  7778    EP091980
# ...

# %%
StatusDF
# Out:
#            0
# 0        NaN
# 1  Hurricane

# %%
Cyclone['Latitude_Alpha'] =  Cyclone['Latitude'].str[-1]
Cyclone['Longitude_Alpha'] =  Cyclone['Longitude'].str[-1]

# %%
Cyclone['Latitude'] = Cyclone['Latitude'].str.replace('N','')
Cyclone['Latitude'] = Cyclone['Latitude'].str.replace('S','')
Cyclone['Longitude'] = Cyclone['Longitude'].str.replace('W','')
Cyclone['Longitude'] = Cyclone['Longitude'].str.replace('E','')

# %%
Cyclone['Status']==HU
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Cyclone['Status']==HU
#
# NameError: name 'HU' is not defined

# %%
Cyclone['Latitude'] = Cyclone['Latitude'].astype('float')
Cyclone['Longitude'] = Cyclone['Longitude'].astype('float')

# %%
Cyclone['Latitude'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 15476 entries, 7625 to 23100
# Series name: Latitude
# Non-Null Count  Dtype
# --------------  -----
# 15476 non-null  float64
# dtypes: float64(1)
# memory usage: 241.8 KB

# %% [markdown]
# ## 필리핀 분석

# %%
Pili_cy = Cyclone[(Cyclone['Latitude']<=21.2) & (Cyclone['Latitude']>=4.3) & (Cyclone['Latitude_Alpha']=='N')]
Pili_cy = Pili_cy[(Pili_cy['Longitude']<=127.3) & (Pili_cy['Longitude']>=114.1)& (Cyclone['Latitude_Alpha']=='E')]
# Out:
# C:\Users\kjy19\AppData\Local\Temp\ipykernel_20172\1693196491.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Pili_cy = Pili_cy[(Pili_cy['Longitude']<=127.3) & (Pili_cy['Longitude']>=114.1)& (Cyclone['Latitude_Alpha']=='E')]

# %%
Pili_cy
# Out:
# Empty DataFrame
# Columns: [ID, Name, Date, Time, Event, Status, Latitude, Longitude, Maximum Wind, Minimum Pressure, Latitude_Alpha, Longitude_Alpha]
# Index: []

# %%
Korea_cy = Cyclone[(Cyclone['Latitude']<=43) & (Cyclone['Latitude']>=33) & (Cyclone['Latitude_Alpha']=='N')]
Korea_cy = Korea_cy[(Korea_cy['Longitude']<=132) & (Korea_cy['Longitude']>=124) & (Korea_cy['Latitude_Alpha']=='E')]

# %%
Korea_cy
# Out:
# Empty DataFrame
# Columns: [ID, Name, Date, Time, Event, Status, Latitude, Longitude, Maximum Wind, Minimum Pressure, Latitude_Alpha, Longitude_Alpha]
# Index: []

# %%
Usa_cy = Cyclone[(Cyclone['Latitude']<=48) & (Cyclone['Latitude']>=24) & (Cyclone['Latitude_Alpha']=='N')]
Usa_cy = Korea_cy[(Korea_cy['Longitude']<=125) & (Korea_cy['Longitude']>=48) & (Korea_cy['Latitude_Alpha']=='W')]

# %%
Usa_cy
# Out:
# Empty DataFrame
# Columns: [ID, Name, Date, Time, Event, Status, Latitude, Longitude, Maximum Wind, Minimum Pressure, Latitude_Alpha, Longitude_Alpha]
# Index: []
