# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib
import pandas as pd
import csv


file_name = 'Climate_year_DF.xlsx'
storm = 'typhoon_data.csv'
Climate = pd.read_excel(file_name)
Cyclone = pd.read_csv(storm)

# Cyclone['Date'] = pd.to_datetime(Cyclone['Date'])
# 1980 ~ 2010 
# Cyclone['Date']	=	pd.to_datetime(Cyclone['Date'],	format='%Y%m%d')
# Cyclone = Cyclone[(Cyclone['Date'].dt.year>=1980) & (Cyclone['Date'].dt.year<=2010)]
Cyclone.drop(['Unnamed: 0','Maximum sustained wind speed','Direction of the longest radius of 50kt winds or greater','The longeast radius of 50kt winds or greater','The shortest radius of 50kt winds or greater','Direction of the longest radius of 30kt winds or greater','The longeast radius of 30kt winds or greater','The shortest radius of 30kt winds or greater','Indicator of landfall or passage'],
             axis=1, inplace=True)
# Cyclone['Name']= Cyclone['Name'].str.rstrip().str.lstrip()


# Created_Cyclone = []
# for y in range(1980,2011):
#     Created_Cyclone.append(len(Cyclone[Cyclone['Date'].dt.year == y]['ID'].unique()))
# Created_Cyclone

# %%
Cyclone['Latitude of the center']
# Out:
# 0        200
# 1        200
# 2        230
# 3        250
# 4        276
#         ...
# 68619    182
# 68620    190
# 68621    200
# 68622    204
# 68623    203
# Name: Latitude of the center, Length: 68624, dtype: int64

# %%
Cyclone.columns = ['ID','year','month','day','hour','grade','Latitude','Longitude','Central pressure']

# %% [markdown]
# ## 기온 변화 그래프 자료

# %%
Climate
# Out:
#          Unnamed: 0   1980   1981   1982   1983   1984   1985   1986   1987  \
# 0       Afghanistan  14.89  14.86  13.73  14.61  14.25  14.89  14.22  14.98
# 1            Africa  24.45  24.30  24.21  24.58  24.39  24.34  24.31  24.92
# 2           Albania  12.16  12.58  13.02  12.51  12.64  12.95  13.06  13.00
# 3           Algeria  23.16  23.58  23.09  23.68  23.06  23.53  23.26  24.25
# 4    American Samoa  26.99  26.75  26.90  26.93  26.88  26.95  26.98  26.90
# ..              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 237  Virgin Islands  26.99  26.90  26.55  26.96  26.60  26.59  26.61  27.14
# 238  Western Sahara  22.93  23.02  22.37  23.38  22.41  22.86  22.42  23.73
# 239           Yemen  26.86  26.54  26.08  26.24  25.85  25.88  26.05  26.61
# 240          Zambia  21.34  21.25  21.60  22.35  21.67  21.33  21.29  22.31
# 241        Zimbabwe  21.13  20.80  21.57  22.37  21.71  21.20  21.20  22.32
#
# ...

# %% [markdown]
# ## 필리핀

# %%
Pili_cy = Cyclone[(Cyclone['Latitude']<=212) & (Cyclone['Latitude']>=43)]
Pili_cy = Pili_cy[(Pili_cy['Longitude']<=1273) & (Pili_cy['Longitude']>=1141)]

# %%
Pili_cy = Pili_cy[(Pili_cy['year'] >= 1980) & (Pili_cy['year']<=2010)]

# len(Pili_cy['ID'].unique()) => 376개
Pili_cy.to_excel('필리핀태풍.xlsx')

# %%
Pili_Cy_list = Pili_cy['ID'].unique().tolist()

# %%
year_list = [i for i in range(1980,2011)]
Pili_cy_sum = []
for y in year_list: 
    a = Pili_cy[Pili_cy['year']==y]
    Pili_cy_sum.append(len(a['ID'].unique()))

# %%
Pili_cy_sum
# Out:
# [12,
#  12,
#  15,
#  13,
#  12,
#  11,
#  16,
#  13,
#  15,
#  14,
#  16,
#  14,
#  10,
#  13,
#  15,
#  13,
#  13,
#  10,
#  11,
#  12,
#  12,
#  12,
#  7,
#  13,
#  9,
#  9,
#  13,
#  8,
#  14,
#  13,
#  7]

# %% [markdown]
# ## 필리핀 - 기온 변화 그래프

# %%
year_list.insert(0,'Country')
year_list
# Out:
# ['Country',
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010]

# %%
Pili_temp = Climate[Climate['Unnamed: 0'] == 'Philippines']
# Climate
# ,year_list
# Pili_temp.columns = year_list

# Pili_temp['Country'] = 'Country'
# Pili_temp = Pili_temp.set_index('Country')
Pili_temp
# Out:
#       Unnamed: 0   1980   1981   1982  1983   1984  1985   1986  1987   1988  \
# 173  Philippines  26.77  26.83  26.75  27.1  26.67  26.9  26.79  27.3  27.19
#
#      ...  2001   2002   2003   2004   2005   2006   2007   2008   2009   2010
# 173  ...  27.1  27.08  27.01  27.09  27.14  27.18  27.16  26.88  27.01  27.36
#
# [1 rows x 32 columns]

# %%
# Pili_temp.loc['2'] = 'Cyclone', Pili_cy_sum
Pili_cy_sum.insert(0,'Cyclone')

# %%
Pili_temp.loc['2'] =Pili_cy_sum
# Pili_temp.set_index('Unnamed: 0')
Pili_temp = Pili_temp.T
# Out:
# C:\Users\kjy19\AppData\Local\Temp\ipykernel_20600\1421045315.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pili_temp.loc['2'] =Pili_cy_sum

# %%
Pili_temp.drop(['Unnamed: 0'], inplace=True)
Pili_temp
# Out:
#         173     2
# 1980  26.77  12.0
# 1981  26.83  12.0
# 1982  26.75  15.0
# 1983   27.1  13.0
# 1984  26.67  12.0
# 1985   26.9  11.0
# 1986  26.79  16.0
# 1987   27.3  13.0
# 1988  27.19  15.0
# 1989  26.73  14.0
# 1990  26.93  16.0
# 1991  26.79  14.0
# 1992   26.9  10.0
# 1993  26.85  13.0
# 1994  26.83  15.0
# 1995  26.83  13.0
# 1996  26.89  13.0
# 1997  26.98  10.0
# 1998  27.78  11.0
# 1999  26.93  12.0
# 2000  27.01  12.0
# 2001   27.1  12.0
# 2002  27.08   7.0
# 2003  27.01  13.0
# 2004  27.09   9.0
# 2005  27.14   9.0
# 2006  27.18  13.0
# 2007  27.16   8.0
# 2008  26.88  14.0
# 2009  27.01  13.0
# 2010  27.36   7.0

# %%
Pili_temp.columns = ['Country', 'Cyclone']

# %%
Pili_temp.corr()
# Out:
#           Country   Cyclone
# Country  1.000000 -0.417728
# Cyclone -0.417728  1.000000

# %%
plt.scatter(Pili_temp['Country'], Pili_temp['Cyclone'])
plt.title('필리핀 년간 평균기온 - 태풍 발생 상관관계')
plt.legend()
# Out:
# C:\Users\kjy19\AppData\Local\Temp\ipykernel_20600\3453611722.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 corr(Pili_temp, Pili_cy_sum)
#
# NameError: name 'corr' is not defined
