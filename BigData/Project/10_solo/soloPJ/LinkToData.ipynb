# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# 로그인 관련 import 해옴. 참고한 블로그는 노션 인스타 로그인 문제 블로그 링크
from selenium.webdriver import ActionChains 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By # HTML 요소를 찾아서 가져오고 싶을 때 쓰는 것

import re

import pandas as pd

# %%
# 태그별 링크 모음 한꺼번에 처리하기 위해 파일 리스트 제작
import os
filelist = os.listdir("./")
filelist = [f for f in filelist if ".csv" in f]
filelist
# Out:
# ['감성태그.csv',
#  '강아지태그.csv',
#  '고양이태그.csv',
#  '공부태그.csv',
#  '광고태그.csv',
#  '대구태그.csv',
#  '데일리태그.csv',
#  '라이프태그.csv',
#  '링크csv.csv',
#  '뷰티태그.csv',
#  '사진태그.csv',
#  '산책태그.csv',
#  '셀카태그.csv',
#  '소통태그.csv',
#  '스타일태그.csv',
#  '여행태그.csv',
#  '일상태그.csv',
#  '추천태그.csv',
#  '취미태그.csv',
#  '카페태그.csv']

# %%
# # 링크 통합 후 본격적인 크롤링 시작 // 추가 크롤링 시 통합용
# LinkDF = pd.DataFrame(columns=["태그","링크"])
# for f in filelist:
#     tempDF = pd.read_csv(f)
#     LinkDF = pd.concat([LinkDF,tempDF])
# LinkDF

# LinkDF.to_csv("링크csv.csv")

for f in filelist:
    tempDF = pd.read_csv(f)
    print(f"{f}",len(tempDF['링크'].unique()))
# Out:
# 감성태그.csv 4305
# 강아지태그.csv 5007
# 고양이태그.csv 5940
# 공부태그.csv 6393
# 광고태그.csv 1506
# 대구태그.csv 6960
# 데일리태그.csv 2451
# 라이프태그.csv 6687
# 링크csv.csv 91323
# 뷰티태그.csv 6573
# 사진태그.csv 6282
# 산책태그.csv 6261
# 셀카태그.csv 6513
# 소통태그.csv 6531
# 스타일태그.csv 4983
# 여행태그.csv 5145
# 일상태그.csv 6015
# 추천태그.csv 4390
# 취미태그.csv 6546
# 카페태그.csv 4776

# %%
LinkDF = pd.read_csv("링크csv.csv")

# %%
# # 일단 크롬 띄워놓고 해당 화면에서 한번 로그인하면 그 창에서 계속 크롤링 하도록 설정
chrome_driver_path = "path_to_chromedriver"  # 크롬 드라이버 설치 경로 입력
service = Service(chrome_driver_path)

# # 웹 드라이버 실행
driver = webdriver.Chrome()
url ="https://www.instagram.com"
driver.get(url) # 1차 로그인 화면 
# time.sleep(3)

# %%
# 191551 => 엄청 밑에 태그 잇음 + 답글 열기 해야함.
# i = 191551
# print(LinkDF.iloc[i])
# url = LinkDF.iloc[i]["링크"]
# driver.get(url)

# %% [markdown]
# 아이디 크롤링
# 창 크기에 따라 달라지는 캡션 길이 - 스크롤 해야함.
# 내용 크롤링
# 더보기 눌러줘야함.
# 대댓글 확인 일일이 눌러주고 거기서 게시글 작성자의 아이디와 맞는지 확인 후 태그 부분 크롤링

# %% [markdown]
# 아이디 : x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz  _acan _acao _acat _acaw _aj1- _ap30 _a6hd
# span = class _ap3a _aaco _aacw _aacx _aad7 _aade

# %%
# 본 부분 
# x193iq5w xeuugli x1fj9vlw x13faqbe x1vvkbs xt0psk2 x1i0vuye xvs91rp xo1l8bm x5n08af x10wh9bi x1wdrske x8viiok x18hxmgj

# %%
# text_XPath = '//*[@id="mount_0_0_b8"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/span'
# text_text = driver.find_element(By.XPATH, text_XPath) 
# text_text.text

# %% [markdown]
# 댓글에서 id 추출
# XPath : //*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
#
# Selector : #mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > span.x1lliihq.x1plvlek.xryxfnj.x1n2onr6.x1ji0vk5.x18bv5gf.x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.x1s928wv.xhkezso.x1gmr53x.x1cpjm7i.x1fgarty.x1943h6x.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj > span > div > a > div > div > span
#
# element : <span class="_ap3a _aaco _aacw _aacx _aad7 _aade" dir="auto">hyeji.log</span>

# %%
# # 댓글 누르기 - 성공!!!! 
# button_XPath = '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[2]/div'
# buttons = driver.find_elements(By.XPATH,button_XPath)
# time.sleep(1.5)
# for button in buttons:
#     button.send_keys(Keys.ENTER)
#     time.sleep(1.5)
#     print(button)
#     # button.click()    # 왜 크,ㄹ릭 2번 함 ????????????????????????????
#     break

# %% [markdown]
# 다른 사람 : //*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[12]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span
#
# 주인 댓글 : //*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span

# %%
# id_XPath = "//*[@id='mount_0_0_b8']/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span"
# 아래, 본문의 아이디

# id_XPath =   '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[1]/div/div[2]/div/div[1]/div[1]/div/span/span/div/a/div/div/span'
# text_id = driver.find_element(By.XPATH, id_XPath)

# %%
# scrollable_div = driver.find_element(By.CSS_SELECTOR, '#mount_0_0_dO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.xvkph5b.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x10o80wk.x14k21rp.xh8yej3.x8vgawa > section > main > div > div._aa6e > article > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1n2onr6.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul')
# scroll_step = 300  # 한 번에 스크롤할 픽셀 수
# current_position = 0

# while current_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
#     # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
#     # 현재 위치에서 scroll_step만큼만 스크롤
#     driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#     current_position += scroll_step

#     # id 크롤링
#     id_XPath =  '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span'
#     try:
#         time.sleep(1)
#         text_id = driver.find_element(By.XPATH, id_XPath)
#         # text_id.text
#         # print(text_id.text)
#     except:
#         print("아니 왜 안댐?")    # id의 댓글만 뽑아오기 용

#     try:
#         com_id = driver.find_elements(By.XPATH, '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span')
#         if com_id[0].text == text_id.text:
#             button_XPath = '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[2]/div'
#             buttons = driver.find_elements(By.XPATH,button_XPath)
#             time.sleep(1.5)
#             for button in buttons:
#                 button.send_keys(Keys.ENTER)
#                 time.sleep(1.5)
#                 # print(button)
#                 break
#             driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#             com_hash = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > ul > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span"
#             has = driver.find_elements(By.CSS_SELECTOR,com_hash)
#             print(has[0].text)
#         break
#     except:
#         pass

# %%
# sele = '#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(1) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > span.x1lliihq.x1plvlek.xryxfnj.x1n2onr6.x1ji0vk5.x18bv5gf.x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.x1s928wv.xhkezso.x1gmr53x.x1cpjm7i.x1fgarty.x1943h6x.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj > span > div > a > div > div > span'
# com_id = driver.find_elements(By.XPATH, )
# for c in com_id:
#     print(c.text)

# %%
# # 스크롤 부분
# scrollable_div = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_6x > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6")


# scroll_step = 300  # 한 번에 스크롤할 픽셀 수
# current_position = 0

# # 1. 아이디 크롤링 (id XPath)
# id_XPath = "//*[@id='mount_0_0_b8']/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span"
# text_id = driver.find_element(By.XPATH, id_XPath) 
# text_id.text


# # 본문 크롤링 (text XPath)
# # 본문에 태그가 있는 경우에는 태그도 다 함께 나온다.
# text_XPath = '//*[@id="mount_0_0_b8"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/span'
# text_text = driver.find_element(By.XPATH, id_XPath) 
# text_text.text

# # 댓글 div
# # # element : x78zum5 xdt5ytf x1iyjqo2
# # XPath : //*[@id="mount_0_0_b8"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]
# # Selector : #mount_0_0_b8 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2

# # 요소의 scrollHeight만큼 스크롤
# while current_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
#     # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
#     # 현재 위치에서 scroll_step만큼만 스크롤
#     driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#     current_position += scroll_step
#     time.sleep(1)
# time.sleep(2)

# %%
# scroll_method = "document.querySelector('3x5yr21d').scrollTo(0, document.querySelector('3x5yr21d').scrollHeight)"
# x5yr21d xw2csxc x1odjw0f x1n2onr6
# driver.execute_script(scroll_method)
# itemlist = driver.find_element_by_class_name("x5yr21d")
# driver.execute_script("arguments[0].scrollBy(0, Y)", itemlist)

# %%
# first_result = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n")
# for f in first_result[:1]:  # 여기서 하나씩 뽑아서? href가 포함되어있는 것만 한다.
#     result_links = f.get_attribute("href")
#     print(result_links)

# %%
LinkDF = LinkDF[['태그','링크']]
# LinkDF.columns = [LinkDF.columns +['게시자 아이디', '본문 내용','해시태그']]

DataDF = pd.DataFrame(columns=['게시자 아이디', '본문 내용','해시태그'])
DataDF = LinkDF + DataDF
DataDF
# Out:
#        게시자 아이디   링크 본문 내용   태그 해시태그
# 0          NaN  NaN   NaN  NaN  NaN
# 1          NaN  NaN   NaN  NaN  NaN
# 2          NaN  NaN   NaN  NaN  NaN
# 3          NaN  NaN   NaN  NaN  NaN
# 4          NaN  NaN   NaN  NaN  NaN
# ...        ...  ...   ...  ...  ...
# 352438     NaN  NaN   NaN  NaN  NaN
# 352439     NaN  NaN   NaN  NaN  NaN
# 352440     NaN  NaN   NaN  NaN  NaN
# 352441     NaN  NaN   NaN  NaN  NaN
# 352442     NaN  NaN   NaN  NaN  NaN
#
# [352443 rows x 5 columns]

# %%
LinkDF = pd.read_csv("링크csv.csv")
LinkDF.drop_duplicates(subset='링크',inplace=True)
LinkDF = LinkDF[["태그","링크"]]
LinkDF['게시자 아이디'] = [" " for n in range(len(LinkDF["링크"].unique()))]
LinkDF['본문 내용'] = [" " for n in range(len(LinkDF["링크"].unique()))]
LinkDF['해시태그'] = [" " for n in range(len(LinkDF["링크"].unique()))]

LinkDF
# Out:
#         태그                                        링크 게시자 아이디 본문 내용 해시태그
# 0       감성  https://www.instagram.com/p/CjvNzS8vvMB/
# 1       감성  https://www.instagram.com/p/DBaX8STz2sf/
# 2       감성  https://www.instagram.com/p/DA0uUuESwOz/
# 3       감성  https://www.instagram.com/p/DAfAMV5TNKS/
# 4       감성  https://www.instagram.com/p/DAx1Xf2SQtm/
# ...     ..                                       ...     ...   ...  ...
# 347494  카페  https://www.instagram.com/p/CapHbmDpdFK/
# 347495  카페  https://www.instagram.com/p/DAAypQ8SKTI/
# 347496  카페  https://www.instagram.com/p/C9lqHsPJUPy/
# 347497  카페  https://www.instagram.com/p/Ci09hEWvTqJ/
# 347498  카페  https://www.instagram.com/p/CdOE8SHlLyp/
#
# [91323 rows x 5 columns]

# %%
# for idx, i in enumerate(list(LinkDF['링크'])[:10]): 
#     LinkDF.iloc[idx] = [LinkDF.iloc[idx]['태그'], LinkDF.iloc[idx]['링크'],'test2','test2','test3']
# LinkDF

# %%
# chrome_driver_path = "path_to_chromedriver"  # 크롬 드라이버 설치 경로 입력
# service = Service(chrome_driver_path)
# driver = webdriver.Chrome()
# driver.get("https://www.instagram.com/p/C-mePRtSRid/	")

# %%
id_XPath='//*[@id="mount_0_0_ju"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/div[1]/li/div/div/div[2]/h2/div/a'

# id_XPath = "#mount_0_0_0Y > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.xvkph5b.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x10o80wk.x14k21rp.xh8yej3.x8vgawa > section > main > div._aa6b._ad9f._aa6d > div._aa6e > article > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1n2onr6.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul > div.x1qjc9v5.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x78zum5.xdt5ytf.x2lah0s.xk390pu.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.xggy1nq.x11njtxf > li > div > div > div._a9zr > h2 > div > a"
text_XPath = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > span > div > span"
# id_XPath =  '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span'

# %%
id_selecter ="#mount_0_0_9n > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.xvkph5b.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x10o80wk.x14k21rp.xh8yej3.x8vgawa > section > main > div._aa6b._ad9f._aa6d > div._aa6e > article > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1n2onr6.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div._aasi > div > header > div._aaqy._aaqz > div._aar0._ad95._aar1 > div.x78zum5 > div > div > span > a"
id_XPath='//*[@id="mount_0_0_E5"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/div[1]/li/div/div/div[2]/h2/div/a'
id_XPath='//*[@id="mount_0_0_9n"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul/div[1]/li/div/div/div[2]/h2/div/a'

scroll_XPath = '//*[@id="mount_0_0_Gu"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'
scroll_Select = "#mount_0_0_Gu > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.xvkph5b.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x10o80wk.x14k21rp.xh8yej3.x8vgawa > section > main > div._aa6b._ad9f._aa6d > div._aa6e > article > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1n2onr6.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul"

# %%
# text = "x193iq5w xeuugli x1fj9vlw x13faqbe x1vvkbs xt0psk2 x1i0vuye xvs91rp xo1l8bm x5n08af x10wh9bi x1wdrske x8viiok x18hxmgj"
# text = text.replace(" ",".")
# text

# %%
# x1i10hfl.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz  _acan _acao _acat _acaw _aj1- _ap30 _a6hd
# x1i10hfl xjqpnuy xa49m3k xqeqjp1 x2hbi6w xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x1lku1pv x1a2a7pz x6s0dn4 xjyslct x1ejq31n xd10rxx x1sy0etr x17r0tee x9f619 x1ypdohk x1f6kntn xwhw2v2 xl56j7k x17ydfre x2b8uid xlyipyv x87ps6o x14atkfc xcdnw81 x1i0vuye xjbqb8w xm3z3ea x1x8b98j x131883w x16mih1h x972fbf xcfux6l x1qhh985 xm0m39n xt0psk2 xt7dq6l xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x1n5bzlp xqnirrm xj34u2y x568u83
# class="x1i10hfl xjqpnuy xa49m3k xqeqjp1 x2hbi6w xdl72j9 x2lah0s xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r x2lwn1j xeuugli x1hl2dhg xggy1nq x1ja2u2z x1t137rt x1q0g3np x1lku1pv x1a2a7pz x6s0dn4 xjyslct x1ejq31n xd10rxx x1sy0etr x17r0tee x9f619 x1ypdohk x1f6kntn xwhw2v2 xl56j7k x17ydfre x2b8uid xlyipyv x87ps6o x14atkfc xcdnw81 x1i0vuye xjbqb8w xm3z3ea x1x8b98j x131883w x16mih1h x972fbf xcfux6l x1qhh985 xm0m39n xt0psk2 xt7dq6l xexx8yu x4uap5 x18d9i69 xkhd6sd x1n2onr6 x1n5bzlp xqnirrm xj34u2y x568u83"
# comid.text

# %%
def insert_tag_row(idx, Oner_ID, MainText, hash_list):
    LinkDF.iloc[idx] = [LinkDF.iloc[idx]['태그'], LinkDF.iloc[idx]['링크'],  Oner_ID, MainText, hash_list]

for idx, link in enumerate(list(LinkDF['링크'])[:100]): 
    driver.get(link) # 1차 로그인 화면 
    time.sleep(4)

    # 스크롤할 부분 찾기
    try:
        scrollable_div = driver.find_element(By.CLASS_NAME, "_a9z6")
    except:
        pass
    try:
        scrollable_div = driver.find_element(By.CLASS_NAME, "_a9z6._a9za")
    except:
        pass
    try:
        scrollable_div = driver.find_element(By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6")
    except:
        pass
    try:
        scrollable_div = driver.find_element(By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul')
    except:
        pass
    try:
        scrollable_div = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_IQ > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.xvkph5b.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x10o80wk.x14k21rp.xh8yej3.x8vgawa > section > main > div._aa6b._ad9f._aa6d > div._aa6e > article > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1n2onr6.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > div.x78zum5.xdt5ytf.x1q2y9iw.x1n2onr6.xh8yej3.x9f619.x1iyjqo2.x18l3tf1.x26u7qi.xy80clv.xexx8yu.x4uap5.x18d9i69.xkhd6sd > div.x78zum5.xdt5ytf.x1iyjqo2.xs83m0k.x2lwn1j.x1odjw0f.x1n2onr6.x9ek82g.x6ikm8r.xdj266r.x11i5rnm.x4ii5y1.x1mh8g0r.xexx8yu.x1pi30zi.x18d9i69.x1swvt13 > ul")
    except:
        pass
    try:
        scrollable_div = driver.find_element(By.XPATH, "/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul")
    except:
        pass
    
        


       
    
    scroll_step = 300  # 스크롤 픽셀
    current_position = 0

    # 스크롤 되는 부분
    stop_point = False
    while stop_point == False:
        # 본문에 해시태그가 10개 이상 포함되어있으면 댓글 안보기
        # urrent_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
        # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
        # 현재 위치에서 scroll_step만큼만 스크롤
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)


        # id 크롤링
        try:
            time.sleep(1)
            Oner_ID = driver.find_element(By.CLASS_NAME,'x1i10hfl.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.xdl72j9.x2lah0s.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1q0g3np.x1lku1pv.x1a2a7pz.x6s0dn4.xjyslct.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x9f619.x1ypdohk.x1f6kntn.xwhw2v2.xl56j7k.x17ydfre.x2b8uid.xlyipyv.x87ps6o.x14atkfc.xcdnw81.x1i0vuye.xjbqb8w.xm3z3ea.x1x8b98j.x131883w.x16mih1h.x972fbf.xcfux6l.x1qhh985.xm0m39n.xt0psk2.xt7dq6l.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x1n5bzlp.xqnirrm.xj34u2y.x568u83')
            Oner_ID = Oner_ID.text
            print("계정주 아이디 : ",Oner_ID, end="/t")
        except:
            Oner_ID = None
            print(f"{link[-10:]} 아이디 안댓음 도대체 왜 와이 어째서",end="/t")    # id의 댓글만 뽑아오기 용


        hash_list = []

        # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade
        try:
            MainText= driver.find_element(By.CLASS_NAME,'_ap3a._aaco._aacu._aacx._aad7._aade')
            print(f"본문 클래스 네임 안댐." ,end="/t")
        except:
            pass
        try:
            MainText= driver.find_element(By.CLASS_NAME,'x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.xt0psk2.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj')
            print(f"본문 클래스 네임2 안댐." ,end="/t")
        except:
            pass

        MainText = MainText.text
        print(MainText)
        text_list = MainText.split()
        for t in text_list:
            if "#" in t:                # 본문에 해시태그가 있는 경우, 삭제 및 hash리스트에 빼서 넣어두기.
                MainText.replace(t,"")
                hash_list.append(t)
        MainText = re.sub('[^가-힣]+',' ',MainText) # 영어 및 이모티콘 같은 글 삭제  
        if len(MainText) < 30:
            MainText = None # 전처리, 30자 이하라면 분석이 애매하니 삭제한다.
            stop_point = True
        else: 
            pass
        

        # 해시태그가 본문에 없다면, 댓글이나 대댓글에 있다.
        if len(hash_list) < 5:
            try:
                comment_Oner = driver.find_elements(By.XPATH, '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span')
                if comment_Oner[0].text == Oner_ID: # 계정주 == 댓글주 아이디 같으면?
                    comment = driver.find_element(By.CSS_SELECTOR,"#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span")
                    comment = comment.text
                    print("comment :", comment)
                    if "#" in comment:
                        comment_list = comment.split()
                        for c in comment_list:
                            if "#" in c:
                                hash_list.append(c)
                        stop_point = True
                    else:
                        print("댓글 내부에는 해시태그 없음.")
                        # 댓글에 해시태그가 없다면 대댓글 열어봐
                        button_XPath = '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[2]/div'
                        buttons = driver.find_elements(By.XPATH,button_XPath)
                        time.sleep(1.5)
                        for button in buttons:
                            button.send_keys(Keys.ENTER)
                            time.sleep(1.5)
                            # print(button)
                            break
                        # 댓글 열고 나서는 또 아래로 내려서 봐야함. 맨 밑에 있었다면 안보이니까.
                        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
                        cocom_hash_selector = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > ul > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span"
                        hash = driver.find_elements(By.CSS_SELECTOR,cocom_hash_selector)
                        hash = hash.text
                        for h in hash.split():
                            hash_list.append(h)
                        print("대댓글 해시태그",hash)
                        stop_point = True
                break
            except:
                stop_point = True
                pass
        stop_point = True
    print(idx, Oner_ID, MainText, hash_list)
    insert_tag_row(idx, Oner_ID, MainText, hash_list)
LinkDF
# Out:
# 계정주 아이디 :  musicdalin/t본문 클래스 네임2 안댐./t"내게 기대도 돼, 내 사랑은 변함없을 거야"💜
#
# 💿 Michael Learns To Rock - Complicated Heart
# (Cover by Nonoy Peña)
#
# #명곡 #추억 #팝송 #사랑 #연인 #고백 #가사해석 #팝송추천 #드라이브
# #플레이리스트 #감성팝송 #노래추천 #감성 #플리 #커버 #가사 #노래
# 0 musicdalin  내게 기대도 돼 내 사랑은 변함없을 거야 명곡 추억 팝송 사랑 연인 고백 가사해석 팝송추천 드라이브 플레이리스트 감성팝송 노래추천 감성 플리 커버 가사 노래 ['#명곡', '#추억', '#팝송', '#사랑', '#연인', '#고백', '#가사해석', '#팝송추천', '#드라이브', '#플레이리스트', '#감성팝송', '#노래추천', '#감성', '#플리', '#커버', '#가사', '#노래']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\kjy19\anaconda3\envs\slpj\lib\site-packages\numpy\core\fromnumeric.py:3185, in ndim(a)
#    3184 try:
# -> 3185     return a.ndim
#    3186 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'ndim'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 132
#     130         stop_point = True
#     131     print(idx, Oner_ID, MainText, hash_list)
# --> 132     insert_tag_row(idx, Oner_ID, MainText, hash_list)
#     133 LinkDF
#
# Cell In[30], line 2, in insert_tag_row(idx, Oner_ID, MainText, hash_list)
#       1 def insert_tag_row(idx, Oner_ID, MainText, hash_list):
# ----> 2     LinkDF.iloc[idx] = [LinkDF.iloc[idx]['태그'], LinkDF.iloc[idx]['링크'],  Oner_ID, MainText, hash_list]
#
# File c:\Users\kjy19\anaconda3\envs\slpj\lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\kjy19\anaconda3\envs\slpj\lib\site-packages\pandas\core\indexing.py:1835, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1832 # align and set the values
#    1833 if take_split_path:
#    1834     # We have to operate column-wise
# -> 1835     self._setitem_with_indexer_split_path(indexer, value, name)
#    1836 else:
#    1837     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\kjy19\anaconda3\envs\slpj\lib\site-packages\pandas\core\indexing.py:1872, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1869 if isinstance(value, ABCDataFrame):
#    1870     self._setitem_with_indexer_frame_value(indexer, value, name)
# -> 1872 elif np.ndim(value) == 2:
#    1873     # TODO: avoid np.ndim call in case it isn't an ndarray, since
#    1874     #  that will construct an ndarray, which will be wasteful
#    1875     self._setitem_with_indexer_2d_value(indexer, value)
#    1877 elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#    1878     # We are setting multiple rows in a single column.
#
# File <__array_function__ internals>:200, in ndim(*args, **kwargs)
#
# File c:\Users\kjy19\anaconda3\envs\slpj\lib\site-packages\numpy\core\fromnumeric.py:3187, in ndim(a)
#    3185     return a.ndim
#    3186 except AttributeError:
# -> 3187     return asarray(a).ndim
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.

# %%
id_XPath = "//*[@id='mount_0_0_g7']/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[1]/div/div[2]/div/div[1]/div[1]/div/span/span/div/a/div/div/span"
text_id = driver.find_element(By.XPATH, id_XPath)
print("text_id :",text_id.text)

text_XPath = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > span > div > span"
text_text = driver.find_element(By.CSS_SELECTOR, text_XPath) 
print("text_text :",text_text.text)

scrollable_div = driver.find_element(By.CSS_SELECTOR, '#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6')
scroll_step = 300  # 한 번에 스크롤할 픽셀 수
current_position = 0

while current_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
    # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
    # 현재 위치에서 scroll_step만큼만 스크롤
    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
    current_position += scroll_step

    # id 크롤링
    id_XPath =  '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/div/span[1]/div/a/div/div/span'
    try:
        time.sleep(1)
        text_id = driver.find_element(By.XPATH, id_XPath)
        # text_id.text
        # print(text_id.text)
    except:
        print("아니???외??않도???")    # id의 댓글만 뽑아오기 용

    try:
        com_id = driver.find_elements(By.XPATH, '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span')
        if com_id[0].text == text_id.text:
            comment = driver.find_element(By.CSS_SELECTOR,"#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span")
            if "#" in comment.text:
                print(comment.text)
            else:
                print("댓글 내부에는 해시태그 없음.")
            button_XPath = '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[2]/div'
            buttons = driver.find_elements(By.XPATH,button_XPath)
            time.sleep(1.5)
            for button in buttons:
                button.send_keys(Keys.ENTER)
                time.sleep(1.5)
                # print(button)
                break
            driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
            com_hash = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > ul > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span"
            has = driver.find_elements(By.CSS_SELECTOR,com_hash)
            print("대댓글 해시태그",has[0].text)
        break
    except:
        pass
# Out:
# text_id : hyeji.log
# text_text : 내가 제일 좋아하는 green 🌿
# 오늘은 차분한 그린톤으로 다이어리를 꾸미며 하루를 마무리 합니다
# 여러분은 어떤 색깔을 가장 좋아하시나요~?
# 댓글 내부에는 해시태그 없음.
# 댓글 내부에는 해시태그 없음.
# 대댓글 해시태그 @hyeji.log #빈티지다꾸 #감성다꾸 #다이어리 #다이어리꾸미기 #일기 #취미 #문구스타그램 #colors #green #diary #journal #vintagejournal #artjournaling #journaling #stamping
