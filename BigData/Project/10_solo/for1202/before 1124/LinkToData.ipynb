# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# 로그인 관련 import 해옴. 참고한 블로그는 노션 인스타 로그인 문제 블로그 링크
from selenium.webdriver import ActionChains 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By # HTML 요소를 찾아서 가져오고 싶을 때 쓰는 것

import re
import pandas as pd

# %%
# # 태그별 링크 모음 한꺼번에 처리하기 위해 파일 리스트 제작
# import os
# filelist = os.listdir(r"C:\Users\Doyeon\Desktop\KDT\soloPJ\first")
# filelist = [f for f in filelist if ".csv" in f]
# filelist

# %%
# # 중복 이슈 제거 (해결완료)
# for f in filelist:
#     tempDF = pd.read_csv("./first/"+f)
#     print(f"{f} 변경 전", len(tempDF['링크'].unique()))
#     tempDF.drop_duplicates(subset="링크", inplace=True)
#     print(f"{f} 변경 후", len(tempDF['링크'].unique()))
#     tempDF.to_csv(f"{f}태그(r).csv")
#     print("--------------------------------------")

# %%
# tempDF1 = pd.read_csv("대구태그.csv", index_col=[0,1,2])
# tempDF2 = pd.read_csv("라이프태그.csv", index_col=[0,1,2])
# tempDF = pd.concat([tempDF1,tempDF2])
# tempDF

# %%
# # 링크 통합 후 본격적인 크롤링 시작
# LinkDF = pd.DataFrame(columns=["태그","링크"])
# for f in filelist:
#     tempDF = pd.read_csv("./first/"+f)
#     LinkDF = pd.concat([LinkDF,tempDF])
# LinkDF.drop_duplicates(subset="링크", inplace=True)

# LinkDF.to_csv("링크.csv")

# %%
# 일단 크롬 띄워놓고 해당 화면에서 한번 로그인하면 그 창에서 계속 크롤링 하도록 설정
chrome_driver_path = "path_to_chromedriver"  # 크롬 드라이버 설치 경로 입력
service = Service(chrome_driver_path)

# 웹 드라이버 실행
driver = webdriver.Chrome()
url ="https://www.instagram.com"
driver.get(url) # 1차 로그인 화면 
time.sleep(3)

# %%
# 각 링크 별 확인용
#  i = 15135
# print(LinkDF.iloc[i])
# url = LinkDF.iloc[i]["링크"]
# driver.get(url)

# %% [markdown]
# 아이디 크롤링
# 창 크기에 따라 달라지는 캡션 길이 - 스크롤 해야함.
# 내용 크롤링
# 더보기 눌러줘야함.
# 대댓글 확인 일일이 눌러주고 거기서 게시글 작성자의 아이디와 맞는지 확인 후 태그 부분 크롤링

# %% [markdown]
# 아이디 : x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz  _acan _acao _acat _acaw _aj1- _ap30 _a6hd
# span = class _ap3a _aaco _aacw _aacx _aad7 _aade

# %%
# 스크롤 해봄
# scrollable_div = driver.find_element(By.CSS_SELECTOR, "#mount_0_0_6x > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6")


# scroll_step = 300  # 한 번에 스크롤할 픽셀 수
# current_position = 0
# # 요소의 scrollHeight만큼 스크롤
# while current_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
#     # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
#     # 현재 위치에서 scroll_step만큼만 스크롤
#     driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#     current_position += scroll_step
#     time.sleep(1)
# time.sleep(2)

# %%
# 링크 뽑을 때 쓴 코드
# first_result = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n")
# for f in first_result[:1]:  # 여기서 하나씩 뽑아서? href가 포함되어있는 것만 한다.
#     result_links = f.get_attribute("href")
#     print(result_links)

# %%
# LinkDF + 아이디 + 본문 + 해시태그 빈 자리 만들어두기
LinkDF = pd.read_csv("링크.csv")
LinkDF = LinkDF[["태그","링크"]]
LinkDF['게시자 아이디'] = [" " for n in range(len(LinkDF["링크"].unique()))]
LinkDF['본문 내용'] = [" " for n in range(len(LinkDF["링크"].unique()))]
LinkDF['해시태그'] = [" " for n in range(len(LinkDF["링크"].unique()))]
LinkDF
# Out:
#         태그                                        링크 게시자 아이디 본문 내용 해시태그
# 0       감성  https://www.instagram.com/p/CjvNzS8vvMB/
# 1       감성  https://www.instagram.com/p/DBaX8STz2sf/
# 2       감성  https://www.instagram.com/p/DA0uUuESwOz/
# 3       감성  https://www.instagram.com/p/DAfAMV5TNKS/
# 4       감성  https://www.instagram.com/p/DAx1Xf2SQtm/
# ...     ..                                       ...     ...   ...  ...
# 106810  화장  https://www.instagram.com/p/CjiB3GEvEJM/
# 106811  화장  https://www.instagram.com/p/CYdo1OGJu55/
# 106812  화장  https://www.instagram.com/p/CYvaTvyLHOh/
# 106813  화장  https://www.instagram.com/p/CMNzqMiJS8V/
# 106814  화장  https://www.instagram.com/p/CjkFeJoLkeF/
#
# [106815 rows x 5 columns]

# %%
def insert_tag_row(idx, Oner_ID, MainText, hash_list):
    LinkDF.at[idx, '태그'] = LinkDF.iloc[idx]['태그']
    LinkDF.at[idx, '링크'] = LinkDF.iloc[idx]['링크']
    LinkDF.at[idx, '게시자 아이디'] = Oner_ID
    LinkDF.at[idx, '본문 내용'] = MainText
    LinkDF.at[idx, '해시태그'] = hash_list

# %%
text = 'x9f619 xjbqb8w x78zum5 x168nmei x13lgxp2 x5pf9jr xo71vjh x1uhb9sk x1plvlek xryxfnj x1c4vz4f x2lah0s xdt5ytf xqjyukv x1qjc9v5 x1oa3qoh x1nhvcw1' 
text = text.replace(" ",".")
text
# Out:
# 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'

# %%
comment_path =[
                # 전체댓글 Selector
                (By.CLASS_NAME, 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'),
            ]
for by, path in comment_path:
    try:
        comment = driver.find_elements(by, path)
        print(len(comment))
        print(comment[26].text.split("\n")[0])  # 이게 댓글 부분에서 계정주 아이디와 같다면 /// 26은 for문 돌려서 봐야할듯...
        break
    except:
        print("무언가 잘못되었다")
# comment_Oner = driver.find_elements(By.XPATH, '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[1]/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span')
# print("comment_Oner :", comment_Oner)
# comment_Oner
    for c in comment:
        com = c.find_element(By.CLASS_NAME, "_ap3a._aaco._aacw._aacx._aad7._aade")
        com = com.text
        print(com)

        if com == "iamkimbunny":
            plz_oner_com = com.find_element(By.CLASS_NAME, "x1lliihq.x1plvlek.xryxfnj.x1n2onr6.x1ji0vk5.x18bv5gf.x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.x1s928wv.xhkezso.x1gmr53x.x1cpjm7i.x1fgarty.x1943h6x.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgjd")
            plz_oner_com = plz_oner_com.text
            print(plz_oner_com.text)
# Out:
# 31
# iamkimbunny

# %%
# 보존용
# for idx, link in enumerate(list(LinkDF['링크'])): 
#     print(f"---------------------{idx}/{LinkDF['링크'].shape[0]}---------------------")
#     driver.get(link) # 1차 로그인 화면 
#     time.sleep(4)


#     # 스크롤할 부분 찾기
#     # 리스트화해서 사용하는 방법
#     # 클래스 네임 및 선택자 리스트 정의 // 와 여러개 모아서 보여두기는 좋은듯.
#     scroll_selectors = [
#     (By.CLASS_NAME, "_a9z6"),
#     (By.CLASS_NAME, "_a9z6._a9za"),
#     (By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6"),
#     (By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
#     (By.CSS_SELECTOR, "#mount_0_0_IQ > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 ...")
#     ]

#     scrollable_div = None
#     for by, selector in scroll_selectors:
#         try:
#             scrollable_div = driver.find_element(by, selector)
#             break
#         except:
#             pass

    
#     scroll_step, current_position = 300, 0  # 스크롤 픽셀 / 시작점 
    
#     # 스크롤 되는 부분
#     stop_point = False
#     while stop_point == False:
#         # 본문에 해시태그가 10개 이상 포함되어있으면 댓글 안보기
#         # urrent_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
#         # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
#         # 현재 위치에서 scroll_step만큼만 스크롤
        

#         # id 크롤링
#         try:
#             time.sleep(1)
#             Oner_ID = driver.find_element(By.CLASS_NAME,'x1i10hfl.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.xdl72j9.x2lah0s.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1q0g3np.x1lku1pv.x1a2a7pz.x6s0dn4.xjyslct.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x9f619.x1ypdohk.x1f6kntn.xwhw2v2.xl56j7k.x17ydfre.x2b8uid.xlyipyv.x87ps6o.x14atkfc.xcdnw81.x1i0vuye.xjbqb8w.xm3z3ea.x1x8b98j.x131883w.x16mih1h.x972fbf.xcfux6l.x1qhh985.xm0m39n.xt0psk2.xt7dq6l.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x1n5bzlp.xqnirrm.xj34u2y.x568u83')
#             Oner_ID = Oner_ID.text
#         except:
#             Oner_ID = None
#             print(f"{link[-10:]} 아이디 안댓음 도대체 왜 와이 어째서",end="\t")    # id의 댓글만 뽑아오기 용


#         hash_list = []

#         MainText_path = [
#         (By.CLASS_NAME, "_ap3a._aaco._aacu._aacx._aad7._aade"),
#         (By.CLASS_NAME, "x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.xt0psk2.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj"),
#         (By.CLASS_NAME, ""),
#         ]
#         # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
#         for by, path in MainText_path:
#             try:
#                 MainText = driver.find_element(by, path)
#                 break
#             except:               
#                 print(f"{MainText_path.index((by,path))}번, 본문 내용 크롤링에서 문제 발생")
#                 MainText = None
#         MainText = MainText.text
#         text_list = MainText.split()
#         for t in text_list:
#             if "#" in t:                # 본문에 해시태그가 있는 경우, 삭제 및 hash리스트에 빼서 넣어두기.
#                 MainText.replace(t,"")
#                 hash_list.append(t)
#         MainText = re.sub('[^가-힣]+',' ',MainText) # 영어 및 이모티콘 같은 글 삭제  
#         if len(MainText) < 30:
#             MainText = None # 전처리, 30자 이하라면 분석이 애매하니 삭제한다.
#             stop_point = True
#         else: 
#             pass
        
        

#         # 해시태그가 본문에 없다면, 댓글이나 대댓글에 있다.
#         if len(hash_list) < 5:  # 본문에 해시태그가 없어서 그 수가 적으면?
#             driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#             # 댓글에서 계정주 찾기
#             comment_Oner_path =[
#                 (By.CSS_SELECTOR, "#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(10) > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > span.x1lliihq.x1plvlek.xryxfnj.x1n2onr6.x1ji0vk5.x18bv5gf.x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.x1s928wv.xhkezso.x1gmr53x.x1cpjm7i.x1fgarty.x1943h6x.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj > span > div > a > div > div > span"),
#                 (By.XPATH, '//*[@id="mount_0_0_Nn"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[10]/div/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span'),
#                 (By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[10]/div/div/div[2]/div[1]/div[1]/div/div[1]/span[1]/span/div/a/div/div/span')
#             ]
#             for by, path in comment_Oner_path:
#                 try:
#                     comment_Oner = driver.find_elements(by, path)
#                 except:
#                     print(f"{MainText_path.index((by,path))}번, 댓글 크롤링에서 문제 발생")
#                 time.sleep(2)

#                 if comment_Oner[0].text == Oner_ID: # 계정주 == 댓글주 아이디 같으면?
#                     time.sleep(3)
#                     comment = driver.find_element(By.CSS_SELECTOR,"#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span")
#                     comment = comment.text  # 댓글 내용
#                     print("comment :", comment)
#                     if "#" in comment:
#                         comment_list = comment.split()
#                         for c in comment_list:
#                             if "#" in c:
#                                 hash_list.append(c)
#                         stop_point = True
#                     else:
#                         print("댓글 내부에는 해시태그 없음.")
#                         # 댓글에 해시태그가 없다면 대댓글 열어봐
#                         button_XPath = '//*[@id="mount_0_0_g7"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[13]/div[2]/div'
#                         buttons = driver.find_elements(By.XPATH,button_XPath)
#                         time.sleep(3)
#                         for button in buttons:
#                             button.send_keys(Keys.ENTER)
#                             time.sleep(2)
#                             # print(button)
#                             break
#                         # 댓글 열고 나서는 또 아래로 내려서 봐야함. 맨 밑에 있었다면 안보이니까.
#                         driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
#                         time.sleep(3)
#                         cocom_hash_selector = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > ul > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span"
#                         hash = driver.find_elements(By.CSS_SELECTOR,cocom_hash_selector)
#                         hash = hash.text
#                         for h in hash.split():
#                             hash_list.append(h)
#                         print("대댓글 해시태그",hash)
#                         stop_point = True
#                 break
#             except:
#                 stop_point = True
#                 pass
#         stop_point = True
    
#     print("Oner_ID :",Oner_ID)
#     print("MainText :",MainText)
#     print("hash_list :",hash_list)
#     print()
#     insert_tag_row(idx, Oner_ID, MainText, hash_list)
    
# LinkDF

# %%
for idx, link in enumerate(list(LinkDF['링크'])): 
    print(f"---------------------{idx}/{LinkDF['링크'].shape[0]}---------------------")
    driver.get(link) # 1차 로그인 화면 
    time.sleep(4)


    # 스크롤할 부분 찾기
    # 리스트화해서 사용하는 방법
    # 클래스 네임 및 선택자 리스트 정의 // 와 여러개 모아서 보여두기는 좋은듯.
    scroll_selectors = [
    (By.CLASS_NAME, "_a9z6"),
    (By.CLASS_NAME, "_a9z6._a9za"),
    (By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6"),
    (By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
    (By.CSS_SELECTOR, "#mount_0_0_IQ > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 ...")
    ]

    scrollable_div = None
    for by, selector in scroll_selectors:
        try:
            scrollable_div = driver.find_element(by, selector)
            break
        except:
            pass

    
    scroll_step, current_position = 300, 0  # 스크롤 픽셀 / 시작점 
    
    # 스크롤 되는 부분
    # 본문에 해시태그가 10개 이상 포함되어있으면 댓글 안보기
    # urrent_position < int(scrollable_div.get_attribute("scrollHeight")): # 전체 스크롤.
    # 근데 나는 id 발견되자마자 끝낼거니까 조건문 변경 필요.
    # 현재 위치에서 scroll_step만큼만 스크롤
        

    # id 크롤링
    try:
        time.sleep(1)
        Oner_ID = driver.find_element(By.CLASS_NAME,'x1i10hfl.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.xdl72j9.x2lah0s.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1q0g3np.x1lku1pv.x1a2a7pz.x6s0dn4.xjyslct.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x9f619.x1ypdohk.x1f6kntn.xwhw2v2.xl56j7k.x17ydfre.x2b8uid.xlyipyv.x87ps6o.x14atkfc.xcdnw81.x1i0vuye.xjbqb8w.xm3z3ea.x1x8b98j.x131883w.x16mih1h.x972fbf.xcfux6l.x1qhh985.xm0m39n.xt0psk2.xt7dq6l.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x1n5bzlp.xqnirrm.xj34u2y.x568u83')
        Oner_ID = Oner_ID.text
    except:
        Oner_ID = None
        print(f"{link[-10:]} 아이디 안댓음 도대체 왜 와이 어째서",end="\t")    # id의 댓글만 뽑아오기 용


    hash_list = []
    MainText_path = [
    (By.CLASS_NAME, "_ap3a._aaco._aacu._aacx._aad7._aade"),
    (By.CLASS_NAME, "x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.xt0psk2.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj"),
    (By.CLASS_NAME, ""),
    ]
    # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
    for by, path in MainText_path:
        try:
            MainText = driver.find_element(by, path)
            break
        except:               
            print(f"{MainText_path.index((by,path))}번, 본문 내용 크롤링에서 문제 발생")
            MainText = None
    MainText = MainText.text
    text_list = MainText.split()
    for t in text_list:
        if "#" in t:                # 본문에 해시태그가 있는 경우, 삭제 및 hash리스트에 빼서 넣어두기.
            MainText.replace(t,"")
            hash_list.append(t)
    MainText = re.sub('[^가-힣]+',' ',MainText) # 영어 및 이모티콘 같은 글 삭제  
    if len(MainText) < 30:
        MainText = None # 전처리, 30자 이하라면 분석이 애매하니 삭제한다.
        stop_point = True
    else: 
        pass
        

    stop_point = False
    while stop_point == False:
        # 해시태그가 본문에 없다면, 댓글이나 대댓글에 있다.
        if len(hash_list) < 5:  # 본문에 해시태그가 없어서 그 수가 적으면?
            driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)   # 스크롤 한번 하기.
            time.sleep(2)
            # 댓글에서 계정주 찾기
            # 전체댓글 Selector // [댓글작성자 아이디, 댓글 시간, 내용, 답글달기 이런식으로 나옴. 그게 리스트로 주루룩]
            comment_path = [
                (By.CLASS_NAME, 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'),
                ("a","b")
            ]
            for by, path in comment_path:
                try:
                    comments = driver.find_elements(by, path)   # 이게 댓글 부분에서 계정주 아이디와 같다면 /// 26은 for문 돌려서 봐야할듯...
                    break
                except:
                    print("무언가 잘못되었다")
            for com in comments:    # 댓글 전체 끌어옴
                # id [0]부분이 id 그게 게시글 주인 id와 같다면?
                if com.text.split("\n")[0] == Oner_ID:
                    CommentText = com.text.split("\n")[2]   # 댓글 내용인 2번을 가져온다.
                    if "#" in CommentText:  # 그 중에서도 만약 #가 있다면.
                        com_hash = CommentText.split("")    # 스플릿으로 나누고.
                        for h in com_hash:
                            if "#" in h:
                                hash_list.append(h) # 댓글 중에서도 "#" 있는 부분만 가져온다.
                        stop_point = True
                else:   # 그게 아니라면 댓글에도, 본문에도 해시태그가 없었던거니까 대댓글 찾아야지 .......
                    print("댓글 내부에는 해시태그 없음.")
                    # 댓글에 해시태그가 없다면 대댓글 열어봐
                    button_XPath = '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[1]/div[2]/div'
                    buttons = driver.find_elements(By.XPATH,button_XPath)
                    time.sleep(3)
                    for button in buttons:
                        button.send_keys(Keys.ENTER)
                        time.sleep(2)
                        # print(button)
                        break
                    # 댓글 열고 나서는 또 아래로 내려서 봐야함. 맨 밑에 있었다면 안보이니까.
                    driver.execute_script("arguments[0].scrollTop = arguments[0].scrollTop + arguments[1];", scrollable_div, scroll_step)
                    time.sleep(3)
                    cocom_hash_selector = "#mount_0_0_g7 > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(13) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > ul > div > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1cy8zhl.x1oa3qoh.x1nhvcw1 > span"
                    hash = driver.find_elements(By.CSS_SELECTOR,cocom_hash_selector)
                    hash = hash.text
                    for h in hash.split():
                        hash_list.append(h)
                    print("대댓글 해시태그",hash)
                    stop_point = True
                break
        stop_point = True
    
    print("Oner_ID :",Oner_ID)
    print("MainText :",MainText)
    print("hash_list :",hash_list)
    print()
    insert_tag_row(idx, Oner_ID, MainText, hash_list)
    
LinkDF

# %%
scroll_selectors
# Out:
# [('class name', '_a9z6'),
#  ('class name', '_a9z6._a9za'),
#  ('class name', 'x5yr21d.xw2csxc.x1odjw0f.x1n2onr6'),
#  ('xpath',
#   '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
#  ('xpath',
#   '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]')]

# %%
# 스크롤 확인 // 작동 확인 완료
# scroll_selectors = [
#     # (By.CLASS_NAME, "x5yr21d xw2csxc x1odjw0f x1n2onr6"),
#     (By.CLASS_NAME, "_a9z6._a9za"),
#     (By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6"),
#     (By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
#     (By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]'),
#     (By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6')
# ]

# scrollable_div = None
# for by, selector in scroll_selectors:
#     try:
#         scrollable_div = driver.find_element(by, selector)
#         break
#     except:
#         pass

# driver.execute_script("arguments[0].scrollTop += arguments[1];", scrollable_div, scroll_step)

# %%
hash_list = []
comments_path = [
(By.CLASS_NAME, 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'),
(By.XPATH, "/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[1]/div[1]/div/div[2]/div[1]/div[1]/div"),
(By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(1) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div')
]
# 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
for by, path in comments_path:
    try:
        comments = driver.find_elements(by, path)
        print("comments 일단 뭐라도 가져옴", comments[0].text, "예???")
        if (comments == [] or None) or (comments[0].text == [] or " "):
            print("엥")
            pass
        else:
            if com.text.split("\n")[0] == Oner_ID:
                CommentText = com.text.split("\n")[2]   # 댓글 내용인 2번을 가져온다.
                if "#" in CommentText:  # 그 중에서도 만약 #가 있다면.
                    com_hash = CommentText.split("")    # 스플릿으로 나누고.
                    for h in com_hash:
                        if "#" in h:
                            hash_list.append(h) # 댓글 중에서도 "#" 있는 부분만 가져온다.
        break
    except:               
        print("댓글 내부에는 해시태그 없음.")

print("\n아래요")
for com in comments:
    if com.text.split("\n")[0] == "iamkimbunny":
        if "#" in com.text.split("\n")[2]:
            print(com.text.split("\n"))

            text = com.text.split("\n")[2]
            for t in text.split(" "):
                if "#" in t:
                    hash_list.append(t)
    # print(com.text.split("\n")[2])    스크롤 하면서 있는 답글보기는 모두 눌러. 그리고 그걸 다 긁어서 
    # 위에 있는 코드처럼 하고 리스트로 뽑아서 이중에서 2번째에 # 태그 있는것만 골라 써 씨바름ㄴ이ㅏ릉ㄴㄹㅇㄴㄹㅇㄹㄹ
hash_list
# Out:
# comments 일단 뭐라도 가져옴  예???
# 엥
#
# 아래요
# ['iamkimbunny', ' 4주', '#글귀 #글스타그램 #글 #글귀스타그램 #시 #시스타그램 #감성 #공감 #공감글 #감성글 #사랑글 #감성글귀 #좋은글 #책 #책스타그램 #좋은글귀 #에세이 #사랑 #이별 #연인 #친구 #우정 #상처', '좋아요 1개', '답글 달기']
# ['iamkimbunny', ' 4주', '#글귀 #글스타그램 #글 #글귀스타그램 #시 #시스타그램 #감성 #공감 #공감글 #감성글 #사랑글 #감성글귀 #좋은글 #책 #책스타그램 #좋은글귀 #에세이 #사랑 #이별 #연인 #친구 #우정 #상처']
# ['#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처']

# %%
text = 'x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x87ps6o x1d5wrs8'
text = text.replace(" ",".")
text
# Out:
# 'x1i10hfl.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xt0psk2.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz.x87ps6o.x1d5wrs8'

# %%
scroll_selectors = [
    # (By.CLASS_NAME, "x5yr21d xw2csxc x1odjw0f x1n2onr6"),
    (By.CLASS_NAME, "_a9z6._a9za"),
    (By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6"),
    (By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
    (By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]'),
    (By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6')
]

scrollable_div = None
for by, selector in scroll_selectors:
    try:
        scrollable_div = driver.find_element(by, selector)
        break
    except:
        pass



stop_point = False
while stop_point == False:
    button_path = [
        (By.CLASS_NAME, 'x1i10hfl.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xt0psk2.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz.x87ps6o.x1d5wrs8'),
        (By.CSS_SELECTOR, '#mount_0_0_AB > div > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(6) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > div'),
        (By.XPATH, '//*[@id="mount_0_0_AB"]/div/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[6]/div[2]/div'),
        (By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[6]/div[2]/div')
    ]
    
    for by, path in button_path:
        buttons = driver.find_elements(by, path)
        if buttons:  # 버튼이 존재하는 경우
            for button in buttons:
                if button.is_displayed():  # 버튼이 화면에 표시되는지 확인
                    try:
                        button.click()  # 버튼 클릭
                        time.sleep(1.8)
                    except Exception as e:
                        print(f"버튼 클릭 오류: {e}")
                    break
            break

    time.sleep(1.5)
    driver.execute_script("arguments[0].scrollTop += arguments[1];", scrollable_div, 200)
    time.sleep(0.8)

    comments_path = [
    (By.CLASS_NAME, 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'),
    (By.XPATH, "/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[1]/div[1]/div/div[2]/div[1]/div[1]/div"),
    (By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(1) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div')
    ]
    # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
    for by, path in comments_path:
        try:
            comments = driver.find_elements(by, path)
            print("comments 일단 뭐라도 가져옴", comments[0].text, "예???")
            if (comments == [] or None) or (comments[0].text == [] or " "):
                print("엥")
                pass
            else:
                if com.text.split("\n")[0] == Oner_ID:
                    CommentText = com.text.split("\n")[2]   # 댓글 내용인 2번을 가져온다.
                    if "#" in CommentText:  # 그 중에서도 만약 #가 있다면.
                        com_hash = CommentText.split("")    # 스플릿으로 나누고.
                        for h in com_hash:
                            if "#" in h:
                                hash_list.append(h) # 댓글 중에서도 "#" 있는 부분만 가져온다.
            break
        except:               
            print("댓글 내부에는 해시태그 없음.")

    print("아래요")
    for com in comments:
        if com.text.split("\n")[0] == "sokmaeum_my":
            
            if "#" in com.text.split("\n")[2]:
                text = com.text.split("\n")[2]
                for t in text.split(" "):
                    if "#" in t:
                        hash_list.append(t)
        stop_point = True
        # print(com.text.split("\n")[2])    스크롤 하면서 있는 답글보기는 모두 눌러. 그리고 그걸 다 긁어서 
        # 위에 있는 코드처럼 하고 리스트로 뽑아서 이중에서 2번째에 # 태그 있는것만 골라 써 씨바름ㄴ이ㅏ릉ㄴㄹㅇㄴㄹㅇㄹㄹ
hash_list
# Out:
# comments 일단 뭐라도 가져옴  예???
# 엥
# 아래요
# ['#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처',
#  '#글귀',
#  '#글스타그램',
#  '#글',
#  '#글귀스타그램',
#  '#시',
#  '#시스타그램',
#  '#감성',
#  '#공감',
#  '#공감글',
#  '#감성글',
#  '#사랑글',
#  '#감성글귀',
#  '#좋은글',
#  '#책',
#  '#책스타그램',
#  '#좋은글귀',
#  '#에세이',
#  '#사랑',
#  '#이별',
#  '#연인',
#  '#친구',
#  '#우정',
#  '#상처']

# %%
LinkDF.iloc[2]['링크']
# Out:
# 'https://www.instagram.com/p/DA0uUuESwOz/'

# %%
# 보존용 
# 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
        # for by, path in comments_path:
        #     try:
        #         comments = driver.find_elements(by, path)
        #         # print("comments 일단 뭐라도 가져옴", comments[0].text, "예???")
        #         if (comments == [] or None) or (comments[0].text == [] or " "):
        #             # print("엥")
        #             pass
        #         else:
        #             if com.text.split("\n")[0] == Oner_ID:
        #                 CommentText = com.text.split("\n")[2]   # 댓글 내용인 2번을 가져온다.
        #                 if "#" in CommentText:  # 그 중에서도 만약 #가 있다면.
        #                     com_hash = CommentText.split("")    # 스플릿으로 나누고.
        #                     for h in com_hash:
        #                         if "#" in h:
        #                             hash_list.append(h) # 댓글 중에서도 "#" 있는 부분만 가져온다.
        #         break
        #     except:               
        #         print("댓글 내부에는 해시태그 없음.")

        # for com in comments:
        #     if com.text.split("\n")[0] == Oner_ID:    
        #         if "#" in com.text.split("\n")[2]:
        #             text = com.text.split("\n")[2]
        #             for t in text.split(" "):
        #                 if "#" in t:
        #                     hash_list.append(t)
        #             stop_point = True
        #     # print(com.text.split("\n")[2])    스크롤 하면서 있는 답글보기는 모두 눌러. 그리고 그걸 다 긁어서 
        #     # 위에 있는 코드처럼 하고 리스트로 뽑아서 이중에서 2번째에 # 태그 있는것만 골라 써 씨바름ㄴ이ㅏ릉ㄴㄹㅇㄴㄹㅇㄹㄹ

# %%
for idx, link in enumerate(list(LinkDF['링크'])):
    hash_list = []
    print(f"---------------------{idx}/{LinkDF['링크'].shape[0]}---------------------")
    driver.get(link) # 1차 로그인 화면 
    time.sleep(4)

    # id 크롤링
    try:
        time.sleep(1)
        Oner_ID = driver.find_element(By.CLASS_NAME,'x1i10hfl.xjqpnuy.xa49m3k.xqeqjp1.x2hbi6w.xdl72j9.x2lah0s.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.x2lwn1j.xeuugli.x1hl2dhg.xggy1nq.x1ja2u2z.x1t137rt.x1q0g3np.x1lku1pv.x1a2a7pz.x6s0dn4.xjyslct.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x9f619.x1ypdohk.x1f6kntn.xwhw2v2.xl56j7k.x17ydfre.x2b8uid.xlyipyv.x87ps6o.x14atkfc.xcdnw81.x1i0vuye.xjbqb8w.xm3z3ea.x1x8b98j.x131883w.x16mih1h.x972fbf.xcfux6l.x1qhh985.xm0m39n.xt0psk2.xt7dq6l.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x1n2onr6.x1n5bzlp.xqnirrm.xj34u2y.x568u83')
        Oner_ID = Oner_ID.text
    except:
        Oner_ID = None
        print(f"{link[-10:]} 아이디 안댓음 도대체 왜 와이 어째서",end="\t")    # id의 댓글만 뽑아오기 용
    print("Oner_ID :", Oner_ID)


    # 본문본문ㅇㄹ므나이릠ㄴㅇㄹㄴㅁㅇㄹㄴㅇㄹㅇㄹ
    MainText_path = [
    (By.CLASS_NAME, "_ap3a._aaco._aacu._aacx._aad7._aade"),
    (By.CLASS_NAME, "x193iq5w.xeuugli.x1fj9vlw.x13faqbe.x1vvkbs.xt0psk2.x1i0vuye.xvs91rp.xo1l8bm.x5n08af.x10wh9bi.x1wdrske.x8viiok.x18hxmgj"),
    (By.CSS_SELECTOR, "#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div > span > div > span"),
    (By.XPATH, "//*[@id='mount_0_0_Nn']/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/span"),
    (By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div[2]/div/span/div/span')
    ]
    # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
    for by, path in MainText_path:
        try:
            MainText = driver.find_element(by, path)
            break
        except:               
            print(f"{MainText_path.index((by,path))}번, 본문 내용 크롤링에서 문제 발생")
            MainText = None
    MainText = MainText.text
    text_list = MainText.split()
    for t in text_list:
        if "#" in t:                # 본문에 해시태그가 있는 경우, 삭제 및 hash리스트에 빼서 넣어두기.
            MainText.replace(t,"")
            hash_list.append(t)
    MainText = re.sub('[^가-힣]+',' ',MainText) # 영어 및 이모티콘 같은 글 삭제  
    if len(MainText) < 30:
        MainText = "30자 이하" # 전처리, 30자 이하라면 분석이 애매하니 삭제한다.
    else: 
        pass
    print("MainText :", MainText)

    if MainText == "30자 이하":
        continue
    

    # 스크롤 가능한 요소 찾기
    scroll_selectors = [
    # (By.CLASS_NAME, "x5yr21d xw2csxc x1odjw0f x1n2onr6"),
    (By.CLASS_NAME, "_a9z6._a9za"),
    (By.CLASS_NAME, "x5yr21d.xw2csxc.x1odjw0f.x1n2onr6"),
    (By.XPATH, '//*[@id="mount_0_0_IQ"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div[2]/div[1]/article/div/div[2]/div/div[2]/div[1]/ul'),
    (By.XPATH, '/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]'),
    (By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6')
    ]

    scrollable_div = None
    for by, selector in scroll_selectors:
        try:
            scrollable_div = driver.find_element(by, selector)
            break
        except:
            pass

    stop_point = False
    while len(hash_list) < 1:
        button_path = [
            (By.CLASS_NAME, 'x1i10hfl.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr.x17r0tee.x972fbf.xcfux6l.x1qhh985.xm0m39n.x9f619.x1ypdohk.xt0psk2.xe8uvvx.xdj266r.x11i5rnm.xat24cr.x1mh8g0r.xexx8yu.x4uap5.x18d9i69.xkhd6sd.x16tdsg8.x1hl2dhg.xggy1nq.x1a2a7pz.x87ps6o.x1d5wrs8'),
            (By.CSS_SELECTOR, '#mount_0_0_AB > div > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(6) > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1.x540dpk > div'),
            (By.XPATH, '//*[@id="mount_0_0_AB"]/div/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[6]/div[2]/div'),
            (By.XPATH, '/html/body/div[2]/div/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[6]/div[2]/div')
        ]
        
        for by, path in button_path:
            buttons = driver.find_elements(by, path)
            if buttons:  # 버튼이 존재하는 경우
                for button in buttons:
                    if button.is_displayed():  # 버튼이 화면에 표시되는지 확인
                        # 버튼 인식은 하는데 필요한 버튼이 2번째에 있으면 계속 1번째만 누르고 2번째 버튼 코앞까지 갔다가 1번으로 스크롤이 돌아옴.
                        try:
                            button.click()  # 버튼 클릭
                            time.sleep(1.8)
                            break
                        except Exception as e:
                            print(f"버튼 클릭 오류: {e}")
                    break
                      

        # time.sleep(1.5)
        # driver.execute_script("arguments[0].scrollTop += arguments[1];", scrollable_div, 400)
        # time.sleep(0.8)

        comments_path = [
        (By.CLASS_NAME, 'x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1'),
        (By.XPATH, "/html/body/div[2]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]/div/div[2]/div[1]/div[1]/div/div[2]/div[1]/div[1]/div"),
        (By.CSS_SELECTOR, '#mount_0_0_Nn > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.x9f619.xvbhtw8.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.x1gryazu.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x6s0dn4.x78zum5.xdt5ytf.xdj266r.xkrivgy.xat24cr.x1gryazu.x1n2onr6.xh8yej3 > div > div.x4h1yfo > div > div.x5yr21d.xw2csxc.x1odjw0f.x1n2onr6 > div > div.x78zum5.xdt5ytf.x1iyjqo2 > div:nth-child(1) > div:nth-child(1) > div > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div.x9f619.xjbqb8w.x78zum5.x168nmei.x13lgxp2.x5pf9jr.xo71vjh.x1uhb9sk.x1plvlek.xryxfnj.x1iyjqo2.x2lwn1j.xeuugli.xdt5ytf.xqjyukv.x1qjc9v5.x1oa3qoh.x1nhvcw1 > div:nth-child(1) > div')
        ]
        # 본문 내용 // Class : _ap3a _aaco _aacu _aacx _aad7 _aade\
        for by, path in comments_path:
            try:
                comments = driver.find_elements(by, path)
                # print("comments 일단 뭐라도 가져옴", comments[0].text, "예???")
                if (comments == [] or None) or (comments[0].text == [] or " "):
                    # print("엥")
                    pass
                else:
                    for com in comments:
                        if com.text.split("\n")[0] == Oner_ID:    
                            if "#" in com.text.split("\n")[2]:
                                text = com.text.split("\n")[2]
                                for t in text.split(" "):
                                    if "#" in t:
                                        hash_list.append(t)
            except:              
                print("댓글 내부에는 해시태그 없음.")
                continue
            # print(com.text.split("\n")[2])    스크롤 하면서 있는 답글보기는 모두 눌러. 그리고 그걸 다 긁어서 
            # 위에 있는 코드처럼 하고 리스트로 뽑아서 이중에서 2번째에 # 태그 있는것만 골라 써 씨바름ㄴ이ㅏ릉ㄴㄹㅇㄴㄹㅇㄹㄹ

    print("hash_list :", hash_list)
    print()
    time.sleep(2)
    
    insert_tag_row(idx, Oner_ID, MainText, hash_list)
# Out:
# ---------------------0/106815---------------------
# Oner_ID : musicdalin
# MainText :  내게 기대도 돼 내 사랑은 변함없을 거야 명곡 추억 팝송 사랑 연인 고백 가사해석 팝송추천 드라이브 플레이리스트 감성팝송 노래추천 감성 플리 커버 가사 노래
# hash_list : ['#명곡', '#추억', '#팝송', '#사랑', '#연인', '#고백', '#가사해석', '#팝송추천', '#드라이브', '#플레이리스트', '#감성팝송', '#노래추천', '#감성', '#플리', '#커버', '#가사', '#노래']
#
# ---------------------1/106815---------------------
# Oner_ID : dawn_365days
# MainText :  남친 여친 태그 사랑 관련글만 올립니다 팔로우 하시고 좋은글 받아보세요 사랑 연인 커플 연애 연애조언 사랑글 감성
# hash_list : ['#사랑', '#연인', '#커플', '#연애', '#연애조언', '#사랑글', '#감성']
#
# ---------------------2/106815---------------------
# Oner_ID : sokmaeum_my
# MainText : 30자 이하
# ---------------------3/106815---------------------
# Oner_ID : iamkimbunny
# MainText : 고작 한 번이었을 뿐인데 한 번 깨진 마음은 어찌할 도리가 없다
# 댓글 내부에는 해시태그 없음.
# 댓글 내부에는 해시태그 없음.

# %%
LinkDF
# Out:
#         태그                                        링크            게시자 아이디  \
# 0       감성  https://www.instagram.com/p/CjvNzS8vvMB/         musicdalin
# 1       감성  https://www.instagram.com/p/DBaX8STz2sf/       dawn_365days
# 2       감성  https://www.instagram.com/p/DA0uUuESwOz/        sokmaeum_my
# 3       감성  https://www.instagram.com/p/DAfAMV5TNKS/        iamkimbunny
# 4       감성  https://www.instagram.com/p/DAx1Xf2SQtm/  love.alone_always
# ...     ..                                       ...                ...
# 106810  화장  https://www.instagram.com/p/CjiB3GEvEJM/
# 106811  화장  https://www.instagram.com/p/CYdo1OGJu55/
# 106812  화장  https://www.instagram.com/p/CYvaTvyLHOh/
# 106813  화장  https://www.instagram.com/p/CMNzqMiJS8V/
# 106814  화장  https://www.instagram.com/p/CjkFeJoLkeF/
#
#                                                     본문 내용  \
# 0        내게 기대도 돼 내 사랑은 변함없을 거야 명곡 추억 팝송 사랑 연인 고백 가사해석...
# 1        남친 여친 태그 사랑 관련글만 올립니다 팔로우 하시고 좋은글 받아보세요 사랑 연인...
# 2                                                  30자 이하
# 3                    고작 한 번이었을 뿐인데 한 번 깨진 마음은 어찌할 도리가 없다
# 4                           못 잊게 하는 법 연애 감성 외사랑 외사랑관련밈 사랑
# ...                                                   ...
# 106810
# 106811
# 106812
# 106813
# 106814
#
#                                                      해시태그
# 0       [#명곡, #추억, #팝송, #사랑, #연인, #고백, #가사해석, #팝송추천, #...
# 1                  [#사랑, #연인, #커플, #연애, #연애조언, #사랑글, #감성]
# 2                                                      []
# 3                                                      []
# 4                          [#연애, #감성, #외사랑, #외사랑관련밈, #사랑]
# ...                                                   ...
# 106810
# 106811
# 106812
# 106813
# 106814
#
# [106815 rows x 5 columns]
