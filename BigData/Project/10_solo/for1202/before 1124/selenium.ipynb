# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# 로그인 관련 import 해옴. 참고한 블로그는 노션 인스타 로그인 문제 블로그 링크
from selenium.webdriver import ActionChains 
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By # HTML 요소를 찾아서 가져오고 싶을 때 쓰는 것

import pandas as pd

# %% [markdown]
# ###### By
# ID
# NAME
# XPATH
# LINK_TEXT
# TAG
#
# https://olivia-blackcherry.tistory.com/278

# %%
# 크롬 드라이버 경로 설정 (자신의 경로로 변경해야 함)
chrome_driver_path = "path_to_chromedriver"  # 크롬 드라이버 설치 경로 입력
service = Service(chrome_driver_path)

# 웹 드라이버 실행
driver = webdriver.Chrome()

# 영화 리뷰 url 리스트 로드

# %% [markdown]
# #### 크롤링 확인

# %%
#### find_element_by_css_selector 사용 불가능으로 실패
# # //*[@id="mount_0_0_Tx"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[1]/div[1]/div/a
# driver = webdriver.Chrome()
# url ="https://www.instagram.com"
# url_path = "/explore/search/keyword/?q=%23"
# tag = "흑백요리사"
# driver.get(url) # 1차 로그인 화면 
# time.sleep(3)
# # 02. 로그인
# #경로 지정
# id_box = driver.find_element_by_css_selector("#loginForm > div > div:nth-child(1) > div > label > input")   #아이디 입력창
# # # //*[@id="loginForm"]/div/div[1]/div/label/input
# password_box = driver.find_element_by_css_selector("#loginForm > div > div:nth-child(2) > div > label > input")     #비밀번호 입력창
# login_button = driver.find_element_by_css_selector('#loginForm > div > div:nth-child(3) > button')      #로그인 버튼

# # # #동작 제어
# act = ActionChains(driver)      #동작 명령어 지정
# act.send_keys_to_element(id_box, 'qlrwinds@gmail.com').send_keys_to_element(password_box, 'wpdlcl4411').click(login_button).perform()     #아이디 입력, 비밀 번호 입력, 로그인 버튼 클릭 수행
# time.sleep(2)

# text = driver.find_elements(By.CLASS_NAME, 'x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x4gyw5p _a6hd')
# text

# %%
driver = webdriver.Chrome()
url ="https://www.instagram.com"
url_path = "/explore/search/keyword/?q=%23"
tag = "흑백요리사"
driver.get(url+url_path+tag) # 1차 로그인 화면 
time.sleep(3)

# %% [markdown]
# #### 크롤링 순서
# 1. 인스타 태그별 url모음
# 2. url 마다 들어가서 게시글의 계정이름, 게시글,태그, 댓글or대댓글 - 계정주에 한하여 태그만 긁어오기.

# %% [markdown]
# ##### 1. 인스타 태그 url 긁어오기

# %% [markdown]
# https://www.instagram.com/explore/search/keyword/?q=%23대구
# https://www.instagram.com/explore/search/keyword/?q=%23맛집
# https://www.instagram.com/explore/search/keyword/?q=%23여행
# https://www.instagram.com/explore/search/keyword/?q=%23라이프
# https://www.instagram.com/explore/search/keyword/?q=%23일상
# https://www.instagram.com/explore/search/keyword/?q=%23취미
# https://www.instagram.com/explore/search/keyword/?q=%23사진
#
# 기본 https://www.instagram.com/explore/search/keyword/?q=%23
# + 해시태그

# %%
base_link = "https://www.instagram.com/explore/search/keyword/?q=%23"
tag_list = ["대구","맛집","여행","라이프","일상","취미","사진","스타일","공부","대학","카페","감성","추천","광고","다이어트","셀카","소통",
 "뷰티","강아지","고양이","산책","데일리","맞팔","패션","사랑","먹스타","지역"]

# %%
instaDF = pd.DataFrame(columns=["태그","링크"])
instaDF
# Out:
# Empty DataFrame
# Columns: [태그, 링크]
# Index: []

# %%
# driver = webdriver.Chrome()
# url ="https://www.instagram.com"
# url_path = "/explore/search/keyword/?q=%23"
# tag = "흑백요리사"
# driver.get(url+url_path+tag) # 1차 로그인 화면 
# time.sleep(3)

# %%
unb_tag ="x1i10hfl xjbqb8w x1ejq31n xd10rxx c x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x4gyw5p _a6hd"
# 아래 작은 박스들 // 위에는 upper3
"x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x4gyw5p _a6hd"
# Out:
# 'x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x4gyw5p _a6hd'

# %% [markdown]
# ##### 연습...? 테스트용

# %%
# # GPT ver 10.24 _ 00:34 
# # 나왔었는데 ...................................
# url = "https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC"
# driver.get(url)
# time.sleep(5)
# elements = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n")
# # "a.x1i10hfl.xjbqb8w") 원래 이거였음. 다만 다른 잡다한 링크가 너무 많이 나온다
# # elements
# # hrefs = [element.get_attribute("href") for element in elements[:3]]   # upper 3만 나오는거를 이제 p만 나오도록 걸러보자
# hrefs = []
# for element in elements:
#     tempele = element.get_attribute("href")
#     print(tempele)
#     if "/p/" in tempele:
#         hrefs.append(tempele)

# print(hrefs)

# # 공통점 : /p/가 들어간다.
# Out:
# https://www.instagram.com/p/DAiv33ZOt4u/
# https://www.instagram.com/p/DBLaCCeTbmY/
# https://www.instagram.com/p/DANtymWyHXf/
# https://www.instagram.com/p/DBU9C1bBSBU/
# https://www.instagram.com/p/DBGG2UayMfo/
# https://www.instagram.com/p/DAICYYsydHa/
# https://www.instagram.com/p/DAVhVoBPCPB/
# https://www.instagram.com/p/DA8DIzhv_-A/
# https://www.instagram.com/p/DApoU54J-PK/
# https://www.instagram.com/p/DAUmv5wSfND/
# https://www.instagram.com/p/DBDxJnZvhZU/
# https://www.instagram.com/p/DA78AYYSBHa/
# https://www.instagram.com/p/DAgN-3Vy9MO/
# https://www.instagram.com/p/DBJArHDzZWi/
# https://www.instagram.com/p/DAkxGljJFF4/
# https://www.instagram.com/p/DAREzM6Skk7/
# https://www.instagram.com/p/DArziN6TEYj/
# https://www.instagram.com/p/DA6Arv3TCuM/
# https://www.instagram.com/
# https://www.instagram.com/explore/
# https://www.instagram.com/reels/
# https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC#
# ...

# %%
# for h in hrefs:
#     print(h)
# Out:
# https://www.instagram.com/p/DAiv33ZOt4u/
# https://www.instagram.com/p/DBLaCCeTbmY/
# https://www.instagram.com/p/DANtymWyHXf/
# https://www.instagram.com/p/DBU9C1bBSBU/
# https://www.instagram.com/p/DBGG2UayMfo/
# https://www.instagram.com/p/DAICYYsydHa/
# https://www.instagram.com/p/DAVhVoBPCPB/
# https://www.instagram.com/p/DA8DIzhv_-A/
# https://www.instagram.com/p/DApoU54J-PK/
# https://www.instagram.com/p/DAUmv5wSfND/
# https://www.instagram.com/p/DBDxJnZvhZU/
# https://www.instagram.com/p/DA78AYYSBHa/
# https://www.instagram.com/p/DAgN-3Vy9MO/
# https://www.instagram.com/p/DBJArHDzZWi/
# https://www.instagram.com/p/DAkxGljJFF4/
# https://www.instagram.com/p/DAREzM6Skk7/
# https://www.instagram.com/p/DArziN6TEYj/
# https://www.instagram.com/p/DA6Arv3TCuM/

# %%
# url = "https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC"
# driver.get(url)
# time.sleep(5)
# elements = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n.xd10rxx.x1sy0etr")
# # "a.x1i10hfl.xjbqb8w") 원래 이거였음. 다만 다른 잡다한 링크가 너무 많이 나온다
# # elements
# hrefs = [element.get_attribute("href") for element in elements]
# Out:
# ['https://www.instagram.com/p/DAiv33ZOt4u/', 'https://www.instagram.com/p/DBLaCCeTbmY/', 'https://www.instagram.com/p/DANtymWyHXf/', 'https://www.instagram.com/p/DBU9C1bBSBU/', 'https://www.instagram.com/p/DBGG2UayMfo/', 'https://www.instagram.com/p/DAICYYsydHa/', 'https://www.instagram.com/p/DAVhVoBPCPB/', 'https://www.instagram.com/p/DA8DIzhv_-A/', 'https://www.instagram.com/p/DApoU54J-PK/', 'https://www.instagram.com/p/DAUmv5wSfND/', 'https://www.instagram.com/p/DBDxJnZvhZU/', 'https://www.instagram.com/p/DA78AYYSBHa/', 'https://www.instagram.com/p/DAgN-3Vy9MO/', 'https://www.instagram.com/p/DBJArHDzZWi/', 'https://www.instagram.com/p/DAkxGljJFF4/', 'https://www.instagram.com/p/DAREzM6Skk7/', 'https://www.instagram.com/p/DArziN6TEYj/', 'https://www.instagram.com/p/DA6Arv3TCuM/', 'https://www.instagram.com/', 'https://www.instagram.com/explore/', 'https://www.instagram.com/reels/', 'https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC
# ...

# %%
# for h in hrefs:
#     # print(h)
#     # print(type(h))
#     if "/p/" in h:
        
#         print("in h : ",h)
# Out:
# in h :  https://www.instagram.com/p/DAiv33ZOt4u/
# in h :  https://www.instagram.com/p/DBLaCCeTbmY/
# in h :  https://www.instagram.com/p/DANtymWyHXf/

# %%
# "/p/" in "https://www.instagram.com/p/DAiv33ZOt4u/"
# Out:
# True

# %%
# len(hrefs)
# Out:
# 24

# %%
# 아래 코드 None값 떠서 하는 테스트
# //*[@id="mount_0_0_uF"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[8]/div[3]/div/a
# link = driver.find_elements(By.CLASS_NAME, 'x1i10hfl xjbqb8w x1ejq31n xd10rxx x1sy0etr x17r0tee x972fbf xcfux6l x1qhh985 xm0m39n x9f619 x1ypdohk xt0psk2 xe8uvvx xdj266r x11i5rnm xat24cr x1mh8g0r xexx8yu x4uap5 x18d9i69 xkhd6sd x16tdsg8 x1hl2dhg xggy1nq x1a2a7pz x4gyw5p _a6hd')
# url = "https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC"
# driver.get(url)
# time.sleep(5)
# # link = driver.find_elements(By.XPATH, "//*[@id='mount_0_0_uF']/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[8]/div[3]/div/a")
# # link =  driver.find_elements(By.CLASS_NAME, unb_tag)
# # link =  driver.find_elements(By.PARTIAL_LINK_TEXT, "/p/")
# # link =  driver.find_element(By.CLASS_NAME, unb_tag)
# link = driver.find_element_by_css_selector("a.x1i10hfl.xjbqb8w")
# link

# %% [markdown]
# #### 자 본격적으로 드가자

# %%
# url = "https://www.instagram.com/explore/search/keyword/?q=%23%ED%9D%91%EB%B0%B1%EC%9A%94%EB%A6%AC%EC%82%AC"
# driver.get(url)
# time.sleep(5)
# elements = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n")
# # "a.x1i10hfl.xjbqb8w") 원래 이거였음. 다만 다른 잡다한 링크가 너무 많이 나온다
# # elements
# # hrefs = [element.get_attribute("href") for element in elements[:3]]   # upper 3만 나오는거를 이제 p만 나오도록 걸러보자
# hrefs = []
# for element in elements:
#     tempele = element.get_attribute("href")
#     print(tempele)
#     if "/p/" in tempele:
#         hrefs.append(tempele)

# print(hrefs)

# %%
first_result = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n")
for f in first_result[:1]:  # 여기서 하나씩 뽑아서? href가 포함되어있는 것만 한다.
    result_links = f.get_attribute("href")
    print(result_links)
# Out:
# https://www.instagram.com/p/C-wqSkrRn4S/

# %%
tag_list = ["대구","맛집","여행","라이프","일상","취미","사진","스타일","공부","대학","카페","감성","추천","광고","다이어트","셀카","소통",
 "뷰티","강아지","고양이","산책","데일리","맞팔","패션","사랑","먹스타","지역"]

# %%
tag_list[12]
# Out:
# '추천'

# %% [markdown]
# 큰 카테고리로 나눠서 우선...
# 광고,홍보 -
# 일상 -
# 동물 -
# 연애 - 데이터
# 여행 -
# 취미 -

# %%
base_link = "https://www.instagram.com/explore/search/keyword/?q=%23"
driver = webdriver.Chrome()

for tag in ['먹스타그램']:    # 일반 테스트로 태그 하나만 해본다. 1024 / 00:56
    insta_link_list = []
    # 태그서치 url
    url = base_link+tag
    driver.get(url)

    # 페이지 로딩 대기
    time.sleep(2.5)
    time.sleep(10) # 로그인 해야지

    for i in range(400):  # 원하는 만큼 스크롤 (숫자를 늘리면 더 많은 리뷰를 가져옴)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(4)

    # 리뷰 평점과 내용 크롤링
        # link = driver.find_elements(By.CLASS_NAME, unb_tag)
        first_result = driver.find_elements(By.CSS_SELECTOR, "a.x1i10hfl.xjbqb8w.x1ejq31n") # 처음에 온갖게 리스트 뭉탱이로 나오고
        for f in first_result:  # 여기서 하나씩 뽑아서? href가 포함되어있는 것만 한다.
            link = f.get_attribute("href")
            if "/p/" in link:
                insta_link_list.append({tag:link})
                # print(link, "link 갯수 : ",len(insta_link_list))
    # ratings = driver.find_elements(By.CLASS_NAME, 'aytsxOVO')  # 평점이 들어 있는 클래스 확인
    instaDF = pd.DataFrame(columns=["태그","링크"])

    idx = 0
    for i in insta_link_list:
        for k,v in i.items():
            instaDF.loc[idx] = [k,v]
            idx +=1

    instaDF.to_csv(f"{tag}태그.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 base_link = "https://www.instagram.com/explore/search/keyword/?q=%23"
# ----> 2 driver = webdriver.Chrome()
#       3 time.sleep(10) # 로그인 해야지
#       4 for tag in ['먹스타그램']:    # 일반 테스트로 태그 하나만 해본다. 1024 / 00:56
#
# File c:\Users\Doyeon\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# ...

# %%
tag
# Out:
# '감성'

# %%
insta_link_list


idx = 0
for i in insta_link_list:
    for k,v in i.items():
        instaDF.loc[idx] = [k,v]
        idx +=1

instaDF.to_csv(f"{tag}태그.csv")

# %%
insta_link_list
# Out:
# [{'대구': 'https://www.instagram.com/p/Cehe619vsRL/'},
#  {'대구': 'https://www.instagram.com/p/C-h1G8Fyikd/'},
#  {'대구': 'https://www.instagram.com/p/DBQihBMJ3Ql/'},
#  {'대구': 'https://www.instagram.com/p/DAbJPjFzct1/'},
#  {'대구': 'https://www.instagram.com/p/DARUw87hqYv/'},
#  {'대구': 'https://www.instagram.com/p/DAmW__tTU09/'},
#  {'대구': 'https://www.instagram.com/p/DA_Hklxy00h/'},
#  {'대구': 'https://www.instagram.com/p/DAcxiMxTpzi/'},
#  {'대구': 'https://www.instagram.com/p/DBEMp8jTTkC/'},
#  {'대구': 'https://www.instagram.com/p/DAfwacqv8BV/'},
#  {'대구': 'https://www.instagram.com/p/C99BXeopTRN/'},
#  {'대구': 'https://www.instagram.com/p/C-6uCNlJluA/'},
#  {'대구': 'https://www.instagram.com/p/DAh1WULTf4K/'},
#  {'대구': 'https://www.instagram.com/p/C-R89vuS79A/'},
#  {'대구': 'https://www.instagram.com/p/C-KD6R2PRjb/'},
#  {'대구': 'https://www.instagram.com/p/C-ETgyxS0oI/'},
#  {'대구': 'https://www.instagram.com/p/C-l7AjXyITt/'},
#  {'대구': 'https://www.instagram.com/p/C-CTO9byCQQ/'},
# ...

# %%
print(len(insta_link_list))
print(len(set(insta_link_list)))
# Out:
# 14985
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 print(len(insta_link_list))
# ----> 2 print(len(set(insta_link_list)))
#
# TypeError: unhashable type: 'dict'

# %%
for l in insta_link_list:
    l[0]
# Out:
# [{'대구': <selenium.webdriver.remote.webelement.WebElement (session="eabbdaf9f9536d8d4b84cc0951e6707c", element="f.8B59E4BCA1078095696EE37D3115B3DC.d.00A2B2933B1F9775D15CD617908466D4.e.49560")>}, {'대구': <selenium.webdriver.remote.webelement.WebElement (session="eabbdaf9f9536d8d4b84cc0951e6707c", element="f.8B59E4BCA1078095696EE37D3115B3DC.d.00A2B2933B1F9775D15CD617908466D4.e.49571")>}, {'대구': <selenium.webdriver.remote.webelement.WebElement (session="eabbdaf9f9536d8d4b84cc0951e6707c", element="f.8B59E4BCA1078095696EE37D3115B3DC.d.00A2B2933B1F9775D15CD617908466D4.e.49583")>}, {'대구': <selenium.webdriver.remote.webelement.WebElement (session="eabbdaf9f9536d8d4b84cc0951e6707c", element="f.8B59E4BCA1078095696EE37D3115B3DC.d.00A2B2933B1F9775D15CD617908466D4.e.49706")>}, {'대구': <selenium.webdriver.remote.webelement.WebElement (session="eabbdaf9f9536d8d4b84cc0951e6707c", element="f.8B59E4BCA1078095696EE37D3115B3DC.d.00A2B2933B1F9775D15CD617908466D4.e.49718")>}, {'대구': <selenium.webdriver.remot
# ...

# %%
# 중복 확인

DaeguDF = pd.read_csv("대구태그.csv")
print(len(DaeguDF))
DaeguDF = DaeguDF.drop_duplicates()
print(len(DaeguDF))
# Out:
# 14985
# 14985

# %%
url_list = movieDF['url']

for idx, url in enumerate(url_list):

    # Watcha 영화 리뷰 페이지로 이동
    driver.get(url)
    # url = 'https://pedia.watcha.com/ko-KR/contents/tEZAvmQ/comments'

    # 페이지 로딩 대기
    time.sleep(3)

    # 스크롤을 내려서 추가 리뷰를 로딩
    for i in range(300):  # 원하는 만큼 스크롤 (숫자를 늘리면 더 많은 리뷰를 가져옴)
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)

    # 리뷰 평점과 내용 크롤링
    reviews = driver.find_elements(By.CLASS_NAME, 'NrA8QHzP')  # 리뷰가 들어 있는 클래스 확인
    ratings = driver.find_elements(By.CLASS_NAME, 'aytsxOVO')  # 평점이 들어 있는 클래스 확인

    review_tot = []
    rating_tot = []

    # 리뷰와 평점을 출력
    for i in range(min(len(reviews), len(ratings))):
        review_text = reviews[i].text
        rating_score = ratings[i].text

        # 데이터 추가
        review_tot.append(review_text)
        rating_tot.append(rating_score)

        # 확인
        # print("=" * 50)
        # print("=" * 50)
        # print(f"평점: {rating_score}")
        # print("-"*50)
        # print(f"리뷰: {review_text}")
        # print("="*50)

        # # 로그 추가: 각 크롤링 데이터 확인
        # print(f"평점 {i+1}: {rating_score}")
        # print(f"리뷰 {i+1}: {review_text}")
        # print("=" * 50)

    # 저장
    DF_NAME = movieDF['title'][idx]
    tmpDF = pd.DataFrame({"review":review_tot,'rating':rating_tot})
    tmpDF.to_csv(f'./{DF_NAME}_review.csv', index=False, encoding='utf-8-sig')
    del tmpDF

# 드라이버 종료
driver.quit()
