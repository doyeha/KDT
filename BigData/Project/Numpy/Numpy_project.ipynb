# %% [markdown]
# #### 버섯버섯

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
Mush = pd.read_csv('Mushroom.csv')
Mush
# Out:
#      poison cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0         p         x           s         n       t    p               f
# 1         e         x           s         y       t    a               f
# 2         e         b           s         w       t    l               f
# 3         p         x           y         w       t    p               f
# 4         e         x           s         g       f    n               f
# ...     ...       ...         ...       ...     ...  ...             ...
# 8119      e         k           s         n       f    n               a
# 8120      e         x           s         n       f    n               a
# 8121      e         f           s         n       f    n               a
# 8122      p         k           y         n       f    y               f
# 8123      e         x           s         n       f    n               a
#
#      gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# ...

# %%
# 바꾸는 열 이름, 바꿀 텍스트, 바꾼 텍스트
def change(col, text, to_text):
    Mush[col] = Mush[col].replace(text, to_text)

# %%
# 버섯 칼럼 리스트
Mush_list = []
for i in list(Mush.columns):
    Mush_list.append(i)
print(Mush_list)
# Out:
# ['poison', 'cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor', 'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color', 'stalk_shape', 'stalk_root', 'stalk_surface_above_ring', 'stalk_surface_below_ring', 'stalk_color_above_ring', 'stalk_color_below_ring', 'veil_type', 'veil_color', 'ring_number', 'ring_type', 'spore_print_color', 'population', 'habitat']

# %%
Total_list = [
'poison=p,enable=e',
'bell=b,conical=c,convex=x,flat=f,knobbed=k,sunken=s',
'fibrous=f,grooves=g,scaly=y,smooth=s',
'brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y',
'bruises=t,no=f',

'almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s',

'attached=a,descending=d,free=f,notched=n',
'close=c,crowded=w,distant=d',
'broad=b,narrow=n',
'black=k,brown=n,buff=b,chocolate=h,gray=g,green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y',
'enlarging=e,tapering=t',
'bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?',
'fibrous=f,scaly=y,silky=k,smooth=s',
'fibrous=f,scaly=y,silky=k,smooth=s',
'brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y',
'brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y',
'partial=p,universal=u',
'brown=n,orange=o,white=w,yellow=y',
'none=n,one=o,two=t',
'cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z',
'black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y',
'abundant=a,clustered=c,numerous=n,nscattered=s,several=v,solitary=y',
'grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d'
]

# %%
# 하나씩 꺼내서 먼저 ,로 분류하고 그 다음에 스플릿 해서 좌우 오른쪽꺼를 왼쪽으로 바꾼다.
i = 0
for first in Total_list:
    Mu = Mush_list[i]
    first = first.split(',')
    print(first)
    for f in first:
        f = f.split('=')
        print(f)
        change(Mu, f[1], f[0])
    i += 1
# Out:
# ['poison=p', 'enable=e']
# ['poison', 'p']
# ['enable', 'e']
# ['bell=b', 'conical=c', 'convex=x', 'flat=f', 'knobbed=k', 'sunken=s']
# ['bell', 'b']
# ['conical', 'c']
# ['convex', 'x']
# ['flat', 'f']
# ['knobbed', 'k']
# ['sunken', 's']
# ['fibrous=f', 'grooves=g', 'scaly=y', 'smooth=s']
# ['fibrous', 'f']
# ['grooves', 'g']
# ['scaly', 'y']
# ['smooth', 's']
# ['brown=n', 'buff=b', 'cinnamon=c', 'gray=g', 'green=r', 'pink=p', 'purple=u', 'red=e', 'white=w', 'yellow=y']
# ['brown', 'n']
# ['buff', 'b']
# ['cinnamon', 'c']
# ['gray', 'g']
# ['green', 'r']
# ['pink', 'p']
# ['purple', 'u']
# ['red', 'e']
# ['white', 'w']
# ['yellow', 'y']
# ['bruises=t', 'no=f']
# ['bruises', 't']
# ['no', 'f']
# ['almond=a', 'anise=l', 'creosote=c', 'fishy=y', 'foul=f', 'musty=m', 'none=n', 'pungent=p', 'spicy=s']
# ['almond', 'a']
# ['anise', 'l']
# ['creosote', 'c']
# ['fishy', 'y']
# ['foul', 'f']
# ['musty', 'm']
# ['none', 'n']
# ['pungent', 'p']
# ['spicy', 's']
# ...

# %%
Mush
# Out:
#       poison cap_shape cap_surface cap_color  bruises     odor  \
# 0     poison    convex      smooth     brown  bruises  pungent
# 1     enable    convex      smooth    yellow  bruises   almond
# 2     enable      bell      smooth     white  bruises    anise
# 3     poison    convex       scaly     white  bruises  pungent
# 4     enable    convex      smooth      gray       no     none
# ...      ...       ...         ...       ...      ...      ...
# 8119  enable   knobbed      smooth     brown       no     none
# 8120  enable    convex      smooth     brown       no     none
# 8121  enable      flat      smooth     brown       no     none
# 8122  poison   knobbed       scaly     brown       no    fishy
# 8123  enable    convex      smooth     brown       no     none
#
#      gill_attachment gill_spacing gill_size gill_color  ...  \
# 0               free        close    narrow      black  ...
# 1               free        close     broad      black  ...
# ...

# %%
Mush.to_csv('Mushroom3.csv')

# %%
# change('poison','p','poison')
# change('poison','e','enable')

# %%
Mush
# Out:
#       poison cap_shape cap_surface cap_color  bruises     odor  \
# 0     poison    convex      smooth     brown  bruises  pungent
# 1     enable    convex      smooth    yellow  bruises   almond
# 2     enable      bell      smooth     white  bruises    anise
# 3     poison    convex       scaly     white  bruises  pungent
# 4     enable    convex      smooth      gray       no     none
# ...      ...       ...         ...       ...      ...      ...
# 8119  enable   knobbed      smooth     brown       no     none
# 8120  enable    convex      smooth     brown       no     none
# 8121  enable      flat      smooth     brown       no     none
# 8122  poison   knobbed       scaly     brown       no    fishy
# 8123  enable    convex      smooth     brown       no     none
#
#      gill_attachment gill_spacing gill_size gill_color  ...  \
# 0               free        close    narrow      black  ...
# 1               free        close     broad      black  ...
# ...
