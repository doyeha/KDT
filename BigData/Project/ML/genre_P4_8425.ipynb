# %%
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
VGgameDF = pd.read_csv('vgsales.csv')

# %%
VGgameDF
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# #### 데이터 전처리 - 결측치 제거

# %%
VGgameDF = VGgameDF.iloc[:,[2,4,5,6,7,8,10]]

# %%
VGgameDF.isnull().sum()
# Out:
# Platform         0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Global_Sales     0
# dtype: int64

# %%
len(VGgameDF[VGgameDF['Publisher'].isnull()].index.to_list())
# Out:
# 58

# %%
VGgameDF.drop(VGgameDF[VGgameDF['Publisher'].isnull()].index.to_list(), inplace=True)
VGgameDF.drop(VGgameDF[VGgameDF['Publisher']=='Unknown'].index.to_list(), inplace=True)
# Out:
# C:\Users\kjy19\AppData\Local\Temp\ipykernel_24204\1161423503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VGgameDF.drop(VGgameDF[VGgameDF['Publisher'].isnull()].index.to_list(), inplace=True)
# C:\Users\kjy19\AppData\Local\Temp\ipykernel_24204\1161423503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VGgameDF.drop(VGgameDF[VGgameDF['Publisher']=='Unknown'].index.to_list(), inplace=True)

# %%
VGgameDF
# Out:
#       Platform         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          Wii        Sports    Nintendo     41.49     29.02      3.77
# 1          NES      Platform    Nintendo     29.08      3.58      6.81
# 2          Wii        Racing    Nintendo     15.85     12.88      3.79
# 3          Wii        Sports    Nintendo     15.75     11.01      3.28
# 4           GB  Role-Playing    Nintendo     11.27      8.89     10.22
# ...        ...           ...         ...       ...       ...       ...
# 16593      GBA      Platform       Kemco      0.01      0.00      0.00
# 16594       GC       Shooter  Infogrames      0.01      0.00      0.00
# 16595      PS2        Racing  Activision      0.00      0.00      0.00
# 16596       DS        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      GBA      Platform     Wanadoo      0.01      0.00      0.00
#
#        Global_Sales
# 0             82.74
# 1             40.24
# 2             35.82
# 3             33.00
# 4             31.37
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [16337 rows x 7 columns]

# %%
for c in VGgameDF.columns[:2]:
    print(VGgameDF[c].unique())
    print()
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
#
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']

# %%
VGgameDF['Publisher'].isin(['Nintendo']).sum()  # isin 확인용
# Out:
# 703

# %% [markdown]
# #### 데이터 전처리 - 플랫폼 확인

# %%
print(len(VGgameDF['Platform'].unique()))   # 플랫폼 갯수 31개
(VGgameDF['Platform'].value_counts()> 10).value_counts()    # n개 이상의 게임을 배급한 플랫폼 의 수 식별
# Out:
# 31
# count
# True     25
# False     6
# Name: count, dtype: int64

# %%
VGgameDF['Platform'].value_counts().index
# Out:
# Index(['PS2', 'DS', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA', 'GC',
#        '3DS', 'PSV', 'PS4', 'N64', 'SNES', 'XOne', 'SAT', 'WiiU', '2600',
#        'NES', 'GB', 'DC', 'GEN', 'NG', 'SCD', 'WS', '3DO', 'TG16', 'GG',
#        'PCFX'],
#       dtype='object', name='Platform')

# %%
plt.figure(figsize=(20,8))
plt.bar(VGgameDF['Platform'].value_counts().index,VGgameDF['Platform'].value_counts())
plt.xlabel('플랫폼')
plt.ylabel('게임 수')
plt.title('플랫폼 별 배급된 게임 수')
# Out:
# Text(0.5, 1.0, '플랫폼 별 배급된 게임 수')

# %%
VGgameDF['Platform'].value_counts()
# Out:
# Platform
# PS2     2135
# DS      2123
# PS3     1311
# Wii     1298
# X360    1249
# PSP     1198
# PS      1189
# PC       932
# XB       812
# GBA      785
# GC       544
# 3DS      498
# PSV      405
# PS4      335
# N64      318
# SNES     239
# XOne     212
# SAT      173
# WiiU     143
# 2600     132
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: count, dtype: int64

# %%
a = pd.DataFrame((VGgameDF['Platform'].value_counts() > 200)==True)
Platform_list = a[a['count']==True].index.to_list()

# %%
tempDF = VGgameDF[VGgameDF['Platform'].isin(Platform_list)]
tempDF
# Out:
#       Platform     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          Wii    Sports    Nintendo     41.49     29.02      3.77
# 2          Wii    Racing    Nintendo     15.85     12.88      3.79
# 3          Wii    Sports    Nintendo     15.75     11.01      3.28
# 6           DS  Platform    Nintendo     11.38      9.23      6.50
# 7          Wii      Misc    Nintendo     14.03      9.20      2.93
# ...        ...       ...         ...       ...       ...       ...
# 16593      GBA  Platform       Kemco      0.01      0.00      0.00
# 16594       GC   Shooter  Infogrames      0.01      0.00      0.00
# 16595      PS2    Racing  Activision      0.00      0.00      0.00
# 16596       DS    Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      GBA  Platform     Wanadoo      0.01      0.00      0.00
#
#        Global_Sales
# 0             82.74
# 2             35.82
# 3             33.00
# 6             30.01
# 7             29.02
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [15583 rows x 7 columns]

# %%
len(Platform_list)
# Out:
# 17

# %% [markdown]
# #### 데이터 전처리 - 배급처 확인

# %%
tempDF
# Out:
#       Platform     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          Wii    Sports    Nintendo     41.49     29.02      3.77
# 2          Wii    Racing    Nintendo     15.85     12.88      3.79
# 3          Wii    Sports    Nintendo     15.75     11.01      3.28
# 6           DS  Platform    Nintendo     11.38      9.23      6.50
# 7          Wii      Misc    Nintendo     14.03      9.20      2.93
# ...        ...       ...         ...       ...       ...       ...
# 16593      GBA  Platform       Kemco      0.01      0.00      0.00
# 16594       GC   Shooter  Infogrames      0.01      0.00      0.00
# 16595      PS2    Racing  Activision      0.00      0.00      0.00
# 16596       DS    Puzzle    7G//AMES      0.00      0.01      0.00
# 16597      GBA  Platform     Wanadoo      0.01      0.00      0.00
#
#        Global_Sales
# 0             82.74
# 2             35.82
# 3             33.00
# 6             30.01
# 7             29.02
# ...             ...
# 16593          0.01
# 16594          0.01
# 16595          0.01
# 16596          0.01
# 16597          0.01
#
# [15583 rows x 7 columns]

# %%
len(tempDF['Platform'].unique())
# tempDF['Publisher'].unique()
# Out:
# 17

# %%
# tempDF['Platform'].value_counts() > 15

(tempDF['Publisher'].value_counts()> 15).value_counts()
# Out:
# count
# False    428
# True     108
# Name: count, dtype: int64

# %%
temp = pd.DataFrame((tempDF['Publisher'].value_counts() > 15))
Up_Pub_list = temp[temp['count']==True].index.to_list()

# %%
len(Up_Pub_list)
# Up_Pub_list
#
# Out:
# 108

# %%
GameDF = tempDF[tempDF['Publisher'].isin(Up_Pub_list)]

# %%
VGgameDF['Publisher'].value_counts() 
# VGgameDF['Publisher'][VGgameDF['Publisher']=='Nintendo'].count()
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: count, Length: 577, dtype: int64

# %% [markdown]
# #### Decision Tree

# %%
GameDF
# Out:
#       Platform       Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          Wii      Sports    Nintendo     41.49     29.02      3.77
# 2          Wii      Racing    Nintendo     15.85     12.88      3.79
# 3          Wii      Sports    Nintendo     15.75     11.01      3.28
# 6           DS    Platform    Nintendo     11.38      9.23      6.50
# 7          Wii        Misc    Nintendo     14.03      9.20      2.93
# ...        ...         ...         ...       ...       ...       ...
# 16591       PC   Adventure     Ubisoft      0.01      0.00      0.00
# 16592       DS  Simulation   Destineer      0.01      0.00      0.00
# 16593      GBA    Platform       Kemco      0.01      0.00      0.00
# 16594       GC     Shooter  Infogrames      0.01      0.00      0.00
# 16595      PS2      Racing  Activision      0.00      0.00      0.00
#
#        Global_Sales
# 0             82.74
# 2             35.82
# 3             33.00
# 6             30.01
# 7             29.02
# ...             ...
# 16591          0.01
# 16592          0.01
# 16593          0.01
# 16594          0.01
# 16595          0.01
#
# [14014 rows x 7 columns]

# %%
# 모듈로딩
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV

# %%
targetSR = GameDF['Genre']
featureDF = (GameDF.iloc[:,[0,2,3,4,5,6]])

# %%
# lencoder = LabelEncoder()
# lencoder.fit(targetDF)
# lencoder.transform(targetDF)
# targetSR = np.array(targetDF)

# %%
targetSR = pd.get_dummies(targetSR)

# %% [markdown]
# ##### 플랫폼, 장르 원핫

# %%
ohEncoder = OneHotEncoder()

# %%
featureDF = pd.get_dummies(featureDF)

# %%
# pla = np.array(featureDF['Platform']).reshape(-1,1)
# gen = np.array(featureDF['Genre']).reshape(-1,1)

# ohEncoder.fit(pla)
# ohEncoder.fit(gen)

# ohEncoder.transform(pla)
# ohEncoder.transform(gen)

# %%
featureDF
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Global_Sales  Platform_3DS  Platform_DS  \
# 0         41.49     29.02      3.77         82.74         False        False
# 2         15.85     12.88      3.79         35.82         False        False
# 3         15.75     11.01      3.28         33.00         False        False
# 6         11.38      9.23      6.50         30.01         False         True
# 7         14.03      9.20      2.93         29.02         False        False
# ...         ...       ...       ...           ...           ...          ...
# 16591      0.01      0.00      0.00          0.01         False        False
# 16592      0.01      0.00      0.00          0.01         False         True
# 16593      0.01      0.00      0.00          0.01         False        False
# 16594      0.01      0.00      0.00          0.01         False        False
# 16595      0.00      0.00      0.00          0.01         False        False
#
#        Platform_GBA  Platform_GC  Platform_N64  Platform_PC  ...  \
# 0             False        False         False        False  ...
# 2             False        False         False        False  ...
# 3             False        False         False        False  ...
# 6             False        False         False        False  ...
# 7             False        False         False        False  ...
# ...             ...          ...           ...          ...  ...
# 16591         False        False         False         True  ...
# 16592         False        False         False        False  ...
# 16593          True        False         False        False  ...
# 16594         False         True         False        False  ...
# 16595         False        False         False        False  ...
#
#        Publisher_Tomy Corporation  Publisher_UFO Interactive  \
# 0                           False                      False
# 2                           False                      False
# 3                           False                      False
# 6                           False                      False
# 7                           False                      False
# ...                           ...                        ...
# 16591                       False                      False
# 16592                       False                      False
# 16593                       False                      False
# 16594                       False                      False
# 16595                       False                      False
#
#        Publisher_Ubisoft  Publisher_Universal Interactive  \
# 0                  False                            False
# 2                  False                            False
# 3                  False                            False
# 6                  False                            False
# 7                  False                            False
# ...                  ...                              ...
# 16591               True                            False
# 16592              False                            False
# 16593              False                            False
# 16594              False                            False
# 16595              False                            False
#
#        Publisher_Virgin Interactive  Publisher_Vivendi Games  \
# 0                             False                    False
# 2                             False                    False
# 3                             False                    False
# 6                             False                    False
# 7                             False                    False
# ...                             ...                      ...
# 16591                         False                    False
# 16592                         False                    False
# 16593                         False                    False
# 16594                         False                    False
# 16595                         False                    False
#
#        Publisher_Warner Bros. Interactive Entertainment  \
# 0                                                 False
# 2                                                 False
# 3                                                 False
# 6                                                 False
# 7                                                 False
# ...                                                 ...
# 16591                                             False
# 16592                                             False
# 16593                                             False
# 16594                                             False
# 16595                                             False
#
#        Publisher_Zoo Digital Publishing  Publisher_Zoo Games  \
# 0                                 False                False
# 2                                 False                False
# 3                                 False                False
# 6                                 False                False
# 7                                 False                False
# ...                                 ...                  ...
# 16591                             False                False
# 16592                             False                False
# 16593                             False                False
# 16594                             False                False
# 16595                             False                False
#
#        Publisher_Zushi Games
# 0                      False
# 2                      False
# 3                      False
# 6                      False
# 7                      False
# ...                      ...
# 16591                  False
# 16592                  False
# 16593                  False
# 16594                  False
# 16595                  False
#
# [14014 rows x 129 columns]

# %%
print(f'featureDF - shape : {featureDF.shape}, ndim : {featureDF.ndim}')
print(f'targetSR - shape : {targetSR.shape}, ndim : {targetSR.ndim}')
# Out:
# featureDF - shape : (14014, 129), ndim : 2
# targetSR - shape : (14014, 12), ndim : 2

# %%
X_train, X_test, y_train, y_test = train_test_split(featureDF, targetSR, random_state=10, stratify=targetSR)

# %%
dt_model = DecisionTreeClassifier(random_state=10)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=10)

# %%
# print(f'[dt_model.classes_] {dt_model.classes_}')
print(f'[dt_model.n_classes_] {dt_model.n_classes_}')
print(f'[dt_model.max_features] {dt_model.max_features_}')
print(f'[dt_model.feature_names_in_] {dt_model.feature_names_in_}')
print(f'[dt_model.feature_importances_] {dt_model.feature_importances_}')
# Out:
# [dt_model.n_classes_] [2 2 2 2 2 2 2 2 2 2 2 2]
# [dt_model.max_features] 129
# [dt_model.feature_names_in_] ['NA_Sales' 'EU_Sales' 'JP_Sales' 'Global_Sales' 'Platform_3DS'
#  'Platform_DS' 'Platform_GBA' 'Platform_GC' 'Platform_N64' 'Platform_PC'
#  'Platform_PS' 'Platform_PS2' 'Platform_PS3' 'Platform_PS4' 'Platform_PSP'
#  'Platform_PSV' 'Platform_SNES' 'Platform_Wii' 'Platform_X360'
#  'Platform_XB' 'Platform_XOne' 'Publisher_3DO' 'Publisher_505 Games'
#  'Publisher_5pb' 'Publisher_ASCII Entertainment'
#  'Publisher_Acclaim Entertainment' 'Publisher_Activision'
#  'Publisher_Activision Value' 'Publisher_Alchemist' 'Publisher_Aqua Plus'
#  'Publisher_Arc System Works' 'Publisher_Atari' 'Publisher_Atlus'
#  'Publisher_Avanquest' 'Publisher_BAM! Entertainment'
#  'Publisher_Banpresto' 'Publisher_Bethesda Softworks'
#  'Publisher_Black Bean Games' 'Publisher_Broccoli' 'Publisher_Capcom'
#  'Publisher_ChunSoft' 'Publisher_City Interactive' 'Publisher_Codemasters'
#  'Publisher_Compile Heart' 'Publisher_Crave Entertainment'
#  'Publisher_D3Publisher' 'Publisher_DTP Entertainment'
#  'Publisher_Deep Silver' 'Publisher_Destineer'
#  'Publisher_Disney Interactive Studios'
#  'Publisher_DreamCatcher Interactive' 'Publisher_Eidos Interactive'
#  'Publisher_Electronic Arts' 'Publisher_Empire Interactive'
#  'Publisher_Enix Corporation' 'Publisher_Falcom Corporation'
#  'Publisher_Focus Home Interactive' 'Publisher_FuRyu' 'Publisher_GSP'
#  'Publisher_GT Interactive' 'Publisher_Game Factory'
#  'Publisher_Global Star' 'Publisher_Hasbro Interactive'
#  'Publisher_Hudson Soft' 'Publisher_Idea Factory'
#  'Publisher_Ignition Entertainment' 'Publisher_Infogrames'
#  'Publisher_Interplay' 'Publisher_Jaleco' 'Publisher_JoWood Productions'
#  'Publisher_Kadokawa Shoten' 'Publisher_Kalypso Media' 'Publisher_Kemco'
#  'Publisher_Koch Media' 'Publisher_Konami Digital Entertainment'
#  'Publisher_Level 5' 'Publisher_Little Orbit' 'Publisher_LucasArts'
#  'Publisher_MTV Games' 'Publisher_Majesco Entertainment'
#  'Publisher_Marvelous Interactive' 'Publisher_Mastiff'
#  'Publisher_Microsoft Game Studios'
#  'Publisher_Midas Interactive Entertainment' 'Publisher_Midway Games'
#  'Publisher_Milestone S.r.l.' 'Publisher_Mindscape'
#  'Publisher_Namco Bandai Games' 'Publisher_Natsume' 'Publisher_Nintendo'
#  'Publisher_Nippon Ichi Software' 'Publisher_Nordic Games'
#  'Publisher_O-Games' 'Publisher_Oxygen Interactive' 'Publisher_PQube'
#  'Publisher_Paradox Interactive' 'Publisher_Prototype'
#  'Publisher_Psygnosis' 'Publisher_Rising Star Games'
#  'Publisher_Rocket Company' 'Publisher_SCi' 'Publisher_SNK Playmore'
#  'Publisher_Sega' 'Publisher_Sony Computer Entertainment'
#  'Publisher_SouthPeak Games' 'Publisher_Spike' 'Publisher_Square Enix'
#  'Publisher_SquareSoft' 'Publisher_Storm City Games' 'Publisher_Success'
#  'Publisher_TDK Mediactive' 'Publisher_THQ' 'Publisher_Taito'
#  'Publisher_Takara' 'Publisher_Takara Tomy'
#  'Publisher_Take-Two Interactive' 'Publisher_Tecmo Koei'
#  'Publisher_Telltale Games' 'Publisher_Titus' 'Publisher_Tomy Corporation'
#  'Publisher_UFO Interactive' 'Publisher_Ubisoft'
#  'Publisher_Universal Interactive' 'Publisher_Virgin Interactive'
#  'Publisher_Vivendi Games'
#  'Publisher_Warner Bros. Interactive Entertainment'
#  'Publisher_Zoo Digital Publishing' 'Publisher_Zoo Games'
#  'Publisher_Zushi Games']
# [dt_model.feature_importances_] [0.1848366  0.13617336 0.06789582 0.22662169 0.00693257 0.01292654
#  0.00942922 0.00845759 0.00495251 0.00659467 0.01374178 0.01931548
#  0.01364759 0.00515302 0.01265832 0.00393561 0.00332643 0.00975906
#  0.0126561  0.0084788  0.00458425 0.00033975 0.00345171 0.00204408
#  0.0005994  0.00202872 0.00575296 0.00144413 0.00119151 0.00095382
#  0.00058708 0.00630701 0.00220568 0.00105601 0.00091098 0.00175055
#  0.00202913 0.00139599 0.00066375 0.00467247 0.00077956 0.00064817
#  0.00494006 0.00083417 0.00119372 0.00384092 0.00123449 0.00425926
#  0.00148429 0.00303126 0.0006207  0.00364306 0.01249254 0.00141699
#  0.00088992 0.00062096 0.00108357 0.00070855 0.00083458 0.00046576
#  0.00065237 0.00045712 0.00071112 0.00251779 0.00254547 0.00152532
#  0.00174783 0.00091829 0.00070183 0.00141269 0.00193196 0.0009416
#  0.00058648 0.00075099 0.01088913 0.0009049  0.00095065 0.00136883
#  0.00361099 0.00237505 0.00140654 0.00092778 0.00287485 0.00075438
#  0.00181205 0.00139119 0.00109013 0.00634452 0.00066551 0.00633389
#  0.00272552 0.00132333 0.00101037 0.00099726 0.0014765  0.00041431
#  0.00177022 0.00093847 0.00295053 0.00074559 0.00058429 0.0010458
#  0.00767053 0.00655401 0.00172367 0.00161577 0.00543062 0.00153112
#  0.00076338 0.00092788 0.0007685  0.00599616 0.00079238 0.00081828
#  0.00090097 0.00530847 0.00349866 0.00146845 0.00080171 0.00041548
#  0.00055703 0.00697303 0.00042194 0.00170955 0.00170943 0.00507903
#  0.0017623  0.00073394 0.00049996]

# %%
train_score = dt_model.score(X_train, y_train)
test_score = dt_model.score(X_test, y_test)
print(f'train_score : test_score = {train_score:.4f} : {test_score:.4f}')
# Out:
# train_score : test_score = 0.8445 : 0.2597

# %% [markdown]
# ###### 트리 그림

# %%
params = {'max_depth':[12,9,4,3],
       'min_samples_leaf' : [5,3,2]}

gscv=GridSearchCV(DecisionTreeClassifier(), 
                  param_grid=params, 
                  refit=True, 
                  return_train_score=True)
gscv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [12, 9, 4, 3],
#                          'min_samples_leaf': [5, 3, 2]},
#              return_train_score=True)

# %%
print(f'[gscv.best_params_] {gscv.best_params_}')
print(f'[gscv.best_score_] {gscv.best_score_}')
print(f'[gscv.best_estimator_] {gscv.best_estimator_}')
# print(f'[gscv.cv_results_] {gscv.cv_results_}')

cv_resultDF = pd.DataFrame(gscv.cv_results_)

best_model = gscv.best_estimator_
print(f'[best_model.max_depth] : {best_model.max_depth}')
print(f'[best_model.min_samples_leaf] : {best_model.min_samples_leaf}')
# Out:
# [gscv.best_params_] {'max_depth': 12, 'min_samples_leaf': 3}
# [gscv.best_score_] 0.1021883920076118
# [gscv.best_estimator_] DecisionTreeClassifier(max_depth=12, min_samples_leaf=3)
# [best_model.max_depth] : 12
# [best_model.min_samples_leaf] : 3

# %%
from sklearn.tree import export_graphviz
export_graphviz(best_model, out_file = 'tree.dot',
                feature_names=best_model.feature_names_in_,
                impurity=True, filled=True, rounded=True)

# %%
import graphviz
with open('tree.dot') as f:
    dot_data = f.read()

graphviz.Source(dot_data)
