# %% [markdown]
# ### Ensenble - RandomForest & ExtraTree
#  - 배깅 방식의 앙상블 ==> 중복을 허용한 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : RandomForestC/R :
#  - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델 (DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
#  [목표] 와인 분류 => 0과 1 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
DATA_FILE = '../data/wine.csv'

# CSV >> DataFrame 
wineDF = pd.read_csv(DATA_FILE)

# %%
# 데이터 확인
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head(2)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0

# %%
# 타겟/라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
featureDF = wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}, targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3), targetSR : (6497,)

# %%
# 학습용 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF,
                                                    targetSR,
                                                    test_size=0.2,
                                                    stratify=targetSR,
                                                    random_state=1
                                                    )

# %%
print(f'X_train : {X_train.shape} y_train : {y_train}')
print(f'X_test : {X_test.shape} y_trest : {y_test}')
# Out:
# X_train : (5197, 3) y_train : 6378    1.0
# 3069    1.0
# 4986    1.0
# 993     0.0
# 4988    1.0
#        ...
# 453     0.0
# 1460    0.0
# 5755    1.0
# 6299    1.0
# 3369    1.0
# Name: class, Length: 5197, dtype: float64
# X_test : (1300, 3) y_trest : 1002    0.0
# 2345    1.0
# 79      0.0
# 4208    1.0
# 2092    1.0
#        ...
# 4179    1.0
# 2803    1.0
# 6454    1.0
# 5451    1.0
# 1360    0.0
# Name: class, Length: 1300, dtype: float64

# %% [markdown]
# [3] 학습진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                random_state 매개변수 설정으로 고정된 데이터셋 생성
#                oob_score 배개변ㅇ수 ㅣ 샘플 데이터셋 추출 휴ㅜ 남은 데이터셋 검즈용ㅇ으로 사용
lf_model = RandomForestClassifier(random_state=7. oob_Score = True)

# 학습
lf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=7)

# %%
# 모델 파라미터
print(f'classes_ : {lf_model.classes_}')
print(f'n_classes_ : {lf_model.n_classes_}')
print()
print(f'feature_names_in_ : {lf_model.feature_names_in_}')
print(f'n_features_in_ : {lf_model.n_features_in_}')
print(f'feature_importances_ : {lf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2
#
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3
# feature_importances_ : [0.23572103 0.49995154 0.26432743]

# %%
# 모델 파라미터
print(f'clases_         : {lf_model.estimator__}')

for est in lf_model.estimators_: print(est.samples_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 모델 파라미터
# ----> 2 print(f'clases_         : {lf_model.estimators__}')
#       4 for est in lf_model.estimators_: print(est.samples_)
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'estimators__'

# %%
# 모델 파라미터
print(f'clases_         : {lf_model.classes_}')

for est in lf_model.estimators_: print(est)

# %%
print(f'clases_         : {lf_model.classes_}')

for est in lf_model.estimators_: print(est)

# %% [markdown]
# [4] 성능평가

# %%
train_score = lf_model.score(X_train, y_train)
test_score = lf_model.score(X_test, y_test)

# %%
print(f'oob_score : {lf_model.oob_score_}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print(f'oob_score : {lf_model.oob_score_}')
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'oob_score_'

# %% [markdown]
# [5] 튜닝
#  - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼파라미터를 추출항 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 
params = {'max_depth' : range(2,16),
          'min_samples_leaf' : range(5,16),
          'criterion' : ['gini', 'entropy', 'log_loss']
          }

# %%
rf_model = RandomForestClassifier(random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model, param_distributions=params, n_iter = 50, verbose=4)
# verbose

# %%
# searchCV.best_params_

searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END ...max_depth=3, min_samples_leaf=8;, score=0.805 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=8;, score=0.821 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=8;, score=0.835 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=8;, score=0.843 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=8;, score=0.825 total time=   0.1s
# [CV 1/5] END .max_depth=10, min_samples_leaf=11;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=10, min_samples_leaf=11;, score=0.838 total time=   0.3s
# [CV 3/5] END .max_depth=10, min_samples_leaf=11;, score=0.880 total time=   0.2s
# [CV 4/5] END .max_depth=10, min_samples_leaf=11;, score=0.882 total time=   0.2s
# [CV 5/5] END .max_depth=10, min_samples_leaf=11;, score=0.869 total time=   0.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=12;, score=0.869 total time=   0.2s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=12;, score=0.838 total time=   0.2s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=12;, score=0.876 total time=   0.2s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=12;, score=0.875 total time=   0.3s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=12;, score=0.866 total time=   0.2s
# [CV 1/5] END ...max_depth=3, min_samples_leaf=6;, score=0.804 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=6;, score=0.821 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=6;, score=0.835 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=6;, score=0.843 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=6;, score=0.825 total time=   0.1s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=5;, score=0.880 total time=   0.3s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=5;, score=0.850 total time=   0.2s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=5;, score=0.885 total time=   0.3s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=5;, score=0.883 total time=   0.3s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=5;, score=0.877 total time=   0.3s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=5;, score=0.854 total time=   0.2s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=5;, score=0.834 total time=   0.2s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=5;, score=0.868 total time=   0.2s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=5;, score=0.873 total time=   0.2s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=5;, score=0.854 total time=   0.2s
# [CV 1/5] END .max_depth=13, min_samples_leaf=12;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=13, min_samples_leaf=12;, score=0.837 total time=   0.2s
# [CV 3/5] END .max_depth=13, min_samples_leaf=12;, score=0.882 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=12;, score=0.882 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=12;, score=0.870 total time=   0.2s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=13;, score=0.867 total time=   0.2s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=13;, score=0.836 total time=   0.2s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=13;, score=0.876 total time=   0.2s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=13;, score=0.879 total time=   0.2s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=13;, score=0.863 total time=   0.2s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=11;, score=0.866 total time=   0.2s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=11;, score=0.837 total time=   0.2s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=11;, score=0.877 total time=   0.2s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=11;, score=0.874 total time=   0.2s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=11;, score=0.863 total time=   0.2s
# [CV 1/5] END ..max_depth=13, min_samples_leaf=4;, score=0.883 total time=   0.3s
# [CV 2/5] END ..max_depth=13, min_samples_leaf=4;, score=0.848 total time=   0.3s
# [CV 3/5] END ..max_depth=13, min_samples_leaf=4;, score=0.883 total time=   0.3s
# [CV 4/5] END ..max_depth=13, min_samples_leaf=4;, score=0.888 total time=   0.3s
# [CV 5/5] END ..max_depth=13, min_samples_leaf=4;, score=0.875 total time=   0.3s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=6;, score=0.885 total time=   0.3s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=6;, score=0.843 total time=   0.2s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=6;, score=0.878 total time=   0.3s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=6;, score=0.889 total time=   0.3s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=6;, score=0.876 total time=   0.3s
# [CV 1/5] END ...max_depth=9, min_samples_leaf=7;, score=0.881 total time=   0.2s
# [CV 2/5] END ...max_depth=9, min_samples_leaf=7;, score=0.838 total time=   0.2s
# [CV 3/5] END ...max_depth=9, min_samples_leaf=7;, score=0.877 total time=   0.3s
# [CV 4/5] END ...max_depth=9, min_samples_leaf=7;, score=0.883 total time=   0.2s
# [CV 5/5] END ...max_depth=9, min_samples_leaf=7;, score=0.873 total time=   0.2s
# [CV 1/5] END .max_depth=11, min_samples_leaf=10;, score=0.872 total time=   0.2s
# [CV 2/5] END .max_depth=11, min_samples_leaf=10;, score=0.840 total time=   0.2s
# [CV 3/5] END .max_depth=11, min_samples_leaf=10;, score=0.883 total time=   0.2s
# [CV 4/5] END .max_depth=11, min_samples_leaf=10;, score=0.887 total time=   0.3s
# [CV 5/5] END .max_depth=11, min_samples_leaf=10;, score=0.875 total time=   0.2s
# [CV 1/5] END .max_depth=12, min_samples_leaf=14;, score=0.870 total time=   0.2s
# [CV 2/5] END .max_depth=12, min_samples_leaf=14;, score=0.833 total time=   0.2s
# [CV 3/5] END .max_depth=12, min_samples_leaf=14;, score=0.875 total time=   0.2s
# [CV 4/5] END .max_depth=12, min_samples_leaf=14;, score=0.882 total time=   0.2s
# [CV 5/5] END .max_depth=12, min_samples_leaf=14;, score=0.870 total time=   0.2s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=7;, score=0.854 total time=   0.2s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=7;, score=0.836 total time=   0.2s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=7;, score=0.867 total time=   0.2s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=7;, score=0.874 total time=   0.2s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=7;, score=0.853 total time=   0.2s
# [CV 1/5] END ..max_depth=10, min_samples_leaf=3;, score=0.885 total time=   0.3s
# [CV 2/5] END ..max_depth=10, min_samples_leaf=3;, score=0.847 total time=   0.3s
# [CV 3/5] END ..max_depth=10, min_samples_leaf=3;, score=0.882 total time=   0.3s
# [CV 4/5] END ..max_depth=10, min_samples_leaf=3;, score=0.886 total time=   0.3s
# [CV 5/5] END ..max_depth=10, min_samples_leaf=3;, score=0.880 total time=   0.3s
# [CV 1/5] END ...max_depth=6, min_samples_leaf=5;, score=0.863 total time=   0.2s
# [CV 2/5] END ...max_depth=6, min_samples_leaf=5;, score=0.834 total time=   0.2s
# [CV 3/5] END ...max_depth=6, min_samples_leaf=5;, score=0.874 total time=   0.2s
# [CV 4/5] END ...max_depth=6, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 5/5] END ...max_depth=6, min_samples_leaf=5;, score=0.860 total time=   0.2s
# [CV 1/5] END .max_depth=15, min_samples_leaf=15;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=15, min_samples_leaf=15;, score=0.836 total time=   0.2s
# [CV 3/5] END .max_depth=15, min_samples_leaf=15;, score=0.882 total time=   0.2s
# [CV 4/5] END .max_depth=15, min_samples_leaf=15;, score=0.880 total time=   0.3s
# [CV 5/5] END .max_depth=15, min_samples_leaf=15;, score=0.872 total time=   0.3s
# [CV 1/5] END ..max_depth=12, min_samples_leaf=3;, score=0.887 total time=   0.3s
# [CV 2/5] END ..max_depth=12, min_samples_leaf=3;, score=0.850 total time=   0.3s
# [CV 3/5] END ..max_depth=12, min_samples_leaf=3;, score=0.884 total time=   0.3s
# [CV 4/5] END ..max_depth=12, min_samples_leaf=3;, score=0.889 total time=   0.3s
# [CV 5/5] END ..max_depth=12, min_samples_leaf=3;, score=0.879 total time=   0.3s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=6;, score=0.756 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=6;, score=0.767 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=6;, score=0.771 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.1s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.1s
# [CV 1/5] END ...max_depth=4, min_samples_leaf=7;, score=0.840 total time=   0.2s
# [CV 2/5] END ...max_depth=4, min_samples_leaf=7;, score=0.836 total time=   0.2s
# [CV 3/5] END ...max_depth=4, min_samples_leaf=7;, score=0.860 total time=   0.1s
# [CV 4/5] END ...max_depth=4, min_samples_leaf=7;, score=0.861 total time=   0.2s
# [CV 5/5] END ...max_depth=4, min_samples_leaf=7;, score=0.845 total time=   0.1s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=5;, score=0.756 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=5;, score=0.767 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=5;, score=0.771 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.1s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=5;, score=0.754 total time=   0.1s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=15;, score=0.838 total time=   0.2s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=15;, score=0.880 total time=   0.2s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=15;, score=0.881 total time=   0.3s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=15;, score=0.871 total time=   0.3s
# [CV 1/5] END ...max_depth=8, min_samples_leaf=4;, score=0.874 total time=   0.2s
# [CV 2/5] END ...max_depth=8, min_samples_leaf=4;, score=0.840 total time=   0.2s
# [CV 3/5] END ...max_depth=8, min_samples_leaf=4;, score=0.877 total time=   0.2s
# [CV 4/5] END ...max_depth=8, min_samples_leaf=4;, score=0.877 total time=   0.2s
# [CV 5/5] END ...max_depth=8, min_samples_leaf=4;, score=0.872 total time=   0.2s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=4;, score=0.756 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=4;, score=0.767 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=4;, score=0.771 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=4;, score=0.754 total time=   0.1s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=4;, score=0.754 total time=   0.1s
# [CV 1/5] END .max_depth=13, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 2/5] END .max_depth=13, min_samples_leaf=15;, score=0.838 total time=   0.2s
# [CV 3/5] END .max_depth=13, min_samples_leaf=15;, score=0.881 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=15;, score=0.878 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=15;, score=0.871 total time=   0.2s
# [CV 1/5] END .max_depth=10, min_samples_leaf=15;, score=0.869 total time=   0.2s
# [CV 2/5] END .max_depth=10, min_samples_leaf=15;, score=0.837 total time=   0.2s
# [CV 3/5] END .max_depth=10, min_samples_leaf=15;, score=0.881 total time=   0.2s
# [CV 4/5] END .max_depth=10, min_samples_leaf=15;, score=0.883 total time=   0.2s
# [CV 5/5] END .max_depth=10, min_samples_leaf=15;, score=0.867 total time=   0.2s
# [CV 1/5] END ...max_depth=6, min_samples_leaf=3;, score=0.860 total time=   0.2s
# [CV 2/5] END ...max_depth=6, min_samples_leaf=3;, score=0.835 total time=   0.2s
# [CV 3/5] END ...max_depth=6, min_samples_leaf=3;, score=0.875 total time=   0.2s
# [CV 4/5] END ...max_depth=6, min_samples_leaf=3;, score=0.877 total time=   0.2s
# [CV 5/5] END ...max_depth=6, min_samples_leaf=3;, score=0.859 total time=   0.2s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=10;, score=0.855 total time=   0.2s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=10;, score=0.828 total time=   0.2s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=10;, score=0.865 total time=   0.2s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=10;, score=0.875 total time=   0.2s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=10;, score=0.852 total time=   0.2s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=4;, score=0.853 total time=   0.2s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=4;, score=0.834 total time=   0.2s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=4;, score=0.869 total time=   0.2s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=4;, score=0.876 total time=   0.2s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=4;, score=0.853 total time=   0.1s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=7;, score=0.756 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=7;, score=0.767 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=7;, score=0.771 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.1s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=7;, score=0.754 total time=   0.1s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=13;, score=0.804 total time=   0.1s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=13;, score=0.819 total time=   0.1s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=13;, score=0.837 total time=   0.1s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=13;, score=0.845 total time=   0.1s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=13;, score=0.825 total time=   0.1s
# [CV 1/5] END ...max_depth=4, min_samples_leaf=8;, score=0.839 total time=   0.1s
# [CV 2/5] END ...max_depth=4, min_samples_leaf=8;, score=0.837 total time=   0.1s
# [CV 3/5] END ...max_depth=4, min_samples_leaf=8;, score=0.859 total time=   0.2s
# [CV 4/5] END ...max_depth=4, min_samples_leaf=8;, score=0.860 total time=   0.1s
# [CV 5/5] END ...max_depth=4, min_samples_leaf=8;, score=0.843 total time=   0.2s
# [CV 1/5] END .max_depth=13, min_samples_leaf=13;, score=0.872 total time=   0.3s
# [CV 2/5] END .max_depth=13, min_samples_leaf=13;, score=0.833 total time=   0.3s
# [CV 3/5] END .max_depth=13, min_samples_leaf=13;, score=0.873 total time=   0.2s
# [CV 4/5] END .max_depth=13, min_samples_leaf=13;, score=0.881 total time=   0.2s
# [CV 5/5] END .max_depth=13, min_samples_leaf=13;, score=0.871 total time=   0.2s
# [CV 1/5] END ...max_depth=2, min_samples_leaf=8;, score=0.756 total time=   0.1s
# [CV 2/5] END ...max_depth=2, min_samples_leaf=8;, score=0.767 total time=   0.1s
# [CV 3/5] END ...max_depth=2, min_samples_leaf=8;, score=0.771 total time=   0.1s
# [CV 4/5] END ...max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 5/5] END ...max_depth=2, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=4;, score=0.882 total time=   0.3s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=4;, score=0.856 total time=   0.3s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=4;, score=0.882 total time=   0.3s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=4;, score=0.888 total time=   0.3s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=4;, score=0.882 total time=   0.3s
# [CV 1/5] END ...max_depth=3, min_samples_leaf=5;, score=0.805 total time=   0.1s
# [CV 2/5] END ...max_depth=3, min_samples_leaf=5;, score=0.821 total time=   0.1s
# [CV 3/5] END ...max_depth=3, min_samples_leaf=5;, score=0.834 total time=   0.1s
# [CV 4/5] END ...max_depth=3, min_samples_leaf=5;, score=0.843 total time=   0.1s
# [CV 5/5] END ...max_depth=3, min_samples_leaf=5;, score=0.825 total time=   0.1s
# [CV 1/5] END ...max_depth=5, min_samples_leaf=6;, score=0.857 total time=   0.2s
# [CV 2/5] END ...max_depth=5, min_samples_leaf=6;, score=0.834 total time=   0.2s
# [CV 3/5] END ...max_depth=5, min_samples_leaf=6;, score=0.868 total time=   0.2s
# [CV 4/5] END ...max_depth=5, min_samples_leaf=6;, score=0.874 total time=   0.1s
# [CV 5/5] END ...max_depth=5, min_samples_leaf=6;, score=0.854 total time=   0.2s
# [CV 1/5] END ..max_depth=2, min_samples_leaf=11;, score=0.756 total time=   0.1s
# [CV 2/5] END ..max_depth=2, min_samples_leaf=11;, score=0.767 total time=   0.1s
# [CV 3/5] END ..max_depth=2, min_samples_leaf=11;, score=0.771 total time=   0.1s
# [CV 4/5] END ..max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.1s
# [CV 5/5] END ..max_depth=2, min_samples_leaf=11;, score=0.754 total time=   0.1s
# [CV 1/5] END ...max_depth=7, min_samples_leaf=9;, score=0.869 total time=   0.2s
# [CV 2/5] END ...max_depth=7, min_samples_leaf=9;, score=0.835 total time=   0.2s
# [CV 3/5] END ...max_depth=7, min_samples_leaf=9;, score=0.870 total time=   0.2s
# [CV 4/5] END ...max_depth=7, min_samples_leaf=9;, score=0.880 total time=   0.2s
# [CV 5/5] END ...max_depth=7, min_samples_leaf=9;, score=0.864 total time=   0.2s
# [CV 1/5] END .max_depth=12, min_samples_leaf=12;, score=0.876 total time=   0.2s
# [CV 2/5] END .max_depth=12, min_samples_leaf=12;, score=0.835 total time=   0.2s
# [CV 3/5] END .max_depth=12, min_samples_leaf=12;, score=0.884 total time=   0.2s
# [CV 4/5] END .max_depth=12, min_samples_leaf=12;, score=0.886 total time=   0.3s
# [CV 5/5] END .max_depth=12, min_samples_leaf=12;, score=0.874 total time=   0.3s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=12;, score=0.869 total time=   0.2s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=12;, score=0.834 total time=   0.2s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=12;, score=0.878 total time=   0.2s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=12;, score=0.879 total time=   0.2s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=12;, score=0.862 total time=   0.2s
# [CV 1/5] END .max_depth=10, min_samples_leaf=12;, score=0.873 total time=   0.2s
# [CV 2/5] END .max_depth=10, min_samples_leaf=12;, score=0.838 total time=   0.2s
# [CV 3/5] END .max_depth=10, min_samples_leaf=12;, score=0.875 total time=   0.2s
# [CV 4/5] END .max_depth=10, min_samples_leaf=12;, score=0.885 total time=   0.2s
# [CV 5/5] END .max_depth=10, min_samples_leaf=12;, score=0.872 total time=   0.2s
# [CV 1/5] END ..max_depth=13, min_samples_leaf=6;, score=0.883 total time=   0.3s
# [CV 2/5] END ..max_depth=13, min_samples_leaf=6;, score=0.845 total time=   0.3s
# [CV 3/5] END ..max_depth=13, min_samples_leaf=6;, score=0.882 total time=   0.3s
# [CV 4/5] END ..max_depth=13, min_samples_leaf=6;, score=0.884 total time=   0.3s
# [CV 5/5] END ..max_depth=13, min_samples_leaf=6;, score=0.883 total time=   0.3s
# [CV 1/5] END ..max_depth=11, min_samples_leaf=9;, score=0.876 total time=   0.2s
# [CV 2/5] END ..max_depth=11, min_samples_leaf=9;, score=0.834 total time=   0.2s
# [CV 3/5] END ..max_depth=11, min_samples_leaf=9;, score=0.879 total time=   0.3s
# [CV 4/5] END ..max_depth=11, min_samples_leaf=9;, score=0.881 total time=   0.3s
# [CV 5/5] END ..max_depth=11, min_samples_leaf=9;, score=0.876 total time=   0.3s
# [CV 1/5] END ...max_depth=9, min_samples_leaf=3;, score=0.878 total time=   0.2s
# [CV 2/5] END ...max_depth=9, min_samples_leaf=3;, score=0.841 total time=   0.3s
# [CV 3/5] END ...max_depth=9, min_samples_leaf=3;, score=0.879 total time=   0.2s
# [CV 4/5] END ...max_depth=9, min_samples_leaf=3;, score=0.875 total time=   0.2s
# [CV 5/5] END ...max_depth=9, min_samples_leaf=3;, score=0.875 total time=   0.3s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=8;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=8;, score=0.842 total time=   0.3s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=8;, score=0.877 total time=   0.2s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=8;, score=0.879 total time=   0.3s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=8;, score=0.874 total time=   0.2s
# [CV 1/5] END ...max_depth=8, min_samples_leaf=5;, score=0.873 total time=   0.2s
# [CV 2/5] END ...max_depth=8, min_samples_leaf=5;, score=0.838 total time=   0.2s
# [CV 3/5] END ...max_depth=8, min_samples_leaf=5;, score=0.874 total time=   0.2s
# [CV 4/5] END ...max_depth=8, min_samples_leaf=5;, score=0.881 total time=   0.2s
# [CV 5/5] END ...max_depth=8, min_samples_leaf=5;, score=0.872 total time=   0.2s
# [CV 1/5] END ..max_depth=15, min_samples_leaf=9;, score=0.879 total time=   0.2s
# [CV 2/5] END ..max_depth=15, min_samples_leaf=9;, score=0.840 total time=   0.3s
# [CV 3/5] END ..max_depth=15, min_samples_leaf=9;, score=0.882 total time=   0.2s
# [CV 4/5] END ..max_depth=15, min_samples_leaf=9;, score=0.884 total time=   0.2s
# [CV 5/5] END ..max_depth=15, min_samples_leaf=9;, score=0.876 total time=   0.2s
# [CV 1/5] END ..max_depth=8, min_samples_leaf=11;, score=0.871 total time=   0.2s
# [CV 2/5] END ..max_depth=8, min_samples_leaf=11;, score=0.840 total time=   0.2s
# [CV 3/5] END ..max_depth=8, min_samples_leaf=11;, score=0.876 total time=   0.2s
# [CV 4/5] END ..max_depth=8, min_samples_leaf=11;, score=0.883 total time=   0.2s
# [CV 5/5] END ..max_depth=8, min_samples_leaf=11;, score=0.865 total time=   0.2s
# RandomizedSearchCV(estimator=RandomForestClassifier(random_state=7), n_iter=50,
#                    param_distributions={'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(2, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[searchCV.best_score_] {searchCV.best_score_}')
print(f'[searchCV.best_param_] {searchCV.best_params_}')
print(f'[searchCV.best_estimator_] {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [searchCV.best_score_] 0.877817613089509
# [searchCV.best_param_] {'min_samples_leaf': 3, 'max_depth': 12}
# [searchCV.best_estimator_] RandomForestClassifier(max_depth=12, min_samples_leaf=3, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.214180      0.012052         0.016913        0.001384
# 1        0.313653      0.009673         0.020245        0.000596
# 2        0.310828      0.025501         0.019178        0.001237
# 3        0.202709      0.007491         0.015328        0.000550
# 4        0.336964      0.006393         0.022943        0.002691
# 5        0.250739      0.010439         0.017274        0.001141
# 6        0.307479      0.005459         0.020740        0.001117
# 7        0.283122      0.011932         0.018298        0.001255
# 8        0.287823      0.012364         0.018832        0.000885
# 9        0.355524      0.018465         0.021954        0.001690
# 10       0.332426      0.004145         0.021252        0.000481
# 11       0.322650      0.012881         0.022142        0.000813
# 12       0.323173      0.007149         0.021326        0.001741
# 13       0.310232      0.010358         0.021073        0.001627
# 14       0.244186      0.006808         0.016353        0.000542
# 15       0.348003      0.009884         0.021800        0.001014
# 16       0.267818      0.008653         0.018761        0.002125
# 17       0.329623      0.027906         0.020491        0.001762
# 18       0.370483      0.016480         0.023776        0.004722
# 19       0.198914      0.013297         0.016523        0.001915
# 20       0.240358      0.018880         0.015903        0.000974
# 21       0.174530      0.003299         0.013452        0.001644
# 22       0.313197      0.020762         0.020326        0.001967
# 23       0.312453      0.009564         0.021075        0.001409
# 24       0.181016      0.005726         0.013483        0.000682
# 25       0.306159      0.008705         0.019819        0.001007
# 26       0.302765      0.006479         0.021050        0.001468
# 27       0.270802      0.006150         0.017920        0.000512
# 28       0.241646      0.005662         0.018280        0.002104
# 29       0.242695      0.008786         0.017380        0.000696
# 30       0.187710      0.006701         0.014494        0.002077
# 31       0.206866      0.002825         0.015266        0.001494
# 32       0.233519      0.016619         0.015956        0.001605
# 33       0.323134      0.016654         0.021082        0.001969
# 34       0.188369      0.005365         0.015082        0.001333
# 35       0.389750      0.016271         0.024918        0.001888
# 36       0.206335      0.012967         0.015619        0.001206
# 37       0.245614      0.008812         0.017114        0.001215
# 38       0.188633      0.014833         0.013667        0.000873
# 39       0.300228      0.018467         0.019324        0.002032
# 40       0.329875      0.015238         0.020753        0.001593
# 41       0.286501      0.008219         0.019465        0.001381
# 42       0.309787      0.005462         0.020238        0.000988
# 43       0.344999      0.007392         0.022989        0.000992
# 44       0.334401      0.021611         0.021919        0.001354
# 45       0.323065      0.008005         0.021024        0.001430
# 46       0.331393      0.009964         0.020478        0.000884
# 47       0.298837      0.009057         0.019923        0.001548
# 48       0.328878      0.013584         0.021162        0.001230
# 49       0.294242      0.003631         0.019113        0.001021
#
#    param_min_samples_leaf param_max_depth  \
# 0                       8               3
# 1                      11              10
# 2                      12               8
# 3                       6               3
# 4                       5              12
# 5                       5               5
# 6                      12              13
# 7                      13               7
# 8                      11               7
# 9                       4              13
# 10                      6              12
# 11                      7               9
# 12                     10              11
# 13                     14              12
# 14                      7               5
# 15                      3              10
# 16                      5               6
# 17                     15              15
# 18                      3              12
# 19                      6               2
# 20                      7               4
# 21                      5               2
# 22                     15               9
# 23                      4               8
# 24                      4               2
# 25                     15              13
# 26                     15              10
# 27                      3               6
# 28                     10               5
# 29                      4               5
# 30                      7               2
# 31                     13               3
# 32                      8               4
# 33                     13              13
# 34                      8               2
# 35                      4              15
# 36                      5               3
# 37                      6               5
# 38                     11               2
# 39                      9               7
# 40                     12              12
# 41                     12               7
# 42                     12              10
# 43                      6              13
# 44                      9              11
# 45                      3               9
# 46                      8              15
# 47                      5               8
# 48                      9              15
# 49                     11               8
#
#                                        params  split0_test_score  \
# 0     {'min_samples_leaf': 8, 'max_depth': 3}           0.804808
# 1   {'min_samples_leaf': 11, 'max_depth': 10}           0.873077
# 2    {'min_samples_leaf': 12, 'max_depth': 8}           0.869231
# 3     {'min_samples_leaf': 6, 'max_depth': 3}           0.803846
# 4    {'min_samples_leaf': 5, 'max_depth': 12}           0.879808
# 5     {'min_samples_leaf': 5, 'max_depth': 5}           0.853846
# 6   {'min_samples_leaf': 12, 'max_depth': 13}           0.873077
# 7    {'min_samples_leaf': 13, 'max_depth': 7}           0.867308
# 8    {'min_samples_leaf': 11, 'max_depth': 7}           0.866346
# 9    {'min_samples_leaf': 4, 'max_depth': 13}           0.882692
# 10   {'min_samples_leaf': 6, 'max_depth': 12}           0.884615
# 11    {'min_samples_leaf': 7, 'max_depth': 9}           0.880769
# 12  {'min_samples_leaf': 10, 'max_depth': 11}           0.872115
# 13  {'min_samples_leaf': 14, 'max_depth': 12}           0.870192
# 14    {'min_samples_leaf': 7, 'max_depth': 5}           0.853846
# 15   {'min_samples_leaf': 3, 'max_depth': 10}           0.884615
# 16    {'min_samples_leaf': 5, 'max_depth': 6}           0.862500
# 17  {'min_samples_leaf': 15, 'max_depth': 15}           0.873077
# 18   {'min_samples_leaf': 3, 'max_depth': 12}           0.887500
# 19    {'min_samples_leaf': 6, 'max_depth': 2}           0.755769
# 20    {'min_samples_leaf': 7, 'max_depth': 4}           0.840385
# 21    {'min_samples_leaf': 5, 'max_depth': 2}           0.755769
# 22   {'min_samples_leaf': 15, 'max_depth': 9}           0.871154
# 23    {'min_samples_leaf': 4, 'max_depth': 8}           0.874038
# 24    {'min_samples_leaf': 4, 'max_depth': 2}           0.755769
# 25  {'min_samples_leaf': 15, 'max_depth': 13}           0.871154
# 26  {'min_samples_leaf': 15, 'max_depth': 10}           0.869231
# 27    {'min_samples_leaf': 3, 'max_depth': 6}           0.859615
# 28   {'min_samples_leaf': 10, 'max_depth': 5}           0.854808
# 29    {'min_samples_leaf': 4, 'max_depth': 5}           0.852885
# 30    {'min_samples_leaf': 7, 'max_depth': 2}           0.755769
# 31   {'min_samples_leaf': 13, 'max_depth': 3}           0.803846
# 32    {'min_samples_leaf': 8, 'max_depth': 4}           0.839423
# 33  {'min_samples_leaf': 13, 'max_depth': 13}           0.872115
# 34    {'min_samples_leaf': 8, 'max_depth': 2}           0.755769
# 35   {'min_samples_leaf': 4, 'max_depth': 15}           0.881731
# 36    {'min_samples_leaf': 5, 'max_depth': 3}           0.804808
# 37    {'min_samples_leaf': 6, 'max_depth': 5}           0.856731
# 38   {'min_samples_leaf': 11, 'max_depth': 2}           0.755769
# 39    {'min_samples_leaf': 9, 'max_depth': 7}           0.869231
# 40  {'min_samples_leaf': 12, 'max_depth': 12}           0.875962
# 41   {'min_samples_leaf': 12, 'max_depth': 7}           0.869231
# 42  {'min_samples_leaf': 12, 'max_depth': 10}           0.873077
# 43   {'min_samples_leaf': 6, 'max_depth': 13}           0.882692
# 44   {'min_samples_leaf': 9, 'max_depth': 11}           0.875962
# 45    {'min_samples_leaf': 3, 'max_depth': 9}           0.877885
# 46   {'min_samples_leaf': 8, 'max_depth': 15}           0.878846
# 47    {'min_samples_leaf': 5, 'max_depth': 8}           0.873077
# 48   {'min_samples_leaf': 9, 'max_depth': 15}           0.878846
# 49   {'min_samples_leaf': 11, 'max_depth': 8}           0.871154
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.821154           0.835419           0.843118
# 1            0.838462           0.879692           0.881617
# 2            0.837500           0.875842           0.874880
# 3            0.821154           0.835419           0.843118
# 4            0.850000           0.884504           0.882579
# 5            0.833654           0.868142           0.872955
# 6            0.836538           0.881617           0.881617
# 7            0.835577           0.875842           0.878730
# 8            0.836538           0.876805           0.873917
# 9            0.848077           0.882579           0.888354
# 10           0.843269           0.877767           0.889317
# 11           0.837500           0.876805           0.882579
# 12           0.840385           0.882579           0.887392
# 13           0.832692           0.874880           0.881617
# 14           0.835577           0.867180           0.873917
# 15           0.847115           0.881617           0.886429
# 16           0.833654           0.873917           0.880654
# 17           0.835577           0.881617           0.879692
# 18           0.850000           0.883542           0.889317
# 19           0.767308           0.770934           0.753609
# 20           0.835577           0.860443           0.861405
# 21           0.767308           0.770934           0.753609
# 22           0.837500           0.879692           0.880654
# 23           0.840385           0.876805           0.876805
# 24           0.767308           0.770934           0.753609
# 25           0.837500           0.880654           0.877767
# 26           0.836538           0.880654           0.882579
# 27           0.834615           0.874880           0.876805
# 28           0.827885           0.865255           0.874880
# 29           0.833654           0.869105           0.875842
# 30           0.767308           0.770934           0.753609
# 31           0.819231           0.837344           0.845043
# 32           0.836538           0.858518           0.860443
# 33           0.832692           0.872955           0.880654
# 34           0.767308           0.770934           0.753609
# 35           0.855769           0.881617           0.888354
# 36           0.821154           0.834456           0.843118
# 37           0.833654           0.868142           0.873917
# 38           0.767308           0.770934           0.753609
# 39           0.834615           0.870067           0.879692
# 40           0.834615           0.883542           0.886429
# 41           0.833654           0.877767           0.878730
# 42           0.837500           0.874880           0.884504
# 43           0.845192           0.881617           0.883542
# 44           0.833654           0.878730           0.880654
# 45           0.841346           0.878730           0.874880
# 46           0.842308           0.876805           0.878730
# 47           0.837500           0.873917           0.880654
# 48           0.840385           0.881617           0.883542
# 49           0.840385           0.875842           0.882579
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.824832         0.825866        0.013081               42
# 1            0.869105         0.868390        0.015626               18
# 2            0.866218         0.864734        0.014074               27
# 3            0.824832         0.825674        0.013393               43
# 4            0.876805         0.874739        0.012640                6
# 5            0.853705         0.856461        0.013734               37
# 6            0.870067         0.868583        0.016667               15
# 7            0.863330         0.864157        0.015338               29
# 8            0.863330         0.863387        0.014287               31
# 9            0.874880         0.875317        0.014278                4
# 10           0.875842         0.874162        0.016181                7
# 11           0.872955         0.870122        0.016646               11
# 12           0.874880         0.871470        0.016464                9
# 13           0.870067         0.865890        0.017124               25
# 14           0.852743         0.856653        0.013238               36
# 15           0.879692         0.875894        0.014577                3
# 16           0.860443         0.862234        0.016099               32
# 17           0.871992         0.868391        0.016819               16
# 18           0.878730         0.877818        0.014376                1
# 19           0.753609         0.760246        0.007379               45
# 20           0.845043         0.848571        0.010526               39
# 21           0.753609         0.760246        0.007379               45
# 22           0.871030         0.868006        0.015787               19
# 23           0.871992         0.868005        0.013929               20
# 24           0.753609         0.760246        0.007379               45
# 25           0.871030         0.867621        0.015519               21
# 26           0.867180         0.867237        0.016503               23
# 27           0.859480         0.861079        0.015118               33
# 28           0.851781         0.854922        0.015786               38
# 29           0.852743         0.856846        0.014707               35
# 30           0.753609         0.760246        0.007379               45
# 31           0.824832         0.826059        0.014348               41
# 32           0.843118         0.847608        0.009934               40
# 33           0.871030         0.865889        0.016942               26
# 34           0.753609         0.760246        0.007379               45
# 35           0.881617         0.877818        0.011325                1
# 36           0.824832         0.825674        0.012946               44
# 37           0.853705         0.857230        0.013900               34
# 38           0.753609         0.760246        0.007379               45
# 39           0.864293         0.863580        0.015317               30
# 40           0.873917         0.870893        0.018720               10
# 41           0.862368         0.864350        0.016473               28
# 42           0.871992         0.868391        0.016068               17
# 43           0.882579         0.875125        0.014979                5
# 44           0.875842         0.868968        0.017749               14
# 45           0.874880         0.869544        0.014184               13
# 46           0.873917         0.870121        0.014021               12
# 47           0.871992         0.867428        0.015267               22
# 48           0.875842         0.872046        0.016043                8
# 49           0.865255         0.867043        0.014488               24
