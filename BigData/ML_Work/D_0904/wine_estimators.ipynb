# %% [markdown]
# ### Ensenble - RandomForest & ExtraTree
#  - 배깅 방식의 앙상블 ==> 중복을 허용한 랜덤 샘플 + 동일 모델(DT)
#     * 대표 알고리즘 : RandomForestC/R :
#  - 페이스트 방식의 앙상블 ==> 랜덤 샘플 + 동일 모델 (DT)
#     * 대표 알고리즘 : ExtraTreeC/R

# %% [markdown]
#  [목표] 와인 분류 => 0과 1 종류 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비

# %%
# 모듈로딩
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터
DATA_FILE = '../data/wine.csv'

# CSV >> DataFrame  
wineDF = pd.read_csv(DATA_FILE)

# %%
# 데이터 확인
wineDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alcohol  6497 non-null   float64
#  1   sugar    6497 non-null   float64
#  2   pH       6497 non-null   float64
#  3   class    6497 non-null   float64
# dtypes: float64(4)
# memory usage: 203.2 KB

# %%
wineDF.head(2)
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0

# %%
# 타겟/라벨의 클래스 분포
wineDF['class'].value_counts()
# Out:
# class
# 1.0    4898
# 0.0    1599
# Name: count, dtype: int64

# %%
wineDF.describe()
# Out:
#            alcohol        sugar           pH        class
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean     10.491801     5.443235     3.218501     0.753886
# std       1.192712     4.757804     0.160787     0.430779
# min       8.000000     0.600000     2.720000     0.000000
# 25%       9.500000     1.800000     3.110000     1.000000
# 50%      10.300000     3.000000     3.210000     1.000000
# 75%      11.300000     8.100000     3.320000     1.000000
# max      14.900000    65.800000     4.010000     1.000000

# %% [markdown]
# [2] 학습 준비

# %%
# 학습용 & 테스트용 데이터셋 분할
from sklearn.model_selection import train_test_split

# %%
featureDF = wineDF[wineDF.columns[:-1]]
targetSR = wineDF[wineDF.columns[-1]]

print(f'featureDF : {featureDF.shape}, targetSR : {targetSR.shape}')
# Out:
# featureDF : (6497, 3), targetSR : (6497,)

# %%
# 학습용 테스트용 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(featureDF,
                                                    targetSR,
                                                    test_size=0.2,
                                                    stratify=targetSR,
                                                    random_state=1
                                                    )

# %%
print(f'X_train : {X_train.shape} y_train : {y_train}')
print(f'X_test : {X_test.shape} y_trest : {y_test}')
# Out:
# X_train : (5197, 3) y_train : 6378    1.0
# 3069    1.0
# 4986    1.0
# 993     0.0
# 4988    1.0
#        ...
# 453     0.0
# 1460    0.0
# 5755    1.0
# 6299    1.0
# 3369    1.0
# Name: class, Length: 5197, dtype: float64
# X_test : (1300, 3) y_trest : 1002    0.0
# 2345    1.0
# 79      0.0
# 4208    1.0
# 2092    1.0
#        ...
# 4179    1.0
# 2803    1.0
# 6454    1.0
# 5451    1.0
# 1360    0.0
# Name: class, Length: 1300, dtype: float64

# %% [markdown]
# [3] 학습진행

# %%
# 학습방법 : 지도학습 > 분류
# 알고리즘 : 앙상블 > 배깅 - RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
# 인스턴스 생성 => 100개의 내부 DT 모델에서 사용할 데이터셋 생성
#                random_state 매개변수 설정으로 고정된 데이터셋 생성
#                oob_score 배개변ㅇ수 ㅣ 샘플 데이터셋 추출 휴ㅜ 남은 데이터셋 검즈용ㅇ으로 사용
lf_model = ExtraTreesClassifier(random_state=7)

# 학습
lf_model.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(random_state=7)

# %%
# 모델 파라미터
print(f'classes_ : {lf_model.classes_}')
print(f'n_classes_ : {lf_model.n_classes_}')
print()
print(f'feature_names_in_ : {lf_model.feature_names_in_}')
print(f'n_features_in_ : {lf_model.n_features_in_}')
print(f'feature_importances_ : {lf_model.feature_importances_}')
# Out:
# classes_ : [0. 1.]
# n_classes_ : 2
#
# feature_names_in_ : ['alcohol' 'sugar' 'pH']
# n_features_in_ : 3
# feature_importances_ : [0.18992806 0.53030305 0.2797689 ]

# %%
# 모델 파라미터
print(f'clases_         : {lf_model.estimator_}')

for est in lf_model.estimators_: print(est)
# Out:
# clases_         : ExtraTreeClassifier()
# ExtraTreeClassifier(random_state=327741615)
# ExtraTreeClassifier(random_state=976413892)
# ExtraTreeClassifier(random_state=1202242073)
# ExtraTreeClassifier(random_state=1369975286)
# ExtraTreeClassifier(random_state=1882953283)
# ExtraTreeClassifier(random_state=2053951699)
# ExtraTreeClassifier(random_state=959775639)
# ExtraTreeClassifier(random_state=1956722279)
# ExtraTreeClassifier(random_state=2052949340)
# ExtraTreeClassifier(random_state=1322904761)
# ExtraTreeClassifier(random_state=165338510)
# ExtraTreeClassifier(random_state=1133316631)
# ExtraTreeClassifier(random_state=4812360)
# ExtraTreeClassifier(random_state=372560217)
# ExtraTreeClassifier(random_state=309457262)
# ExtraTreeClassifier(random_state=1801189930)
# ExtraTreeClassifier(random_state=1152936666)
# ExtraTreeClassifier(random_state=68334472)
# ExtraTreeClassifier(random_state=2146978983)
# ExtraTreeClassifier(random_state=119248870)
# ExtraTreeClassifier(random_state=769786948)
# ExtraTreeClassifier(random_state=1583990192)
# ExtraTreeClassifier(random_state=1304549247)
# ExtraTreeClassifier(random_state=1420943751)
# ExtraTreeClassifier(random_state=1636129708)
# ExtraTreeClassifier(random_state=1687674368)
# ExtraTreeClassifier(random_state=283194443)
# ExtraTreeClassifier(random_state=748743479)
# ExtraTreeClassifier(random_state=1237575930)
# ExtraTreeClassifier(random_state=740097030)
# ExtraTreeClassifier(random_state=1759190803)
# ExtraTreeClassifier(random_state=833359292)
# ExtraTreeClassifier(random_state=916483116)
# ExtraTreeClassifier(random_state=1485942463)
# ExtraTreeClassifier(random_state=1941857605)
# ExtraTreeClassifier(random_state=1844809528)
# ExtraTreeClassifier(random_state=1852015768)
# ExtraTreeClassifier(random_state=1127788727)
# ExtraTreeClassifier(random_state=106941365)
# ExtraTreeClassifier(random_state=1077017712)
# ExtraTreeClassifier(random_state=431854331)
# ExtraTreeClassifier(random_state=1094761661)
# ExtraTreeClassifier(random_state=1933291456)
# ExtraTreeClassifier(random_state=1508798754)
# ExtraTreeClassifier(random_state=989143352)
# ExtraTreeClassifier(random_state=747550921)
# ExtraTreeClassifier(random_state=208262606)
# ExtraTreeClassifier(random_state=1248819750)
# ExtraTreeClassifier(random_state=1757192964)
# ExtraTreeClassifier(random_state=1879603694)
# ExtraTreeClassifier(random_state=571958409)
# ExtraTreeClassifier(random_state=1927692119)
# ExtraTreeClassifier(random_state=100556259)
# ExtraTreeClassifier(random_state=1652057283)
# ExtraTreeClassifier(random_state=1075502152)
# ExtraTreeClassifier(random_state=1535344467)
# ExtraTreeClassifier(random_state=725906352)
# ExtraTreeClassifier(random_state=830456065)
# ExtraTreeClassifier(random_state=2008983232)
# ExtraTreeClassifier(random_state=431532432)
# ExtraTreeClassifier(random_state=879820150)
# ExtraTreeClassifier(random_state=2072909727)
# ExtraTreeClassifier(random_state=2107823453)
# ExtraTreeClassifier(random_state=488352684)
# ExtraTreeClassifier(random_state=1599380060)
# ExtraTreeClassifier(random_state=1938096892)
# ExtraTreeClassifier(random_state=2050422343)
# ExtraTreeClassifier(random_state=1497897239)
# ExtraTreeClassifier(random_state=1571487242)
# ExtraTreeClassifier(random_state=1187621609)
# ExtraTreeClassifier(random_state=1451346723)
# ExtraTreeClassifier(random_state=1917728192)
# ExtraTreeClassifier(random_state=1153832253)
# ExtraTreeClassifier(random_state=1966724487)
# ExtraTreeClassifier(random_state=1348596887)
# ExtraTreeClassifier(random_state=771276892)
# ExtraTreeClassifier(random_state=311923447)
# ExtraTreeClassifier(random_state=612959456)
# ExtraTreeClassifier(random_state=1185621653)
# ExtraTreeClassifier(random_state=358664548)
# ExtraTreeClassifier(random_state=1944945571)
# ExtraTreeClassifier(random_state=202873313)
# ExtraTreeClassifier(random_state=1516030531)
# ExtraTreeClassifier(random_state=1332338555)
# ExtraTreeClassifier(random_state=676025563)
# ExtraTreeClassifier(random_state=1214271969)
# ExtraTreeClassifier(random_state=1590645779)
# ExtraTreeClassifier(random_state=1808153499)
# ExtraTreeClassifier(random_state=1971789316)
# ExtraTreeClassifier(random_state=1861190419)
# ExtraTreeClassifier(random_state=941989921)
# ExtraTreeClassifier(random_state=1798548603)
# ExtraTreeClassifier(random_state=1773786398)
# ExtraTreeClassifier(random_state=2088312505)
# ExtraTreeClassifier(random_state=1745574629)
# ExtraTreeClassifier(random_state=1260873545)
# ExtraTreeClassifier(random_state=775033821)
# ExtraTreeClassifier(random_state=1474484177)
# ExtraTreeClassifier(random_state=1035597695)
# ExtraTreeClassifier(random_state=1289946527)

# %%
# 모델 파라미터
print(f'clases_         : {lf_model.classes_}')

for est in lf_model.estimators_: print(est)

# %%
print(f'clases_         : {lf_model.classes_}')

for est in lf_model.estimators_: print(est)

# %% [markdown]
# [4] 성능평가

# %%
train_score = lf_model.score(X_train, y_train)
test_score = lf_model.score(X_test, y_test)

# %%
# print(f'oob_score : {lf_model.oob_score_}')

# %%
print(f'train_score : {train_score}, test_score : {test_score}')
# Out:
# train_score : 0.9973061381566288, test_score : 0.8961538461538462

# %% [markdown]
# [5] 튜닝
#  - RandomizedSearchCV 하이퍼파라미터 최적화 클래스
#     * 범위가 넓은 하이퍼파라미터 설정에 좋음
#     * 지정된 범위에서 지정된 횟수만큼 하이퍼파라미터를 추출항 조합 진행

# %%
# 모듈 로딩
from sklearn.model_selection import RandomizedSearchCV

# %%
# RandomForestClassifier 하이퍼파라미터 
params = {'max_depth' : range(2,16),
          'min_samples_leaf' : range(5,16),
          'criterion' : ['gini', 'entropy', 'log_loss']
          }

# %%
rf_model = ExtraTreesClassifier(n_estimators=300, random_state=7)

# %%
searchCV = RandomizedSearchCV(rf_model, param_distributions=params, n_iter = 50, verbose=4)
# verbose

# %%
# searchCV.best_params_

searchCV.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.754 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=14, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=2, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, min_samples_leaf=12;, score=0.754 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, min_samples_leaf=12;, score=0.754 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, min_samples_leaf=12;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=3, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=3, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=13, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=13, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=13, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=13, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=13, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=4, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=3, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=9;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=10, min_samples_leaf=9;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=10, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=10;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=6, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=6, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=6, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=6, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=6, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=11, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=11, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.754 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=15, min_samples_leaf=6;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=12, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=12, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=12, min_samples_leaf=8;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=12, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=12, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=9, min_samples_leaf=12;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=5, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=13;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=12;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=5, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=10;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=13, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=13, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=13, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=13, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=13, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=6, min_samples_leaf=9;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, min_samples_leaf=5;, score=0.754 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=12, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=7, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=7, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=7, min_samples_leaf=5;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=7, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=7, min_samples_leaf=5;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=9, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=9, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=9, min_samples_leaf=8;, score=0.755 total time=   0.4s
# [CV 4/5] END criterion=log_loss, max_depth=9, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=9, min_samples_leaf=8;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=7, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=4, min_samples_leaf=14;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=15, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=15, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=15, min_samples_leaf=15;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=15, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=15, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=13, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=13, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=13, min_samples_leaf=11;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=13, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=13, min_samples_leaf=11;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=5, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=5, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=5, min_samples_leaf=15;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=5, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=5, min_samples_leaf=15;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=log_loss, max_depth=8, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=log_loss, max_depth=8, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=log_loss, max_depth=8, min_samples_leaf=6;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=log_loss, max_depth=8, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=log_loss, max_depth=8, min_samples_leaf=6;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.754 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=12, min_samples_leaf=12;, score=0.755 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=12, min_samples_leaf=12;, score=0.754 total time=   0.3s
# RandomizedSearchCV(estimator=ExtraTreesClassifier(n_estimators=300,
#                                                   random_state=7),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': range(2, 16),
#                                         'min_samples_leaf': range(5, 16)},
#                    verbose=4)

# %%
# 모델 파라미터
print(f'[searchCV.best_score_] {searchCV.best_score_}')
print(f'[searchCV.best_param_] {searchCV.best_params_}')
print(f'[searchCV.best_estimator_] {searchCV.best_estimator_}')

cv_resultDF = pd.DataFrame(searchCV.cv_results_)
cv_resultDF
# Out:
# [searchCV.best_score_] 0.75389649811209
# [searchCV.best_param_] {'min_samples_leaf': 15, 'max_depth': 14, 'criterion': 'entropy'}
# [searchCV.best_estimator_] ExtraTreesClassifier(criterion='entropy', max_depth=14, min_samples_leaf=15,
#                      n_estimators=300, random_state=7)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.375054      0.029092         0.037806        0.003595
# 1        0.324879      0.006580         0.032836        0.002080
# 2        0.335230      0.017278         0.033230        0.001023
# 3        0.354901      0.015795         0.036544        0.001559
# 4        0.323608      0.014157         0.033629        0.002705
# 5        0.316322      0.020128         0.033397        0.001642
# 6        0.372181      0.012222         0.038969        0.003871
# 7        0.337261      0.010783         0.034994        0.002406
# 8        0.326120      0.004894         0.033628        0.000563
# 9        0.341869      0.015862         0.038113        0.002751
# 10       0.340465      0.009581         0.034773        0.001911
# 11       0.361136      0.007809         0.039168        0.001959
# 12       0.357527      0.020873         0.037131        0.005124
# 13       0.347996      0.014692         0.034917        0.002005
# 14       0.356144      0.017120         0.037253        0.002390
# 15       0.339453      0.009159         0.035488        0.001515
# 16       0.334939      0.006515         0.037372        0.004546
# 17       0.344476      0.014441         0.036755        0.003659
# 18       0.370189      0.010080         0.039801        0.002190
# 19       0.401178      0.031520         0.040506        0.003554
# 20       0.345700      0.013623         0.035732        0.003116
# 21       0.342009      0.014010         0.036307        0.006020
# 22       0.379386      0.026035         0.039151        0.003805
# 23       0.352445      0.012747         0.039316        0.005138
# 24       0.340671      0.013032         0.035831        0.003399
# 25       0.329938      0.008520         0.033281        0.001367
# 26       0.351478      0.013822         0.035375        0.002801
# 27       0.350605      0.007152         0.036562        0.002080
# 28       0.332445      0.010088         0.033770        0.002240
# 29       0.335527      0.008198         0.035870        0.001445
# 30       0.378071      0.027050         0.039267        0.002402
# 31       0.340606      0.007655         0.035108        0.001354
# 32       0.340205      0.013175         0.037418        0.004178
# 33       0.342088      0.007720         0.035086        0.000549
# 34       0.368590      0.019960         0.038355        0.003421
# 35       0.337045      0.007603         0.035173        0.001786
# 36       0.370647      0.015932         0.037862        0.001795
# 37       0.347270      0.012455         0.036647        0.001878
# 38       0.366835      0.033016         0.037083        0.001481
# 39       0.336420      0.011103         0.037375        0.002636
# 40       0.337752      0.003673         0.036327        0.003277
# 41       0.379526      0.034568         0.038671        0.001946
# 42       0.335688      0.011534         0.036297        0.004488
# 43       0.327284      0.006102         0.033747        0.002331
# 44       0.354699      0.013631         0.035894        0.001069
# 45       0.358914      0.007605         0.038600        0.002154
# 46       0.336933      0.007869         0.034607        0.001775
# 47       0.351395      0.011191         0.037320        0.001741
# 48       0.347528      0.011260         0.035836        0.001807
# 49       0.349239      0.013278         0.036146        0.000514
#
#    param_min_samples_leaf param_max_depth param_criterion  \
# 0                      15              14         entropy
# 1                       6               3         entropy
# 2                       6               2         entropy
# 3                       5               6        log_loss
# 4                       7               3            gini
# 5                      12               3         entropy
# 6                       5              13         entropy
# 7                       5               4        log_loss
# 8                       5               3        log_loss
# 9                      10               6        log_loss
# 10                     14               7        log_loss
# 11                      9              12         entropy
# 12                     14              15         entropy
# 13                      5               6         entropy
# 14                      9              10        log_loss
# 15                     14              11            gini
# 16                     10               5         entropy
# 17                     14               6         entropy
# 18                     11              11            gini
# 19                      6              15            gini
# 20                     13               6        log_loss
# 21                     11               5         entropy
# 22                      5              10         entropy
# 23                      8              10            gini
# 24                      9               6            gini
# 25                     10               4            gini
# 26                      8              12        log_loss
# 27                     12               9            gini
# 28                     13               5            gini
# 29                     13               7        log_loss
# 30                      5              15         entropy
# 31                     12               9        log_loss
# 32                     11               5        log_loss
# 33                     10               8        log_loss
# 34                      5               9        log_loss
# 35                      8               6        log_loss
# 36                      6              13         entropy
# 37                      9               6        log_loss
# 38                      5              10            gini
# 39                     14              12            gini
# 40                      5               7         entropy
# 41                      8               9        log_loss
# 42                     12               7        log_loss
# 43                     14               4            gini
# 44                     15              15         entropy
# 45                     11              13            gini
# 46                     15               5         entropy
# 47                      6               8        log_loss
# 48                     10               8            gini
# 49                     12              12         entropy
#
#                                                params  split0_test_score  \
# 0   {'min_samples_leaf': 15, 'max_depth': 14, 'cri...           0.753846
# 1   {'min_samples_leaf': 6, 'max_depth': 3, 'crite...           0.753846
# 2   {'min_samples_leaf': 6, 'max_depth': 2, 'crite...           0.753846
# 3   {'min_samples_leaf': 5, 'max_depth': 6, 'crite...           0.753846
# 4   {'min_samples_leaf': 7, 'max_depth': 3, 'crite...           0.753846
# 5   {'min_samples_leaf': 12, 'max_depth': 3, 'crit...           0.753846
# 6   {'min_samples_leaf': 5, 'max_depth': 13, 'crit...           0.753846
# 7   {'min_samples_leaf': 5, 'max_depth': 4, 'crite...           0.753846
# 8   {'min_samples_leaf': 5, 'max_depth': 3, 'crite...           0.753846
# 9   {'min_samples_leaf': 10, 'max_depth': 6, 'crit...           0.753846
# 10  {'min_samples_leaf': 14, 'max_depth': 7, 'crit...           0.753846
# 11  {'min_samples_leaf': 9, 'max_depth': 12, 'crit...           0.753846
# 12  {'min_samples_leaf': 14, 'max_depth': 15, 'cri...           0.753846
# 13  {'min_samples_leaf': 5, 'max_depth': 6, 'crite...           0.753846
# 14  {'min_samples_leaf': 9, 'max_depth': 10, 'crit...           0.753846
# 15  {'min_samples_leaf': 14, 'max_depth': 11, 'cri...           0.753846
# 16  {'min_samples_leaf': 10, 'max_depth': 5, 'crit...           0.753846
# 17  {'min_samples_leaf': 14, 'max_depth': 6, 'crit...           0.753846
# 18  {'min_samples_leaf': 11, 'max_depth': 11, 'cri...           0.753846
# 19  {'min_samples_leaf': 6, 'max_depth': 15, 'crit...           0.753846
# 20  {'min_samples_leaf': 13, 'max_depth': 6, 'crit...           0.753846
# 21  {'min_samples_leaf': 11, 'max_depth': 5, 'crit...           0.753846
# 22  {'min_samples_leaf': 5, 'max_depth': 10, 'crit...           0.753846
# 23  {'min_samples_leaf': 8, 'max_depth': 10, 'crit...           0.753846
# 24  {'min_samples_leaf': 9, 'max_depth': 6, 'crite...           0.753846
# 25  {'min_samples_leaf': 10, 'max_depth': 4, 'crit...           0.753846
# 26  {'min_samples_leaf': 8, 'max_depth': 12, 'crit...           0.753846
# 27  {'min_samples_leaf': 12, 'max_depth': 9, 'crit...           0.753846
# 28  {'min_samples_leaf': 13, 'max_depth': 5, 'crit...           0.753846
# 29  {'min_samples_leaf': 13, 'max_depth': 7, 'crit...           0.753846
# 30  {'min_samples_leaf': 5, 'max_depth': 15, 'crit...           0.753846
# 31  {'min_samples_leaf': 12, 'max_depth': 9, 'crit...           0.753846
# 32  {'min_samples_leaf': 11, 'max_depth': 5, 'crit...           0.753846
# 33  {'min_samples_leaf': 10, 'max_depth': 8, 'crit...           0.753846
# 34  {'min_samples_leaf': 5, 'max_depth': 9, 'crite...           0.753846
# 35  {'min_samples_leaf': 8, 'max_depth': 6, 'crite...           0.753846
# 36  {'min_samples_leaf': 6, 'max_depth': 13, 'crit...           0.753846
# 37  {'min_samples_leaf': 9, 'max_depth': 6, 'crite...           0.753846
# 38  {'min_samples_leaf': 5, 'max_depth': 10, 'crit...           0.753846
# 39  {'min_samples_leaf': 14, 'max_depth': 12, 'cri...           0.753846
# 40  {'min_samples_leaf': 5, 'max_depth': 7, 'crite...           0.753846
# 41  {'min_samples_leaf': 8, 'max_depth': 9, 'crite...           0.753846
# 42  {'min_samples_leaf': 12, 'max_depth': 7, 'crit...           0.753846
# 43  {'min_samples_leaf': 14, 'max_depth': 4, 'crit...           0.753846
# 44  {'min_samples_leaf': 15, 'max_depth': 15, 'cri...           0.753846
# 45  {'min_samples_leaf': 11, 'max_depth': 13, 'cri...           0.753846
# 46  {'min_samples_leaf': 15, 'max_depth': 5, 'crit...           0.753846
# 47  {'min_samples_leaf': 6, 'max_depth': 8, 'crite...           0.753846
# 48  {'min_samples_leaf': 10, 'max_depth': 8, 'crit...           0.753846
# 49  {'min_samples_leaf': 12, 'max_depth': 12, 'cri...           0.753846
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.753846           0.754572           0.753609
# 1            0.753846           0.754572           0.753609
# 2            0.753846           0.754572           0.753609
# 3            0.753846           0.754572           0.753609
# 4            0.753846           0.754572           0.753609
# 5            0.753846           0.754572           0.753609
# 6            0.753846           0.754572           0.753609
# 7            0.753846           0.754572           0.753609
# 8            0.753846           0.754572           0.753609
# 9            0.753846           0.754572           0.753609
# 10           0.753846           0.754572           0.753609
# 11           0.753846           0.754572           0.753609
# 12           0.753846           0.754572           0.753609
# 13           0.753846           0.754572           0.753609
# 14           0.753846           0.754572           0.753609
# 15           0.753846           0.754572           0.753609
# 16           0.753846           0.754572           0.753609
# 17           0.753846           0.754572           0.753609
# 18           0.753846           0.754572           0.753609
# 19           0.753846           0.754572           0.753609
# 20           0.753846           0.754572           0.753609
# 21           0.753846           0.754572           0.753609
# 22           0.753846           0.754572           0.753609
# 23           0.753846           0.754572           0.753609
# 24           0.753846           0.754572           0.753609
# 25           0.753846           0.754572           0.753609
# 26           0.753846           0.754572           0.753609
# 27           0.753846           0.754572           0.753609
# 28           0.753846           0.754572           0.753609
# 29           0.753846           0.754572           0.753609
# 30           0.753846           0.754572           0.753609
# 31           0.753846           0.754572           0.753609
# 32           0.753846           0.754572           0.753609
# 33           0.753846           0.754572           0.753609
# 34           0.753846           0.754572           0.753609
# 35           0.753846           0.754572           0.753609
# 36           0.753846           0.754572           0.753609
# 37           0.753846           0.754572           0.753609
# 38           0.753846           0.754572           0.753609
# 39           0.753846           0.754572           0.753609
# 40           0.753846           0.754572           0.753609
# 41           0.753846           0.754572           0.753609
# 42           0.753846           0.754572           0.753609
# 43           0.753846           0.754572           0.753609
# 44           0.753846           0.754572           0.753609
# 45           0.753846           0.754572           0.753609
# 46           0.753846           0.754572           0.753609
# 47           0.753846           0.754572           0.753609
# 48           0.753846           0.754572           0.753609
# 49           0.753846           0.754572           0.753609
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.753609         0.753896        0.000354                1
# 1            0.753609         0.753896        0.000354                1
# 2            0.753609         0.753896        0.000354                1
# 3            0.753609         0.753896        0.000354                1
# 4            0.753609         0.753896        0.000354                1
# 5            0.753609         0.753896        0.000354                1
# 6            0.753609         0.753896        0.000354                1
# 7            0.753609         0.753896        0.000354                1
# 8            0.753609         0.753896        0.000354                1
# 9            0.753609         0.753896        0.000354                1
# 10           0.753609         0.753896        0.000354                1
# 11           0.753609         0.753896        0.000354                1
# 12           0.753609         0.753896        0.000354                1
# 13           0.753609         0.753896        0.000354                1
# 14           0.753609         0.753896        0.000354                1
# 15           0.753609         0.753896        0.000354                1
# 16           0.753609         0.753896        0.000354                1
# 17           0.753609         0.753896        0.000354                1
# 18           0.753609         0.753896        0.000354                1
# 19           0.753609         0.753896        0.000354                1
# 20           0.753609         0.753896        0.000354                1
# 21           0.753609         0.753896        0.000354                1
# 22           0.753609         0.753896        0.000354                1
# 23           0.753609         0.753896        0.000354                1
# 24           0.753609         0.753896        0.000354                1
# 25           0.753609         0.753896        0.000354                1
# 26           0.753609         0.753896        0.000354                1
# 27           0.753609         0.753896        0.000354                1
# 28           0.753609         0.753896        0.000354                1
# 29           0.753609         0.753896        0.000354                1
# 30           0.753609         0.753896        0.000354                1
# 31           0.753609         0.753896        0.000354                1
# 32           0.753609         0.753896        0.000354                1
# 33           0.753609         0.753896        0.000354                1
# 34           0.753609         0.753896        0.000354                1
# 35           0.753609         0.753896        0.000354                1
# 36           0.753609         0.753896        0.000354                1
# 37           0.753609         0.753896        0.000354                1
# 38           0.753609         0.753896        0.000354                1
# 39           0.753609         0.753896        0.000354                1
# 40           0.753609         0.753896        0.000354                1
# 41           0.753609         0.753896        0.000354                1
# 42           0.753609         0.753896        0.000354                1
# 43           0.753609         0.753896        0.000354                1
# 44           0.753609         0.753896        0.000354                1
# 45           0.753609         0.753896        0.000354                1
# 46           0.753609         0.753896        0.000354                1
# 47           0.753609         0.753896        0.000354                1
# 48           0.753609         0.753896        0.000354                1
# 49           0.753609         0.753896        0.000354                1
