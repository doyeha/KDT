# %% [markdown]
# 1. 기계학습 프로세스에 대해 간략하게 설명하세요
#     머신러닝을 진행하는 일련의 과정
#     데이터 수집 - 전처리 - 모델 학습 - 모델 평가  순으로 이루어진다.
#
# 2. 기계학습에 사용되는 데이터셋에 대해 설명하세요.
#
# 3. 지도학습의 특징을 설명하세요.
#     모델 학습에 있어 예측, 분류하기 위한 목적으로 피쳐와 타겟으로 하는 정답을 모두 제공해 문제와 답지를 주어 공부하게 하는 방법.
#     반대로는 비지도 학습이 있다.
#
# 4. 데이터 전처리 중 처음 데이터 수집 후 데이터 정제하는 과정에 진행되는 작업을 설명하세요
#
#
# 5. 모델 개념을 설명해 주세요
#
#
# 6. 모델의 결과 값이 수치를 예측해주는 기계학습은 무엇인가요
#
#
# 7. 모델 파라미터는 무엇인가요
#
#
# 8. KNN알고리즘에 대해 설명해 주세요
#     끼리끼리 개념.
#     가장 유사한, 근접한 특징들을 토대로 분류, 예측하는 방법.
#
# 9. 하이퍼 파라미터는 무엇인가요
#     최적의 학습을 위해 입력하는 파라미터
#
# 10. Regression의 성능평가 지표들을 설명하세요.
#     회귀분석.
#
# 11. LinearRegression 알고리즘에 대해 설명해 주세요.
#     선형회귀분석
#     절편, 기울기...
#
# 12. Classification.의 성능평가 지표들을 설명하세요.
#     정규화
#
# 13. 피쳐공학에 대해 설명하세요.
#
# 14. LogisticRegression 알고리즘에 대해 설명해 주세요.
#     로지스틱회귀분석
#
# 15.  과대적합 과소적합에 대해 설명해 주세요
#     과대적합 : 학습한 데이터 모델에만 적절히 작동하는 적합 상태
#     과소적합 : 다른 데이터 뿐만 아니라 학습한 데이터 조차 소화하지 못하는 상태.
#
# 16. 아래 데이터셋을 기반으로 분류 회귀 모델을 완성 후 성능평가까지 구현하세요
#     데이터셋     - : iris.csv
#     조건
#     - 분류   3개 품종 중  2개 선택하여 이진 분류 진행
#     * 회귀   3개 품종 중  1개 선택  4개 피쳐 중 꽃잎의 길이값 예측 회
