# %% [markdown]
# #### DL TEST 2024. 09. 19
# 1. (Perceptron) . 퍼셉트론 개념에 대해 설명하세요
#     피쳐 분류를 위한 연산 과정의 하나.
#
#
#
# 2. (Perceptron) . 퍼셉트론 기본 동작 원리 및 수식을 도식화와 함께 작성해주세요
# - 조건 : 피쳐 4개 퍼셉트론 1개
#
#
#     f1w1 + f2w2 + f3w3 + f4w4 + b

# %% [markdown]
# ![스크린샷 2024-09-19 094730.png](<attachment:스크린샷 2024-09-19 094730.png>)

# %% [markdown]
# 3. (Activation Function) 활성화함수 의 역할을 설명하세요
#     출력을 제한하는 함수
#     일정 범위 내로 출력을 제한한다.
#
#
# 4. (Activation Function) . 대표적인 활성화함수 에 대해 설명하세요
# - 최소 4개 이상 값의 범위
#     DNN? / 시그모이드 / MAX...? 뭐 있었는데 .
#
#     Relu
#     시그모이드는 0~1 범위 내에서 출력값 조정
#     s?max 피쳐 많을 때 쓰는 활성화함수.
#
#
# 5. . 경사하강법의 개념 및 대표적인 경사하강법 알고리즘에 대해 간략히 설명하세요
# -  최소 3개
#     손실함수로 그래프를 그려 가장 낮은 지점을 통해 하이퍼 파라미터 탐색
#     경사하강법 가중치와 b 업데이트
#
#     optimizer = 손실의 최솟값을 찾아내는 최적화 알고리즘
#
# 6. 회귀 모델 구현을 간략하게 코드 작성하세요
# -  피쳐 3개

# %%
# 6. 회귀 모델 구현을 간략하게 코드 작성하세요
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchmetrics.regression import *

# %%
# 6
featureSR = 
targetSR = 

X_train, X_test, y_train, y_test = traintestsplit(featureDF, targetDF, stratify = targetDF, ramdom_state = 10)

Model = LinearRegression()
Model()

# %% [markdown]
# 7. . 이진분류 모델 구현을 간략하게 코드 작성하세요
# - 피쳐 5개  - 클래스 2개    - 층 : 4개
#
#     torch 형변환 하고
#
#     클래스 -
#     층 나누고
#     퍼셉트론
#
#     class Model(input):
#         self 층 구현
#         def __init__():
#             super() ? 뭔가 빠졌다.
#             self.in_layer = nn.Linear(5,30)
#             self.hid_layer = nn.Linear(30,40)
#             self.hid_layer2 = nn.Linear(40,20)
#             self.out_layer = nn.Linear(20,1)
#
#         def forward()
#             y = self.in_layer(input)
#             y = F.relu(y)
#             y = self.hid_layer(input)
#             y = F.relu(y)
#             y = self.hid_layer(input)
#             y = F.relu(y)
#         return self.out_layer(input)
#
#     binary_regression/sdfasdfsdf
#
#
# 8.  다중분류 모델 구현을 간략하게 코드 작성하세요
#     - 피쳐 5    - 클래스 8개    - 층 : 3 ~ 5    - 퍼셉트론 : 동적
#
#
# 9. 기울기 소실 개념 및 해결 방법을 설명하세요.
#     기울기 변동과 함께 손실 함수 체크 불가능해짐, 즉 경사하강법 사용 불가능 문제 발생
#     이거 때문에 시그모이드, 렐루와 같은 활성화함수를 사용해 기울기 소실을 방지한다.
#
#
# 10. 파이토치의 모델 동작 모드에 대해 관련 함수도 함께 설명하세요
