# %%
# 모듈 준비
import torch        
import torch.nn as nn                           # 인공신경망 관련 모듈
import torch.nn.functional as F                 # 손실, 거리 등 함수 관련 모듈
import torch.optim as optimizer                 # 최적화 기법 관련 모듈
from torchmetrics.regression import R2Score     # 성능 지표 관련 모듈 - 추가설치치
from torchinfo import summary                   # 모델 정보 관련 모듈 - 추가설치
import matplotlib.pyplot as plt

import pandas as pd                             # 데이터 파일 분석 관련 모듈
from sklearn.model_selection import train_test_split

# %%
# 모델의 가중치 및 절편 값 고정 설정
torch.manual_seed(1)

# 저장 및 실행 위치 설정
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'DEVICE => {DEVICE}')
# Out:
# DEVICE => cpu

# %%
# 데이터 로딩 : CSV => DataFrame
DATA_FILE = 'C:\Git\KDT\BigData\ML_Work\data\iris.csv'

# %%
irisDF = pd.read_csv(DATA_FILE, usecols=[0,1,2,3])
irisDF.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# #### [2] 모델준비
#  - 학습방법 : 지도학습 > 회귀
#  - 알고리즘 : 선형관계 >> 선형모델 ==> nn.Linear

# %%
# 모델 설꼐
# 입력층에 입력값/피쳐 =>  sepal.length, sepal.width, petal.length 3개
# 출력층의 출력값/타겟 =>  petal.width 1개
# 입력층 : 입력 피쳐3, 출력 입력층에 존재하는 퍼셉트론 개수 10, AF ReLU
#              ________|
#             | ReLU
#             v
# 은닉층 : 입력 10,     출력 입력층에 존재하는 퍼셉트론 개수 5, AF ReLU
#              ________|
#             | ReLU
#             v
# 출력층 : 입력 10,     출력 타겟/라벨 개수1, AF ReLU

model = nn.Sequential(nn.Linear(3,10),
                    nn.ReLU(),
                    nn.Linear(10,5),
                    nn.ReLU(),
                    nn.Linear(5,1)      # 입력층과 출력층은 고정이다. 
                    )

# 입력 3개 = 피쳐 3개
# 출력 1개 = 타겟 1개


# 다중분류
# 64픽셀짜리 5 9 4 넣는다? 
# 그럼 input 64 // output 3 (2진 분류 3개 5&9 / 4&9 / 5&4   )

# %%
# 모델 구조 확인 
print(model)

summary(model, input_size=(200000,3))
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=10, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=10, out_features=5, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=5, out_features=1, bias=True)
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               [200000, 1]               --
# ├─Linear: 1-1                            [200000, 10]              40
# ├─ReLU: 1-2                              [200000, 10]              --
# ├─Linear: 1-3                            [200000, 5]               55
# ├─ReLU: 1-4                              [200000, 5]               --
# ├─Linear: 1-5                            [200000, 1]               6
# ==========================================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# Total mult-adds (M): 20.20
# ==========================================================================================
# Input size (MB): 2.40
# Forward/backward pass size (MB): 25.60
# Params size (MB): 0.00
# Estimated Total Size (MB): 28.00
# ==========================================================================================

# %%
adam_optim = optimizer.Adam(model.parameters(), lr=0.1)

# %%
# 가중치와 절편 확인
for name, param in model.named_parameters():
    print(f'[{name}] {param}')
# Out:
# [0.weight] Parameter containing:
# tensor([[ 0.2975, -0.2548, -0.1119],
#         [ 0.2710, -0.5435,  0.3462],
#         [-0.1188,  0.2937,  0.0803],
#         [-0.0707,  0.1601,  0.0285],
#         [ 0.2109, -0.2250, -0.0421],
#         [-0.0520,  0.0837, -0.0023],
#         [ 0.5047,  0.1797, -0.2150],
#         [-0.3487, -0.0968, -0.2490],
#         [-0.1850,  0.0276,  0.3442],
#         [ 0.3138, -0.5644,  0.3579]], requires_grad=True)
# [0.bias] Parameter containing:
# tensor([ 0.1613,  0.5476,  0.3811, -0.5260, -0.5489, -0.2785,  0.5070, -0.0962,
#          0.2471, -0.2683], requires_grad=True)
# [2.weight] Parameter containing:
# tensor([[ 0.3103, -0.1338,  0.2371,  0.0037, -0.1666,  0.1625, -0.1679,  0.0930,
#          -0.0913, -0.0347],
#         [-0.3040, -0.1508,  0.1716, -0.0769,  0.3150,  0.2535, -0.0148, -0.2111,
#           0.1926,  0.0981],
#         [-0.2044,  0.2054,  0.1920,  0.2805, -0.1773, -0.0521, -0.0061,  0.0462,
#          -0.2400, -0.2244],
#         [ 0.1720, -0.0742,  0.1545,  0.0180,  0.1038,  0.0695,  0.1150,  0.1568,
#          -0.2929,  0.1592],
#         [-0.2223, -0.2386,  0.0192, -0.0539,  0.1857, -0.1831, -0.2811,  0.2301,
#          -0.0469,  0.1779]], requires_grad=True)
# [2.bias] Parameter containing:
# tensor([ 0.1017, -0.2371,  0.0635,  0.0760, -0.2117], requires_grad=True)
# [4.weight] Parameter containing:
# tensor([[-0.2122,  0.1525,  0.0801, -0.1902, -0.1354]], requires_grad=True)
# [4.bias] Parameter containing:
# tensor([0.4096], requires_grad=True)

# %% [markdown]
# [4] 학습 ==> 개발자가 구현

# %% [markdown]
# [4-1] 데이터셋 Tensor화 진행 : 데이터준비 시 진행하거나 또는 학습 전 진행

# %%
# 피쳐와 타겟 분리
featureDF = irisDF[irisDF.columns[:-1]]
targetDF = irisDF[['petal.width']]

print(featureDF.shape, targetDF.shape)
# Out:
# (150, 3) (150, 1)

# %%
# Train & Test
X_train, X_test, y_train, y_test=train_test_split(featureDF,targetDF,test_size=0.2, random_state=5)

# Train & Valid
X_train, X_val, y_train, y_val= train_test_split(X_train, y_train, test_size=0.2, random_state=5)

print(f'[FEATURE] TRAIN {X_train.shape} TEST {X_test.shape}, VAL {X_val.shape}')
print(f'[TARGET] TRAIN {y_train.shape} TEST {y_test.shape}, VAL {y_val.shape}')
# Out:
# [FEATURE] TRAIN (96, 3) TEST (30, 3), VAL (24, 3)
# [TARGET] TRAIN (96, 1) TEST (30, 1), VAL (24, 1)

# %%
print(f'[FEATURE] TRAIN {X_train.shape}')
# Out:
# [FEATURE] TRAIN (96, 3)

# %% [markdown]
# - [4-2] 학습진행
#     * 학습횟수 결정 ==> 에포크 설정
#     * 배치크기 결정
#     * 배치크기 계산

# %%
EPOCH = 100                                  # 처음~끝까지 공ㅂ주하는 횟수
BATCH_SIZE = 10                             # 1 에포크에서 한번 학습할 분량 크기
BATCH_CNT = X_train.shape[0]//BATCH_SIZE         # 1 에포크에서 총 학습 횟수이면서 업데이트 회수

print(f'EPOCH : {EPOCH}, BATCH_SIZE : {BATCH_SIZE}, BATCH_CNT : {BATCH_CNT}')
# Out:
# EPOCH : 100, BATCH_SIZE : 10, BATCH_CNT : 9

# %%
##  테스트/검증 함수
# ==> 가중치, 절편 업데이트 X,  최적화 미진행 
# ==> 현재 가중치와 절편값으로 테스트 진행 
def testing(testTS, targetTS, kind = 'val'):
    # Tensor화
    testTS = torch.FloatTensor(testTS.values).to(DEVICE)
    targetTS = torch.FloatTensor(targetTS.values).to(DEVICE)

    with torch.no_grad():   # 가중치 및 절편 업데이트 진행 X
        # -(1) 학습 진행 - forward
        pre_y = model(testTS)
        print(f'{pre_y.shape}')

        # -(2) 오차계산 - 손실함수
        loss = F.mse_loss(pre_y, targetTS)

        # -(3) 성능평가 - R2
        r2 = R2Score()(pre_y, targetTS)

        # -(4) 학습결과 출력 및 저장
        print(f'[{kind}] LOSS : {loss}, R2 : {r2}')
    return loss, r2

# %%
# 모델 학습 함수
def training(featureDF, targetDF, valTS, valTargetTS):
    #[[],[]] <= [train, val]
    loss_history = [[],[]]
    r2_history = [[],[]]

    for epoch in range(EPOCH):
        # 배치 손실 저장 변수
        bs_loss, bs_r2 = 0,0

        for i in range(BATCH_CNT):
            start = i * BATCH_SIZE
            end = start + BATCH_SIZE
            # print(start, end)
            # BS크기만큼 데이터 추출해서 Tensor화 진행
            BSX_train =  torch.FloatTensor(X_train[start:end].values).to(DEVICE)
            BSy_train = torch.FloatTensor(y_train[start:end].values).to(DEVICE)

            # print(BSX_train.shape, BSX_train.device, BSX_train.dtype)
            # print(BSy_train.shape, BSy_train.device, BSy_train.dtype)

            pre_y = model(BSX_train)
            print(f'pre_y.shape : {pre_y.shape}')

            loss = F.mse_loss(pre_y, BSy_train)
            bs_loss += loss.item()
            bs_r2 += R2Score()(pre_y, BSy_train).item()

            adam_optim.zero_grad()
            loss.backward()
            adam_optim.step()
            
        val_loss, val_r2 = testing(valTS, valTargetTS)
        loss_history[1].append(val_loss.item())
        # loss_history[1].append(val_loss)
        # r2_history[1].append(val_r2.item())
        # r2_history[1].append(val_r2)
        r2_history[1].append(val_r2.item())
        # 에포크 단위 손실과 성능지표
        loss_history[0].append(bs_loss/BATCH_CNT)
        r2_history[0].append(bs_r2/BATCH_CNT)

        print(f'[{epoch}/{EPOCH}]\nTRAIN LOSS : {loss_history[0][-1]} R2 : {r2_history[0][-1]}')
        print(f'VALID LOSS : {loss_history[1][-1]} R2 : {r2_history[1][-1]}')
    return loss_history, r2_history

# %%
# training(X_train, y_train, X_val, y_val)

# %%
# 모델 학습 진행
loss, r2 = training(X_train, y_train, X_val, y_val)
# Out:
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4173456132411957, R2 : -4.172325134277344e-06
# [0/100]
# TRAIN LOSS : 0.9089601106113858 R2 : -0.5564884477191501
# VALID LOSS : 0.4173456132411957 R2 : -4.172325134277344e-06
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4904313087463379, R2 : -0.17512524127960205
# [1/100]
# TRAIN LOSS : 0.6724570559130775 R2 : -0.15719307793511283
# VALID LOSS : 0.4904313087463379 R2 : -0.17512524127960205
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.42777684330940247, R2 : -0.02499854564666748
# [2/100]
# TRAIN LOSS : 0.6908658213085599 R2 : -0.18826834360758463
# VALID LOSS : 0.42777684330940247 R2 : -0.02499854564666748
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4195643961429596, R2 : -0.0053206682205200195
# [3/100]
# TRAIN LOSS : 0.6580390334129333 R2 : -0.11383860641055638
# VALID LOSS : 0.4195643961429596 R2 : -0.0053206682205200195
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4175474941730499, R2 : -0.00048792362213134766
# [4/100]
# TRAIN LOSS : 0.6577543748749627 R2 : -0.11573076248168945
# VALID LOSS : 0.4175474941730499 R2 : -0.00048792362213134766
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197741746902466, R2 : -0.005823254585266113
# [54/100]
# TRAIN LOSS : 0.6538664566146003 R2 : -0.10904830031924778
# VALID LOSS : 0.4197741746902466 R2 : -0.005823254585266113
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977405548095703, R2 : -0.005823016166687012
# [55/100]
# TRAIN LOSS : 0.6538697646723853 R2 : -0.10905367798275417
# VALID LOSS : 0.41977405548095703 R2 : -0.005823016166687012
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197739064693451, R2 : -0.005822658538818359
# [56/100]
# TRAIN LOSS : 0.6538729270299276 R2 : -0.10905881722768147
# VALID LOSS : 0.4197739064693451 R2 : -0.005822658538818359
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977378726005554, R2 : -0.005822300910949707
# [57/100]
# TRAIN LOSS : 0.653875986735026 R2 : -0.1090638240178426
# VALID LOSS : 0.41977378726005554 R2 : -0.005822300910949707
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.419773668050766, R2 : -0.0058220624923706055
# [58/100]
# TRAIN LOSS : 0.6538789338535733 R2 : -0.10906861888037787
# VALID LOSS : 0.419773668050766 R2 : -0.0058220624923706055
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977348923683167, R2 : -0.005821704864501953
# [59/100]
# TRAIN LOSS : 0.6538817882537842 R2 : -0.10907328128814697
# VALID LOSS : 0.41977348923683167 R2 : -0.005821704864501953
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197733700275421, R2 : -0.005821347236633301
# [60/100]
# TRAIN LOSS : 0.6538845664925046 R2 : -0.10907779799567328
# VALID LOSS : 0.4197733700275421 R2 : -0.005821347236633301
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977325081825256, R2 : -0.005821108818054199
# [61/100]
# TRAIN LOSS : 0.6538871857855055 R2 : -0.10908208953009711
# VALID LOSS : 0.41977325081825256 R2 : -0.005821108818054199
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197731912136078, R2 : -0.005820870399475098
# [62/100]
# TRAIN LOSS : 0.653889795144399 R2 : -0.10908634132809109
# VALID LOSS : 0.4197731912136078 R2 : -0.005820870399475098
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977307200431824, R2 : -0.005820631980895996
# [63/100]
# TRAIN LOSS : 0.6538923184076945 R2 : -0.1090904606713189
# VALID LOSS : 0.41977307200431824 R2 : -0.005820631980895996
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197729527950287, R2 : -0.0058203935623168945
# [64/100]
# TRAIN LOSS : 0.6538947754436069 R2 : -0.10909447405073378
# VALID LOSS : 0.4197729527950287 R2 : -0.0058203935623168945
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977283358573914, R2 : -0.005820035934448242
# [65/100]
# TRAIN LOSS : 0.6538971132702298 R2 : -0.1090982887479994
# VALID LOSS : 0.41977283358573914 R2 : -0.005820035934448242
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.419772744178772, R2 : -0.005819916725158691
# [66/100]
# TRAIN LOSS : 0.6538994312286377 R2 : -0.10910206370883518
# VALID LOSS : 0.419772744178772 R2 : -0.005819916725158691
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197726249694824, R2 : -0.005819559097290039
# [67/100]
# TRAIN LOSS : 0.653901629977756 R2 : -0.10910563998752171
# VALID LOSS : 0.4197726249694824 R2 : -0.005819559097290039
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977259516716003, R2 : -0.005819439888000488
# [68/100]
# TRAIN LOSS : 0.6539037790563371 R2 : -0.10910915003882514
# VALID LOSS : 0.41977259516716003 R2 : -0.005819439888000488
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977250576019287, R2 : -0.0058193206787109375
# [69/100]
# TRAIN LOSS : 0.653905858596166 R2 : -0.10911254088083903
# VALID LOSS : 0.41977250576019287 R2 : -0.0058193206787109375
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197724163532257, R2 : -0.005819082260131836
# [70/100]
# TRAIN LOSS : 0.6539079248905182 R2 : -0.10911589198642307
# VALID LOSS : 0.4197724163532257 R2 : -0.005819082260131836
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977226734161377, R2 : -0.005818724632263184
# [71/100]
# TRAIN LOSS : 0.6539099117120107 R2 : -0.10911913712819417
# VALID LOSS : 0.41977226734161377 R2 : -0.005818724632263184
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977226734161377, R2 : -0.005818724632263184
# [72/100]
# TRAIN LOSS : 0.6539118157492744 R2 : -0.10912226306067573
# VALID LOSS : 0.41977226734161377 R2 : -0.005818724632263184
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197721481323242, R2 : -0.005818486213684082
# [73/100]
# TRAIN LOSS : 0.653913699918323 R2 : -0.10912529627482097
# VALID LOSS : 0.4197721481323242 R2 : -0.005818486213684082
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977202892303467, R2 : -0.00581812858581543
# [74/100]
# TRAIN LOSS : 0.6539154913690355 R2 : -0.10912823677062988
# VALID LOSS : 0.41977202892303467 R2 : -0.00581812858581543
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197719991207123, R2 : -0.005818009376525879
# [75/100]
# TRAIN LOSS : 0.6539172596401639 R2 : -0.10913115077548557
# VALID LOSS : 0.4197719991207123 R2 : -0.005818009376525879
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197719097137451, R2 : -0.005817890167236328
# [76/100]
# TRAIN LOSS : 0.6539190080430772 R2 : -0.1091340117984348
# VALID LOSS : 0.4197719097137451 R2 : -0.005817890167236328
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977187991142273, R2 : -0.005817770957946777
# [77/100]
# TRAIN LOSS : 0.6539206703503927 R2 : -0.10913667413923475
# VALID LOSS : 0.41977187991142273 R2 : -0.005817770957946777
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977179050445557, R2 : -0.005817532539367676
# [78/100]
# TRAIN LOSS : 0.6539223293463389 R2 : -0.10913938946194118
# VALID LOSS : 0.41977179050445557 R2 : -0.005817532539367676
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197717010974884, R2 : -0.005817413330078125
# [79/100]
# TRAIN LOSS : 0.653923941983117 R2 : -0.1091419988208347
# VALID LOSS : 0.4197717010974884 R2 : -0.005817413330078125
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977164149284363, R2 : -0.0058171749114990234
# [80/100]
# TRAIN LOSS : 0.6539254420333438 R2 : -0.10914446247948541
# VALID LOSS : 0.41977164149284363 R2 : -0.0058171749114990234
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977158188819885, R2 : -0.005817055702209473
# [81/100]
# TRAIN LOSS : 0.6539269818200005 R2 : -0.10914696587456597
# VALID LOSS : 0.41977158188819885 R2 : -0.005817055702209473
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197715222835541, R2 : -0.005816936492919922
# [82/100]
# TRAIN LOSS : 0.6539284288883209 R2 : -0.10914931032392713
# VALID LOSS : 0.4197715222835541 R2 : -0.005816936492919922
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197714626789093, R2 : -0.005816817283630371
# [83/100]
# TRAIN LOSS : 0.6539299090703329 R2 : -0.10915174749162462
# VALID LOSS : 0.4197714626789093 R2 : -0.005816817283630371
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197714030742645, R2 : -0.0058165788650512695
# [84/100]
# TRAIN LOSS : 0.6539313031567467 R2 : -0.10915399922264947
# VALID LOSS : 0.4197714030742645 R2 : -0.0058165788650512695
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977131366729736, R2 : -0.005816459655761719
# [85/100]
# TRAIN LOSS : 0.6539326972431607 R2 : -0.10915629069010417
# VALID LOSS : 0.41977131366729736 R2 : -0.005816459655761719
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.419771283864975, R2 : -0.005816340446472168
# [86/100]
# TRAIN LOSS : 0.6539340184794532 R2 : -0.10915846294826931
# VALID LOSS : 0.419771283864975 R2 : -0.005816340446472168
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197711944580078, R2 : -0.005816221237182617
# [87/100]
# TRAIN LOSS : 0.6539352966679467 R2 : -0.10916052924262153
# VALID LOSS : 0.4197711944580078 R2 : -0.005816221237182617
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197711944580078, R2 : -0.005816221237182617
# [88/100]
# TRAIN LOSS : 0.6539365947246552 R2 : -0.1091626485188802
# VALID LOSS : 0.4197711944580078 R2 : -0.005816221237182617
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977110505104065, R2 : -0.005815982818603516
# [89/100]
# TRAIN LOSS : 0.6539378629790412 R2 : -0.10916471481323242
# VALID LOSS : 0.41977110505104065 R2 : -0.005815982818603516
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977107524871826, R2 : -0.005815863609313965
# [90/100]
# TRAIN LOSS : 0.6539390716287825 R2 : -0.10916667514377171
# VALID LOSS : 0.41977107524871826 R2 : -0.005815863609313965
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197709858417511, R2 : -0.005815744400024414
# [91/100]
# TRAIN LOSS : 0.6539402504762014 R2 : -0.10916860898335774
# VALID LOSS : 0.4197709858417511 R2 : -0.005815744400024414
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197709560394287, R2 : -0.005815625190734863
# [92/100]
# TRAIN LOSS : 0.6539413962099287 R2 : -0.10917048984103733
# VALID LOSS : 0.4197709560394287 R2 : -0.005815625190734863
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977086663246155, R2 : -0.005815386772155762
# [93/100]
# TRAIN LOSS : 0.6539425585005019 R2 : -0.10917238394419353
# VALID LOSS : 0.41977086663246155 R2 : -0.005815386772155762
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977086663246155, R2 : -0.005815386772155762
# [94/100]
# TRAIN LOSS : 0.6539436876773834 R2 : -0.10917421181996663
# VALID LOSS : 0.41977086663246155 R2 : -0.005815386772155762
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977083683013916, R2 : -0.005815267562866211
# [95/100]
# TRAIN LOSS : 0.6539447671837277 R2 : -0.10917598671383327
# VALID LOSS : 0.41977083683013916 R2 : -0.005815267562866211
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197708070278168, R2 : -0.005815267562866211
# [96/100]
# TRAIN LOSS : 0.6539458665582869 R2 : -0.10917778809865315
# VALID LOSS : 0.4197708070278168 R2 : -0.005815267562866211
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.419770747423172, R2 : -0.00581514835357666
# [97/100]
# TRAIN LOSS : 0.6539468897713555 R2 : -0.1091794040468004
# VALID LOSS : 0.419770747423172 R2 : -0.00581514835357666
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.4197706878185272, R2 : -0.005814909934997559
# [98/100]
# TRAIN LOSS : 0.653947909673055 R2 : -0.10918109946780735
# VALID LOSS : 0.4197706878185272 R2 : -0.005814909934997559
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# pre_y.shape : torch.Size([10, 1])
# torch.Size([24, 1])
# [val] LOSS : 0.41977062821388245, R2 : -0.005814790725708008
# [99/100]
# TRAIN LOSS : 0.6539489163292779 R2 : -0.10918274190690783
# VALID LOSS : 0.41977062821388245 R2 : -0.005814790725708008

# %%
# 학습 후 loss 시각화
THRESHOLD = 100 # 안 주면 전체가 나옴 => 값을 보기 어려움 => 자세히 보기 위함 => 끊기 위함 
fg, axes = plt.subplots(1,2, figsize = (10,5))
axes[0].plot(range(1,THRESHOLD+1), loss[0][:THRESHOLD], label = 'Train')
axes[0].plot(range(1,THRESHOLD+1), loss[1][:THRESHOLD], label = 'Val')
axes[0].grid()
axes[0].legend()
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('LOSS')


axes[1].plot(range(1,THRESHOLD+1), r2[0][:THRESHOLD], label = 'Train')
axes[1].plot(range(1,THRESHOLD+1), r2[1][:THRESHOLD], label = 'Val')
axes[1].grid()
axes[1].legend()
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('R2')
axes[1].set_title('R2')
# Out:
# Text(0.5, 1.0, 'R2')
