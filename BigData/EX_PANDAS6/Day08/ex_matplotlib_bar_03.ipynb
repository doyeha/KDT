# %% [markdown]
# #### [막대그래프 활용]

# %%
# [1] 모듈로딩
import numpy as np 
import matplotlib.pyplot as plt

# %%
# [2] 데이터 준비
species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence

# %%
# [3] 펭귄 품종 시각화
# 품종에 따른 성별 비교
fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    #bottom 매개변수 누락
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count
    # 막대 그래프 내에 라벨 추가
    ax.bar_label(p, label_type='center')

# ax.set_title('Number of penguins by sex')
ax.set(title = 'Number of penguins by sex', xlabel='penguin', ylabel='count')
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # [3] 펭귄 품종 시각화
#       2 # 품종에 따른 성별 비교
# ----> 3 fig, ax = plt.subplots()
#       4 bottom = np.zeros(3)
#       6 for sex, sex_count in sex_counts.items():
#       7     #bottom 매개변수 누락
#
# NameError: name 'plt' is not defined

# %% [markdown]
#  - 다중막대 그래프

# %%
# X축 데이터
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}
# Y축 데이터
# 그래프에 나타낼 x축 위치값, 막대그래프 너비, 다중 그래프 간격 값
x = np.arange(len(species))  # (0,3,1)
width = 0.25                    # the width of the bars
multiplier = 0                  # 막대그래프 간격

# %%
# 품종별 특징 비교 다중그래프
fig, ax = plt.subplots(layout='constrained')

# 막대 그리기
for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)   # 눈금
ax.legend(loc='upper left', ncols=3)    # 범례 위치 // ncols 아래로 나오냐. 옆으로 주르륵 나열하느냐 
ax.set_ylim(0, 250)

plt.show()
