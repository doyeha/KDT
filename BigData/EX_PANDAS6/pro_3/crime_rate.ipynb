# %%
import pandas as pd
#

# %% [markdown]
# #### 연도별로 범죄 유형(살인, 강도, 절도, 성폭력 등)의 발생 빈도 변화를 분석
# 특정 범죄 유형이 다른 범죄 유형보다 더 많은 추세를 보이는지 분석
# 지역별 범죄 발생률 비교
#
# 법률 여부 / 범죄 카테고리 / 범죄명

# %%
crime_year = pd.read_excel('범죄발생_월별.xlsx')
# crime_year['2020']
# crime_year.columns = ['법률 여부', '범죄 카테고리', '범죄명',2020,2021,2022]    # 칼럼명 변경
crime_year # 확인용 호출


# """
# crime_year = pd.read_excel('범죄발생_월_20_22.xlsx')
# crime_year.columns = ['법률 여부', '범죄 카테고리', '범죄명',2020,2021,2022]    # 칼럼명 변경
# crime_year # 확인용 호출
# """
# Out:
# c:\Users\kjy19\anaconda3\envs\EV_PY39\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      범죄별(1)                        범죄별(2)  범죄별(3)     2020  2020.1  2020.2  \
# 0    범죄별(1)                        범죄별(2)  범죄별(3)        계      1월      2월
# 1         계                            소계      소계  1714579  141057  128756
# 2       형법범                            소계      소계  1044438   85656   80165
# 3       형법범                          재산범죄      소계   659058   54264   51314
# 4       형법범                          재산범죄      절도   180067   14875   13765
# ..      ...                           ...     ...      ...     ...     ...
# 173    특별법범           화재로인한재해보상과보험가입에관한법률      소계       23       -       -
# 174    특별법범       화재예방·소방시설설치유지및안전관리에관한법률      소계      391      40      28
# ...

# %% [markdown]
# #### 20년도 데이터 정리

# %%
# 20년도 월별 범죄발생
y20_crime = pd.concat([crime_year['범죄별(1)'], crime_year['범죄별(2)'], crime_year['범죄별(3)'],crime_year['2020'],crime_year['2020.1'],crime_year['2020.2'],crime_year['2020.3'],
                       crime_year['2020.4'],crime_year['2020.5'],crime_year['2020.6'],crime_year['2020.7'],
                       crime_year['2020.8'],crime_year['2020.9'],crime_year['2020.10'],crime_year['2020.11'],
                       crime_year['2020.12']],  axis=1 ,keys=['법률 여부','범죄 카테고리','범죄명','소계','1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월',])
y20_crime.drop(0)

# # crime_year.columns = ['법률 여부', '범죄 카테고리', '범죄명',2020,2021,2022]    # 칼럼명 변경
# crime_year.do
# Out:
#     법률 여부                       범죄 카테고리 범죄명       소계      1월      2월      3월  \
# 1       계                            소계  소계  1714579  141057  128756  144857
# 2     형법범                            소계  소계  1044438   85656   80165   91717
# 3     형법범                          재산범죄  소계   659058   54264   51314   59656
# 4     형법범                          재산범죄  절도   180067   14875   13765   15330
# 5     형법범                          재산범죄  장물      616      47      75      64
# ..    ...                           ...  ..      ...     ...     ...     ...
# 173  특별법범           화재로인한재해보상과보험가입에관한법률  소계       23       -       -       -
# 174  특별법범       화재예방·소방시설설치유지및안전관리에관한법률  소계      391      40      28      21
# 175  특별법범  화재의예방및안전에관한법률/소방시설설치및관리에관한법률  소계        -       -       -       -
# 176  특별법범                       화학물질관리법  소계      702     106      47      65
# 177  특별법범                         기타특별법  소계    51472    4054    3951    4345
#
# ...

# %%
# y20_crime.drop([y20_crime['소계']<100])

# 소계 - 값 삭제
y20_crime['소계'].describe()

# 소계의 타입이 object면 삭제 .. 하고싶은데요?
y20_crime.drop(y20_crime[y20_crime['소계']=='-'].index, axis=0, inplace=True)       
#소계에 - 표기되어있는 것들은 삭제. // 아예 일어나지 않은 범죄.
y20_crime           # 177에서 173으로 줄었다.
# Out:
#       법률 여부                  범죄 카테고리     범죄명       소계      1월      2월      3월  \
# 0    범죄별(1)                   범죄별(2)  범죄별(3)        계      1월      2월      3월
# 1         계                       소계      소계  1714579  141057  128756  144857
# 2       형법범                       소계      소계  1044438   85656   80165   91717
# 3       형법범                     재산범죄      소계   659058   54264   51314   59656
# 4       형법범                     재산범죄      절도   180067   14875   13765   15330
# ..      ...                      ...     ...      ...     ...     ...     ...
# 172    특별법범               화물자동차운수사업법      소계     3198     287     187     191
# 173    특별법범      화재로인한재해보상과보험가입에관한법률      소계       23       -       -       -
# 174    특별법범  화재예방·소방시설설치유지및안전관리에관한법률      소계      391      40      28      21
# 176    특별법범                  화학물질관리법      소계      702     106      47      65
# 177    특별법범                    기타특별법      소계    51472    4054    3951    4345
#
# ...

# %%
# 20년도 비슷한 류의 묶음 범죄율 총 증감 계산
y20_crime[(y20_crime['범죄명']=='소계') & (y20_crime['법률 여부']=='형법범')]
# Out:
#    법률 여부   범죄 카테고리 범죄명       소계     1월     2월     3월     4월     5월     6월  \
# 2    형법범        소계  소계  1044438  85656  80165  91717  88949  93787  90794
# 3    형법범      재산범죄  소계   659058  54264  51314  59656  56671  58842  56683
# 10   형법범  강력범죄(흉악)  소계    32812   2424   2279   2458   2572   3020   3178
# 15   형법범  강력범죄(폭력)  소계   210241  17082  15977  17806  17936  19308  18428
# 24   형법범      위조범죄  소계    15614   1556   1174   1428   1308   1353   1333
# 29   형법범     공무원범죄  소계     3689    398    244    295    280    314    348
# 34   형법범      풍속범죄  소계    10951    939    731    777    786    889    787
# 38   형법범      과실범죄  소계     8873    641    616    776    894    802    782
# 42   형법범    기타형법범죄  소계   103200   8352   7830   8521   8502   9259   9255
#
#        7월     8월     9월    10월    11월    12월
# 2   90549  87088  83548  86647  82377  83161
# 3   55737  53235  52029  54397  53063  53167
# 10   3336   3164   2800   2696   2422   2463
# 15  18583  18408  17047  17537  15873  16256
# ...

# %% [markdown]
# #### 21년도

# %%
# 20년도 월별 범죄발생
y21_crime = pd.concat([crime_year['범죄별(1)'], crime_year['범죄별(2)'], crime_year['범죄별(3)'],crime_year['2021'],crime_year['2021.1'],crime_year['2021.2'],crime_year['2021.3'],
                       crime_year['2021.4'],crime_year['2021.5'],crime_year['2021.6'],crime_year['2021.7'],
                       crime_year['2021.8'],crime_year['2021.9'],crime_year['2021.10'],crime_year['2021.11'],
                       crime_year['2021.12']],  axis=1 ,keys=['법률 여부','범죄 카테고리','범죄명','소계','1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월',])
y21_crime.drop(0)
# Out:
#     법률 여부                       범죄 카테고리 범죄명       소계      1월      2월      3월  \
# 1       계                            소계  소계  1531705  123663  111342  140066
# 2     형법범                            소계  소계   917787   75464   66925   82663
# 3     형법범                          재산범죄  소계   575332   49205   42409   52426
# 4     형법범                          재산범죄  절도   166782   11393   11823   14260
# 5     형법범                          재산범죄  장물      302      22      23      32
# ..    ...                           ...  ..      ...     ...     ...     ...
# 173  특별법범           화재로인한재해보상과보험가입에관한법률  소계       39       8       3       1
# 174  특별법범       화재예방·소방시설설치유지및안전관리에관한법률  소계      517      46      38      50
# 175  특별법범  화재의예방및안전에관한법률/소방시설설치및관리에관한법률  소계        -       -       -       -
# 176  특별법범                       화학물질관리법  소계      612      80      41     137
# 177  특별법범                         기타특별법  소계    58456    5087    3934    5465
#
# ...

# %%
# 소계 - 값 삭제
y21_crime['소계'].describe()

# 소계의 타입이 object면 삭제 .. 하고싶은데요?
y21_crime.drop(y21_crime[y21_crime['소계']=='-'].index, axis=0, inplace=True)

# %%
# 비슷한 류의 묶음 범죄율 총 증감 계산
y21_crime[(y21_crime['범죄명']=='소계') & (y21_crime['법률 여부']=='형법범')]
# Out:
#    법률 여부   범죄 카테고리 범죄명      소계     1월     2월     3월     4월     5월     6월  \
# 2    형법범        소계  소계  917787  75464  66925  82663  78408  79288  82058
# 3    형법범      재산범죄  소계  575332  49205  42409  52426  48788  47698  49578
# 10   형법범  강력범죄(흉악)  소계   35126   2386   2279   2976   3049   3512   3869
# 15   형법범  강력범죄(폭력)  소계  180460  13328  13621  16115  15709  16482  16881
# 24   형법범      위조범죄  소계   13518   1260    983   1354   1113   1112   1133
# 29   형법범     공무원범죄  소계    3717    353    250    268    255    315    332
# 34   형법범      풍속범죄  소계    9135   1044    514    718    568   1088    929
# 38   형법범      과실범죄  소계    8179    629    653    762    815    705    766
# 42   형법범    기타형법범죄  소계   92320   7259   6216   8044   8111   8376   8570
#
#        7월     8월     9월    10월    11월    12월
# 2   80542  74885  76528  75583  75170  70273
# 3   49201  46464  46917  47937  48208  46501
# 10   3588   3148   2993   2708   2536   2082
# 15  16136  15096  15720  14969  14283  12120
# ...

# %% [markdown]
# #### 22년도

# %%
y22_crime = pd.concat([crime_year['범죄별(1)'], crime_year['범죄별(2)'], crime_year['범죄별(3)'],crime_year['2022'],crime_year['2022.1'],crime_year['2022.2'],crime_year['2022.3'],
                       crime_year['2022.4'],crime_year['2022.5'],crime_year['2022.6'],crime_year['2022.7'],
                       crime_year['2022.8'],crime_year['2022.9'],crime_year['2022.10'],crime_year['2022.11'],
                       crime_year['2022.12']],  axis=1 ,keys=['법률 여부','범죄 카테고리','범죄명','소계','1월','2월','3월','4월','5월','6월','7월','8월','9월','10월','11월','12월',])
y22_crime.drop(0)
# Out:
#     법률 여부                       범죄 카테고리 범죄명       소계      1월      2월      3월  \
# 1       계                            소계  소계  1575007  117973  104215  130050
# 2     형법범                            소계  소계  1003883   74273   65528   82260
# 3     형법범                          재산범죄  소계   634864   47842   42948   53155
# 4     형법범                          재산범죄  절도   182720   11847   11221   14482
# 5     형법범                          재산범죄  장물      256      21      19      28
# ..    ...                           ...  ..      ...     ...     ...     ...
# 173  특별법범           화재로인한재해보상과보험가입에관한법률  소계        6       1       -       -
# 174  특별법범       화재예방·소방시설설치유지및안전관리에관한법률  소계        -       -       -       -
# 175  특별법범  화재의예방및안전에관한법률/소방시설설치및관리에관한법률  소계      502      44      54      57
# 176  특별법범                       화학물질관리법  소계     1006     129      75     112
# 177  특별법범                         기타특별법  소계    59166    4449    3960    4756
#
# ...

# %%
# 소계 - 값 삭제
y22_crime['소계'].describe()

# 소계의 타입이 object면 삭제 .. 하고싶은데요?
y22_crime.drop(y22_crime[y22_crime['소계']=='-'].index, axis=0, inplace=True)

# %%
y22_crime[(y22_crime['범죄명']=='소계') & (y22_crime['법률 여부']=='형법범')]
# Out:
#    법률 여부   범죄 카테고리 범죄명       소계     1월     2월     3월     4월     5월     6월  \
# 2    형법범        소계  소계  1003883  74273  65528  82260  86863  92893  89138
# 3    형법범      재산범죄  소계   634864  47842  42948  53155  55177  57979  55413
# 10   형법범  강력범죄(흉악)  소계    43927   3133   2590   3439   3723   4493   4222
# 15   형법범  강력범죄(폭력)  소계   190870  13558  11597  14984  16781  18282  17455
# 24   형법범      위조범죄  소계    13622   1102    980   1188   1200   1155   1143
# 29   형법범     공무원범죄  소계     4775    409    303    343    409    471    457
# 34   형법범      풍속범죄  소계     7016    526    453    584    442    509    650
# 38   형법범      과실범죄  소계     8901    725    730    720    870    974    713
# 42   형법범    기타형법범죄  소계    99908   6978   5927   7847   8261   9030   9085
#
#        7월     8월     9월    10월    11월    12월
# 2   90786  89029  86987  87153  81800  77173
# 3   56926  56187  53640  54632  51481  49484
# 10   4404   4152   4068   3608   3316   2779
# 15  17184  16578  17632  16747  15834  14238
# ...

# %% [markdown]
# #### 특례법범 pro_crime에서

# %%
car = pd.concat([car20,car21,car22])
car
# Out:
#    법률 여부      범죄 카테고리 범죄명      소계     1월     2월     3월     4월     5월     6월  \
# 79  특별법범    교통사고처리특례법  소계  184990  15123  14099  12772  13898  15644  16473
# 79  특별법범    교통사고처리특례법  소계  155625  13069  12726  14417  15137  15018  15159
# 97  특별법범  도로교통법(음주운전)  소계  100321   6933   5898   8177   9522   9604   8792
#
#        7월     8월     9월    10월    11월    12월
# 79  15729  15221  15521  16850  16884  16776
# 79  15337  13749  13121   9120   7974  10798
# 97   9317   8483   8707   9296   8125   7467

# %%
car = pd.concat([spic20[spic20['범죄 카테고리']=='교통사고처리특례법'],spic21[spic21['범죄 카테고리']=='교통사고처리특례법'],spic22[spic22['범죄 카테고리']=='교통사고처리특례법']])
car
# Out:
#    법률 여부    범죄 카테고리 범죄명      소계     1월     2월     3월     4월     5월     6월  \
# 79  특별법범  교통사고처리특례법  소계  184990  15123  14099  12772  13898  15644  16473
# 79  특별법범  교통사고처리특례법  소계  155625  13069  12726  14417  15137  15018  15159
# 79  특별법범  교통사고처리특례법  소계   76210   6212   4922   5347   6264   6825   6162
#
#        7월     8월     9월    10월    11월    12월
# 79  15729  15221  15521  16850  16884  16776
# 79  15337  13749  13121   9120   7974  10798
# 79   6421   6332   6728   7277   6867   6853

# %%
drink = pd.concat([spic20[spic20['범죄 카테고리']=='도로교통법(음주운전)'],spic21[spic21['범죄 카테고리']=='도로교통법(음주운전)'],spic22[spic22['범죄 카테고리']=='도로교통법(음주운전)']])
drink
# Out:
#    법률 여부      범죄 카테고리 범죄명      소계    1월    2월    3월    4월    5월    6월    7월  \
# 97  특별법범  도로교통법(음주운전)  소계   95569  7806  5180  7006  8154  8341  8339  9124
# 97  특별법범  도로교통법(음주운전)  소계   91055  5692  6301  8294  8178  7935  7951  7736
# 97  특별법범  도로교통법(음주운전)  소계  100321  6933  5898  8177  9522  9604  8792  9317
#
#       8월    9월   10월   11월   12월
# 97  8438  8728  9040  8191  7222
# 97  7249  7968  8734  8298  6719
# 97  8483  8707  9296  8125  7467

# %% [markdown]
# #### 이하 실패실패 실패

# %%
sogyeDF = crime_year[(crime_year['범죄명']=='소계') & (crime_year['법률 여부']=='형법범')]

sogDF = sogyeDF.copy()
# sogDF[2020].count()
# sogDF['증감']=[

# ]
# sogDF['증감'] = "+" if sogDF[2020]-sogDF[2021] > 0 else "-", "+" if sogDF[2021]-sogDF[2022] > 0 else "-"

test01 = []
for i in range(0,sogDF[2020].count()):
    if sogDF.iloc[i][2020]-sogDF.iloc[i][2021] > 0:
        if sogDF.iloc[i][2021]-sogDF.iloc[i][2022] > 0:
            test01.append("↘↘")
        elif sogDF.iloc[i][2021]-sogDF.iloc[i][2022] < 0:
            test01.append("↘↗")
        else:
            test01.append("↘→")

    elif sogDF.iloc[i][2020]-sogDF.iloc[i][2021] < 0:
        if sogDF.iloc[i][2021]-sogDF.iloc[i][2022] > 0:
            test01.append("↘↗")
        elif sogDF.iloc[i][2021]-sogDF.iloc[i][2022] < 0:
            test01.append("↗↗")
        else:
            sogDF.iloc[i]['증감'] = "↘→"


sogDF['증감'] = test01
# sogDF.iloc[0][2020] - sogDF[0][2021]

#     sogDF[i]['증감'] = ("+" if sogDF[i][2020]-sogDF[i][2021] > 0 else "-", "+" if sogDF[i][2021]-sogDF[i][2022] > 0 else "-")
sogDF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kjy19\anaconda3\envs\EV_PY39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '범죄명'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ...

# %%
sogDF

# %%
print(crime_year['범죄별(1)'].describe()[1])    # 범죄별(1) 종류 1
print(crime_year['범죄별(1)'].describe()[1])

# %%
crime_year.iloc[3:59]
crime_year.iloc[range(3,60)]['범죄별'] = '형법범'

# crime_year.iloc[59]
# f.iloc[[0, 1], [2, 3]]

# crime_year['범죄별(1)'] =

crime_year

# %%
crime_area = pd.read_excel('범죄발생_지역_20_22.xlsx').T
crime_area

# %%
crime_thief = pd.read_excel('강도·절도_및_사기_수법_20_22.xlsx').T
crime_thief

# %%
crime_thief = pd.read_excel('강도·절도_및_사기_수법_20_22.xlsx').T
crime_thief
